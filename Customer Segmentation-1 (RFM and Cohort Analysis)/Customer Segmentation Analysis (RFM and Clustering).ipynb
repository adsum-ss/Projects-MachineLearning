# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # WELCOME!

# %% [markdown]
# Welcome to "RFM Customer Segmentation & Cohort Analysis Project". This is the first project of the Capstone Project Series, which consists of 3 different project that contain different scenarios.
#
# This is a project which you will learn what is RFM? And how to apply RFM Analysis and Customer Segmentation using K-Means Clustering. Also you will improve your Data Cleaning, Data Visualization and Exploratory Data Analysis capabilities. On the other hand you will create Cohort and Conduct Cohort Analysis.
#
# Before diving into the project, please take a look at the determines and project structure.
#
# - **NOTE:** This Project assumes that you already know the basics of coding in Python and are familiar with the theory behind K-Means Clustering.

# %% [markdown]
# # Determines
#
# Using the [Online Retail dataset](https://archive.ics.uci.edu/ml/datasets/Online+Retail) from the UCI Machine Learning Repository for exploratory data analysis, ***Customer Segmentation***, ***RFM Analysis***, ***K-Means Clustering*** and ***Cohort Analysis***.
#
# This is a transnational data set which contains all the transactions occurring between 01/12/2010 and 09/12/2011 for a UK-based and registered non-store online retail. The company mainly sells unique all-occasion gifts. Many customers of the company are wholesalers.
#
# Feature Information:
#
# **InvoiceNo**: Invoice number. *Nominal*, a 6-digit integral number uniquely assigned to each transaction. If this code starts with letter 'c', it indicates a cancellation.
# <br>
# **StockCode**: Product (item) code. *Nominal*, a 5-digit integral number uniquely assigned to each distinct product.
# <br>
# **Description**: Product (item) name. *Nominal*.
# <br>
# **Quantity**: The quantities of each product (item) per transaction. *Numeric*.
# <br>
# **InvoiceDate**: Invoice Date and time. *Numeric*, the day and time when each transaction was generated.
# <br>
# **UnitPrice**: Unit price. *Numeric*, Product price per unit in sterling.
# <br>
# **CustomerID**: Customer number. *Nominal*, a 5-digit integral number uniquely assigned to each customer.
# <br>
# **Country**: Country name. *Nominal*, the name of the country where each customer resides.
#
#
# ---
#
#
# First of all, to observe the structure of the data and missing values, you can use exploratory data analysis and data visualization techniques.
#
# You must do descriptive analysis. Because you must understand the relationship of the features to each other and clear the noise and missing values in the data. After that, the data set will be ready for RFM analysis.
#
# Before starting the RFM Analysis, you will be asked to do some analysis regarding the distribution of *Orders*, *Customers* and *Countries*. These analyzes will help the company develop its sales policies and contribute to the correct use of resources.
#
# You will notice that the UK not only has the most sales revenue, but also the most customers. So you will continue to analyze only UK transactions in the next RFM Analysis, Customer Segmentation and K-Means Clustering topics.
#
# Next, you will begin RFM Analysis, a customer segmentation technique based on customers' past purchasing behavior.
#
# By using RFM Analysis, you can enable companies to develop different approaches to different customer segments so that they can get to know their customers better, observe trends better, and increase customer retention and sales revenues.
#
# You will calculate the Recency, Frequency and Monetary values of the customers in the RFM Analysis you will make using the data consisting of UK transactions. Ultimately, you have to create an RFM table containing these values.
#
# In the Customer Segmentation section, you will create an RFM Segmentation Table where you segment your customers by using the RFM table. For example, you can label the best customer as "Big Spenders" and the lost customer as "Lost Customer".
#
# We will segment the customers ourselves based on their recency, frequency, and monetary values. But can an **unsupervised learning** model do this better for us? You will use the K-Means algorithm to find the answer to this question. Then you will compare the classification made by the algorithm with the classification you have made yourself.
#
# Before applying K-Means Clustering, you should do data pre-processing. In this context, it will be useful to examine feature correlations and distributions. In addition, the data you apply for K-Means should be normalized.
#
# On the other hand, you should inform the K-means algorithm about the number of clusters it will predict. You will also try the ***Elbow method*** and ***Silhouette Analysis*** to find the optimum number of clusters.
#
# After the above operations, you will have made cluster estimation with K-Means. You should visualize the cluster distribution by using a scatter plot. You can observe the properties of the resulting clusters with the help of the boxplot. Thus you will be able to tag clusters and interpret results.
#
# Finally, you will do Cohort Analysis with the data you used at the beginning, regardless of the analysis you have done before. Cohort analysis is a subset of behavioral analytics that takes the user data and breaks them into related groups for analysis. This analysis can further be used to do customer segmentation and track metrics like retention, churn, and lifetime value.

# %% [markdown]
# # Project Structures
#
# - Data Cleaning & Exploratory Data Analysis
# - RFM Analysis
# - Customer Segmentation
# - Applying K-Means Clustering
# - Create Cohort and Conduct Cohort Analysis

# %% [markdown]
# # Tasks
#
# #### 1. Data Cleaning & Exploratory Data Analysis
#
# - Import Modules, Load Data & Data Review
#
#
# - Follow the Steps Below
#
#     *i. Take a look at relationships between InvoiceNo, Quantity and UnitPrice columns.*
#
#     *ii. What does the letter "C" in the invoiceno column mean?*
#
#     *iii. Handling Missing Values*
#
#     *iv. Clean the Data from the Noise and Missing Values*
#
#     *v. Explore the Orders*
#
#     *vi. Explore Customers by Country*
#
#     *vii. Explore the UK Market*
#
# #### 2. RFM Analysis
#
# - Follow the steps below
#
#    *i. Import Libraries*
#
#    *ii. Review "df_uk" DataFrame (the df_uk what you create at the end of the Task 1)*
#
#    *iii. Calculate Recency*
#
#    *iv. Calculate Frequency*
#
#    *v. Calculate Monetary Values*
#
#    *vi. Create RFM Table*
#
# #### 3. Customer Segmentation with RFM Scores
# - Calculate RFM Scoring
#
#     *i. Creating the RFM Segmentation Table*
#
#
# - Plot RFM Segments
#
# #### 4. Applying K-Means Clustering
# - Data Pre-Processing and Exploring
#
#     *i. Define and Plot Feature Correlations*
#
#     *ii. Visualize Feature Distributions*
#
#     *iii. Data Normalization*
#
#
# - K-Means Implementation
#
#     *i. Define Optimal Cluster Number (K) by using "Elbow Method" and "Silhouette Analysis"*
#
#     *ii. Visualize the Clusters*
#
#     *iii. Assign the label*
#
#     *iv. Conclusion*
#
# #### 5. Create Cohort and Conduct Cohort Analysis
# - Future Engineering
#
#     *i. Extract the Month of the Purchase*<br>
#     *ii. Calculating time offset in Months i.e. Cohort Index*
#
#
# - Create 1st Cohort: User Number & Retention Rate
#
#     *i. Pivot Cohort and Cohort Retention*<br>
#     *ii. Visualize analysis of cohort 1 using seaborn and matplotlib*
#
#
# - Create 2nd Cohort: Average Quantity Sold
#
#     *i. Pivot Cohort and Cohort Retention*<br>
#     *ii. Visualize analysis of cohort 2 using seaborn and matplotlib*
#
#
# - Create 3rd Cohort: Average Sales
#
#     *i. Pivot Cohort and Cohort Retention*<br>
#     *ii. Visualize analysis of cohort 3 using seaborn and matplotlib*
#
#
# - **Note: There may be sub-tasks associated with each task, you will see them in order during the course of the work.**

# %% [markdown]
# # 1. Data Cleaning & Exploratory Data Analysis

# %% [markdown]
# ## Import Modules, Load Data & Data Review

# %%
import numpy as np
import pandas as pd
from scipy.stats import skew

#Libraries for data visualization
import matplotlib.pyplot as plt
import seaborn as sns
import squarify
from pandas.plotting import scatter_matrix
from yellowbrick.style import set_palette
set_palette('flatui')

import warnings
warnings.filterwarnings('ignore')

sns.set_style("whitegrid")
plt.rcParams["figure.figsize"] = (10,6)
# pd.set_option('display.max_columns', 100)
# pd.set_option('display.max_rows', 150)
# pd.set_option('display.float_format', '{:.3f}'.format)

# %%
data = pd.read_excel('Online Retail.xlsx')

# %%
df = data.copy()
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0       536365.0    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1       536365.0   71053.0                  WHITE METAL LANTERN       6.0
# 2       536365.0    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3       536365.0    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4       536365.0    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
# ...          ...       ...                                  ...       ...
# 541904  581587.0   22613.0          PACK OF 20 SPACEBOY NAPKINS      12.0
# 541905  581587.0   22899.0         CHILDREN'S APRON DOLLY GIRL        6.0
# 541906  581587.0   23254.0        CHILDRENS CUTLERY DOLLY GIRL        4.0
# 541907  581587.0   23255.0      CHILDRENS CUTLERY CIRCUS PARADE       4.0
# 541908  581587.0   22138.0        BAKING SET 9 PIECE RETROSPOT        3.0
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  float64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(3), object(4)
# memory usage: 33.1+ MB

# %%
df.shape, df.size
# Out:
# ((541909, 8), 4335272)

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
(df.isnull().sum()/len(df))*100
# Out:
# InvoiceNo       0.000000
# StockCode       0.000000
# Description     0.268311
# Quantity        0.000000
# InvoiceDate     0.000000
# UnitPrice       0.000000
# CustomerID     24.926694
# Country         0.000000
# dtype: float64

# %%
df.nunique()
# Out:
# InvoiceNo      25900
# StockCode       4070
# Description     4223
# Quantity         722
# InvoiceDate    23260
# UnitPrice       1630
# CustomerID      4372
# Country           38
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 5268

# %%
df[df.duplicated(keep=False)]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 485     536409.0   22111.0      SCOTTIE DOG HOT WATER BOTTLE       1.0
# 489     536409.0   22866.0     HAND WARMER SCOTTY DOG DESIGN       1.0
# 494     536409.0   21866.0       UNION JACK FLAG LUGGAGE TAG       1.0
# 517     536409.0   21866.0       UNION JACK FLAG LUGGAGE TAG       1.0
# 521     536409.0   22900.0   SET 2 TEA TOWELS I LOVE LONDON        1.0
# ...          ...       ...                               ...       ...
# 541675  581538.0   22068.0       BLACK PIRATE TREASURE CHEST       1.0
# 541689  581538.0   23318.0    BOX OF 6 MINI VINTAGE CRACKERS       1.0
# 541692  581538.0   22992.0            REVOLVER WOODEN RULER        1.0
# 541699  581538.0   22694.0                      WICKER STAR        1.0
# 541701  581538.0   23343.0      JUMBO BAG VINTAGE CHRISTMAS        1.0
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.drop_duplicates(inplace = True)

# %%
df.shape
# Out:
# (536641, 8)

# %%
df.describe().T.style.background_gradient(subset=['mean','std','min','max'], cmap='Set2')
# Out:
# <style type="text/css">
# #T_6307b_row0_col1, #T_6307b_row0_col2, #T_6307b_row0_col3, #T_6307b_row1_col1, #T_6307b_row1_col2, #T_6307b_row2_col7 {
#   background-color: #66c2a5;
#   color: #000000;
# }
# #T_6307b_row0_col7, #T_6307b_row2_col1, #T_6307b_row2_col2, #T_6307b_row2_col3 {
#   background-color: #b3b3b3;
#   color: #000000;
# }
# #T_6307b_row1_col3 {
#   background-color: #ffd92f;
#   color: #000000;
# }
# #T_6307b_row1_col7 {
#   background-color: #8da0cb;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6307b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >mean</th>
#       <th class="col_heading level0 col2" >std</th>
#       <th class="col_heading level0 col3" >min</th>
#       <th class="col_heading level0 col4" >25%</th>
#       <th class="col_heading level0 col5" >50%</th>
#       <th class="col_heading level0 col6" >75%</th>
# ...

# %% [markdown]
# ### InvoiceNo

# %%
df.InvoiceNo.nunique()
# Out:
# 25900

# %%
df.InvoiceNo.map(type).value_counts()
# Out:
# <class 'float'>    527387
# <class 'str'>        9254
# Name: InvoiceNo, dtype: int64

# %%
# invoice numbers with 'str' type
df[df.InvoiceNo.map(type)==str]['InvoiceNo'].sample(5)
# Out:
# 83745     C543347
# 64574     C541654
# 382811    C569960
# 352768    C567685
# 329636    C565848
# Name: InvoiceNo, dtype: object

# %%
df.InvoiceNo.str.contains('C').value_counts()
# Out:
# True     9251
# False       3
# Name: InvoiceNo, dtype: int64

# %%
df[df.InvoiceNo.str.contains('C')==False]
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 299982   A563185         B  Adjust bad debt       1.0 2011-08-12 14:50:00
# 299983   A563186         B  Adjust bad debt       1.0 2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt       1.0 2011-08-12 14:52:00
#
#         UnitPrice  CustomerID         Country
# 299982   11062.06         NaN  United Kingdom
# 299983  -11062.06         NaN  United Kingdom
# 299984  -11062.06         NaN  United Kingdom

# %%
df[df.InvoiceNo.str.contains('C')==True].sample(5)
# Out:
#        InvoiceNo StockCode                     Description  Quantity  \
# 1978     C536548   22767.0     TRIPLE PHOTO FRAME CORNICE       -2.0
# 38454    C539576   22896.0           PEG BAG APPLES DESIGN     -12.0
# 441971   C574658   22197.0                  POPCORN HOLDER      -3.0
# 263237   C559952   21534.0       DAIRY MAID LARGE MILK JUG      -2.0
# 268142   C560391   22698.0  PINK REGENCY TEACUP AND SAUCER      -1.0
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 1978   2010-12-01 14:33:00       9.95     12472.0         Germany
# 38454  2010-12-20 12:25:00       2.55     14911.0            EIRE
# 441971 2011-11-06 11:44:00       0.85     15426.0  United Kingdom
# 263237 2011-07-14 10:57:00       4.95     17696.0  United Kingdom
# 268142 2011-07-18 13:21:00       2.95     12930.0  United Kingdom

# %%
# distribution of 'str' type invoice numbers
# starting with 'C' ===> 9288
# starting with 'A' ===> 3

# %%
df.InvoiceNo.value_counts()
# Out:
# 573585.0    1114
# 581219.0     749
# 581492.0     731
# 580729.0     721
# 558475.0     705
#             ...
# 570518.0       1
# C550935        1
# 550937.0       1
# 550940.0       1
# C558901        1
# Name: InvoiceNo, Length: 25900, dtype: int64

# %%
# Are invoice numbers and customer IDs compatible?

df.groupby('InvoiceNo')['CustomerID'].value_counts().nlargest()
# Out:
# InvoiceNo  CustomerID
# 576339.0   14096.0       542
# 579196.0   14096.0       533
# 580727.0   14096.0       529
# 578270.0   14096.0       442
# 573576.0   14096.0       435
# Name: CustomerID, dtype: int64

# %%
df.groupby('InvoiceNo')['CustomerID'].value_counts(dropna=False).nlargest()
# Out:
# InvoiceNo  CustomerID
# 573585.0   NaN           1114
# 581219.0   NaN            749
# 581492.0   NaN            731
# 580729.0   NaN            721
# 558475.0   NaN            705
# Name: CustomerID, dtype: int64

# %%
df.groupby('InvoiceNo')['CustomerID'].nunique(dropna=False).value_counts()
# Out:
# 1    25900
# Name: CustomerID, dtype: int64

# %%
df.groupby('InvoiceNo')['CustomerID'].nunique().value_counts()
# '0' for NaN values
# Out:
# 1    22190
# 0     3710
# Name: CustomerID, dtype: int64

# %%
df[df.InvoiceNo==576339].groupby([
    df.InvoiceDate, df.CustomerID.astype(str), df.Country
]).size()
# Out:
# InvoiceDate          CustomerID  Country
# 2011-11-14 15:27:00  14096.0     United Kingdom    542
# dtype: int64

# %%
df[df.InvoiceNo==573585].groupby([
    df.InvoiceDate, df.CustomerID.astype(str), df.Country
]).size()
# Out:
# InvoiceDate          CustomerID  Country
# 2011-10-31 14:41:00  nan         United Kingdom    1114
# dtype: int64

# %% [markdown]
# ### StockCode - Description

# %%
df.StockCode.nunique(), df.Description.nunique()
# The number of stockcode and description unique is expected to be the same
# Out:
# (4070, 4223)

# %%
df[['StockCode', 'Description']].isnull().sum()
# Out:
# StockCode         0
# Description    1454
# dtype: int64

# %%
df.groupby('StockCode')['Description'].nunique(dropna=False).value_counts()
# 1324 StockCode, has more than one description information (there are also descriptions with nan values)
# Out:
# 1    2746
# 2    1069
# 3     185
# 4      50
# 5      14
# 6       2
# 7       2
# 9       1
# 8       1
# Name: Description, dtype: int64

# %%
df.StockCode.map(type).value_counts()
# Out:
# <class 'float'>    482154
# <class 'str'>       54487
# Name: StockCode, dtype: int64

# %%
df.Description.map(type).value_counts()
# Out:
# <class 'str'>      535186
# <class 'float'>      1455
# Name: Description, dtype: int64

# %%
df[df.Description.map(type)==float].Description.unique()
# Out:
# array([nan, 20713.0], dtype=object)

# %%
df[df.Description==20713]
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 420391  572891.0   23343.0     20713.0    -400.0 2011-10-26 14:14:00
#
#         UnitPrice  CustomerID         Country
# 420391        0.0         NaN  United Kingdom

# %%
df[df.StockCode.map(type)==str]['StockCode'].unique()[:20]
# Out:
# array(['85123A', '84406B', '84029G', '84029E', 'POST', '82494L', '85099C',
#        '84997B', '84997C', '84519A', '85183B', '85071B', '37444A',
#        '37444C', '84971S', '15056BL', '15056N', 'D', '35004C', '85049A'],
#       dtype=object)

# %%
# SAMPLE
df[df.StockCode=='85123A'].groupby(df.Description).size()
# Out:
# Description
# ?                                        1
# CREAM HANGING HEART T-LIGHT HOLDER       9
# WHITE HANGING HEART T-LIGHT HOLDER    2290
# wrongly marked carton 22804              1
# dtype: int64

# %%
df[df.StockCode=='D'].groupby(df.Description).size()
# Out:
# Description
# Discount    77
# dtype: int64

# %%
df[df.StockCode=='POST'].groupby(df.Description).size()
# Out:
# Description
# POSTAGE    1252
# dtype: int64

# %%
df[df.StockCode==21866].groupby(df.Description).size()
# Out:
# Description
# UNION JACK FLAG LUGGAGE TAG    194
# dtype: int64

# %%
df[df.Description.isna()].head(3)
# Out:
#      InvoiceNo StockCode Description  Quantity         InvoiceDate  UnitPrice  \
# 622   536414.0   22139.0         NaN      56.0 2010-12-01 11:52:00        0.0
# 1970  536545.0   21134.0         NaN       1.0 2010-12-01 14:32:00        0.0
# 1971  536546.0   22145.0         NaN       1.0 2010-12-01 14:33:00        0.0
#
#       CustomerID         Country
# 622          NaN  United Kingdom
# 1970         NaN  United Kingdom
# 1971         NaN  United Kingdom

# %%
df[df.StockCode==22139]['Description'].unique()
# Out:
# array(['RETROSPOT TEA SET CERAMIC 11 PC ', nan, 'amazon'], dtype=object)

# %%
df[df.Description.isnull()].CustomerID.unique()
# CustomerIDs of rows with description information of NaN are also NaN.
# Out:
# array([nan])

# %%
# examining some examples for StockCode

# %%
df.StockCode.str.extract('^([A-Za-z]+)').value_counts()
# Out:
# POST         1256
# DOT           710
# M             566
# C             144
# D              77
# S              62
# BANK           37
# AMAZONFEE      34
# gift           34
# DCGS           21
# CRUK           16
# DCGSSGIRL      13
# DCGSSBOY       11
# PADS            4
# B               3
# m               1
# dtype: int64

# %%
df[df.StockCode=='D'].sample(5)
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 89282    C543840         D    Discount      -1.0 2011-02-14 11:19:00
# 320704   C565078         D    Discount      -1.0 2011-08-31 17:45:00
# 323492   C565313         D    Discount      -1.0 2011-09-02 12:41:00
# 300951   C563225         D    Discount      -1.0 2011-08-14 14:35:00
# 44405    C540171         D    Discount      -1.0 2011-01-05 12:26:00
#
#         UnitPrice  CustomerID         Country
# 89282       70.01     14527.0  United Kingdom
# 320704      57.60     16422.0  United Kingdom
# 323492      14.50     14527.0  United Kingdom
# 300951     434.51     14911.0            EIRE
# 44405       22.97     14527.0  United Kingdom

# %%
df[df.StockCode=='M'].sample(5)
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 414396   C572455         M      Manual      -1.0 2011-10-24 12:41:00
# 357724  568132.0         M      Manual       3.0 2011-09-23 16:22:00
# 144829  548820.0         M      Manual       1.0 2011-04-04 13:04:00
# 331033   C565962         M      Manual     -12.0 2011-09-08 11:25:00
# 21758    C538124         M      Manual      -4.0 2010-12-09 15:43:00
#
#         UnitPrice  CustomerID         Country
# 414396     265.70         NaN  United Kingdom
# 357724       1.25     15549.0  United Kingdom
# 144829    2053.07     12744.0       Singapore
# 331033       1.25     14410.0  United Kingdom
# 21758        0.50     15329.0  United Kingdom

# %%
df[df.StockCode=='C2'].sample(5)
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 263913  560041.0        C2    CARRIAGE       1.0 2011-07-14 14:46:00
# 508632  579256.0        C2    CARRIAGE       1.0 2011-11-29 08:07:00
# 89294   543899.0        C2    CARRIAGE       1.0 2011-02-14 12:11:00
# 153034  549721.0        C2    CARRIAGE       1.0 2011-04-11 15:35:00
# 500645  578792.0        C2    CARRIAGE       1.0 2011-11-25 12:20:00
#
#         UnitPrice  CustomerID         Country
# 263913       50.0     14156.0            EIRE
# 508632       50.0     13349.0  United Kingdom
# 89294        15.0         NaN            EIRE
# 153034       50.0     14911.0            EIRE
# 500645       50.0     14911.0            EIRE

# %%
df[df.StockCode=='AMAZONFEE'].sample(5)
# Out:
#        InvoiceNo  StockCode Description  Quantity         InvoiceDate  \
# 135534  547901.0  AMAZONFEE  AMAZON FEE       1.0 2011-03-28 11:57:00
# 43702    C540117  AMAZONFEE  AMAZON FEE      -1.0 2011-01-05 09:55:00
# 429248   C573549  AMAZONFEE  AMAZON FEE      -1.0 2011-10-31 13:23:00
# 239251   C558037  AMAZONFEE  AMAZON FEE      -1.0 2011-06-24 12:33:00
# 239250   C558036  AMAZONFEE  AMAZON FEE      -1.0 2011-06-24 12:31:00
#
#         UnitPrice  CustomerID         Country
# 135534     219.76         NaN  United Kingdom
# 43702    16888.02         NaN  United Kingdom
# 429248    5942.57         NaN  United Kingdom
# 239251    4534.24         NaN  United Kingdom
# 239250    5791.18         NaN  United Kingdom

# %% [markdown]
# ### Quantity - UnitPrice

# %%
df[['Quantity', 'UnitPrice']].describe().T
# Out:
#               count      mean         std       min   25%   50%    75%  \
# Quantity   536641.0  9.620029  219.130156 -80995.00  1.00  3.00  10.00
# UnitPrice  536641.0  4.632656   97.233118 -11062.06  1.25  2.08   4.13
#
#                max
# Quantity   80995.0
# UnitPrice  38970.0

# %%
df.Quantity.map(type).value_counts()
# Out:
# <class 'float'>    536641
# Name: Quantity, dtype: int64

# %%
df.UnitPrice.map(type).value_counts()
# Out:
# <class 'float'>    536641
# Name: UnitPrice, dtype: int64

# %% [markdown]
# ### CustomerID - Country

# %%
df.CustomerID.map(type).value_counts()
# Out:
# <class 'float'>    536641
# Name: CustomerID, dtype: int64

# %%
df.Country.map(type).value_counts()
# Out:
# <class 'str'>    536641
# Name: Country, dtype: int64

# %%
df[['CustomerID', 'Country']].isnull().sum()
# Out:
# CustomerID    135037
# Country            0
# dtype: int64

# %%
df.groupby(df.CustomerID.astype(str)).Country.nunique().value_counts()
# '1' refers to NaN values
# for some customers, two different country information has been entered.
# Out:
# 1    4364
# 2       8
# 9       1
# Name: Country, dtype: int64

# %%
df.groupby('Country')['CustomerID'].nunique(dropna=False).sort_values(ascending=False)[:10]
# How many customers from each country?
# Out:
# Country
# United Kingdom    3951
# Germany             95
# France              88
# Spain               31
# Belgium             25
# Switzerland         22
# Portugal            20
# Italy               15
# Finland             12
# Austria             11
# Name: CustomerID, dtype: int64

# %%
# Customers with two different country information
y = df.groupby('CustomerID').Country.nunique()
y[y.values>1].index
# Out:
# Float64Index([12370.0, 12394.0, 12417.0, 12422.0, 12429.0, 12431.0, 12455.0,
#               12457.0],
#              dtype='float64', name='CustomerID')

# %%
# SAMPLE
df[df.CustomerID==12457]['Country'].unique()
# Out:
# array(['Switzerland', 'Cyprus'], dtype=object)

# %% [markdown]
# ### InvoiceDate

# %%
df.InvoiceDate.map(type).value_counts()
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>    536641
# Name: InvoiceDate, dtype: int64

# %%
df.InvoiceDate.nunique()
# Out:
# 23260

# %%
# Do invoice numbers and invoice dates match?

df.groupby('InvoiceNo')['InvoiceDate'].value_counts().nlargest()
# Out:
# InvoiceNo  InvoiceDate
# 573585.0   2011-10-31 14:41:00    1114
# 581219.0   2011-12-08 09:28:00     749
# 581492.0   2011-12-09 10:03:00     731
# 580729.0   2011-12-05 17:24:00     721
# 558475.0   2011-06-29 15:58:00     705
# Name: InvoiceDate, dtype: int64

# %%
df.groupby('InvoiceNo')['InvoiceDate'].nunique().value_counts()
# 43 invoices have two different cut-off dates
# Out:
# 1    25857
# 2       43
# Name: InvoiceDate, dtype: int64

# %%
x = df.groupby('InvoiceNo')['InvoiceDate'].nunique()
x[x.values>1].index
# Out:
# Index([ 536591.0,  540185.0,  541596.0,  541631.0,  541809.0,  541816.0,
#         541849.0,  542217.0,  542806.0,  543171.0,  543179.0,  543182.0,
#         543777.0,  544186.0,  544667.0,  544926.0,  545460.0,  545713.0,
#         546388.0,  546986.0,  547690.0,  548203.0,  549245.0,  549524.0,
#         550320.0,  550333.0,  550641.0,  550645.0,  552000.0,  553199.0,
#         553375.0,  553556.0,  554116.0,  558086.0,  561369.0,  562128.0,
#         563245.0,  567183.0,  571735.0,  574076.0,  576057.0,  578548.0,
#        'C545569'],
#       dtype='object', name='InvoiceNo')

# %%
# SAMPLE
df[df.InvoiceNo==571735]
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 406109  571735.0   22086.0  PAPER CHAIN KIT 50'S CHRISTMAS       40.0
# 406110  571735.0   84879.0    ASSORTED COLOUR BIRD ORNAMENT      40.0
# 406111  571735.0   22456.0  NATURAL SLATE CHALKBOARD LARGE       18.0
# 406112  571735.0   22457.0  NATURAL SLATE HEART CHALKBOARD       48.0
# 406113  571735.0   22427.0          ENAMEL FLOWER JUG CREAM      12.0
# 406114  571735.0   22424.0           ENAMEL BREAD BIN CREAM       8.0
# 406115  571735.0   22425.0            ENAMEL COLANDER CREAM      16.0
# 406116  571735.0   22558.0  CLOTHES PEGS RETROSPOT PACK 24       48.0
# 406117  571735.0   22675.0   FRENCH KITCHEN SIGN BLUE METAL      12.0
# 406118  571735.0   22674.0    FRENCH TOILET SIGN BLUE METAL      12.0
# 406119  571735.0   22672.0  FRENCH BATHROOM SIGN BLUE METAL      12.0
# 406120  571735.0   22670.0        FRENCH WC SIGN BLUE METAL      12.0
# ...

# %% [markdown]
# ***

# %% [markdown]
# ### i. Take a look at relationships between InvoiceNo, Quantity and UnitPrice columns.

# %%
df[['Quantity', 'UnitPrice']].describe().T
# Out:
#               count      mean         std       min   25%   50%    75%  \
# Quantity   536641.0  9.620029  219.130156 -80995.00  1.00  3.00  10.00
# UnitPrice  536641.0  4.632656   97.233118 -11062.06  1.25  2.08   4.13
#
#                max
# Quantity   80995.0
# UnitPrice  38970.0

# %%
# SAMPLE
df[df.InvoiceNo==536390]
# there are orders for different items and different quantities (of the same customer) for one invoice
# Out:
#     InvoiceNo StockCode                          Description  Quantity  \
# 211  536390.0   22941.0         CHRISTMAS LIGHTS 10 REINDEER       2.0
# 212  536390.0   22960.0             JAM MAKING SET WITH JARS      12.0
# 213  536390.0   22961.0               JAM MAKING SET PRINTED      12.0
# 214  536390.0   22962.0                JAM JAR WITH PINK LID      48.0
# 215  536390.0   22963.0               JAM JAR WITH GREEN LID      48.0
# 216  536390.0   22968.0           ROSE COTTAGE KEEPSAKE BOX        8.0
# 217  536390.0    84970S    HANGING HEART ZINC T-LIGHT HOLDER     144.0
# 218  536390.0   22910.0    PAPER CHAIN KIT VINTAGE CHRISTMAS      40.0
# 219  536390.0   20668.0      DISCO BALL CHRISTMAS DECORATION     288.0
# 220  536390.0    85123A   WHITE HANGING HEART T-LIGHT HOLDER      64.0
# 221  536390.0   22197.0                 SMALL POPCORN HOLDER     100.0
# 222  536390.0   22198.0                LARGE POPCORN HOLDER       50.0
# ...

# %%
df.groupby('InvoiceNo')[['Quantity', 'UnitPrice']].agg({'Quantity': ['count', sum, np.mean],
                                                                     'UnitPrice': [sum]}).sample(5)
# Out:
#           Quantity                   UnitPrice
#              count    sum       mean       sum
# InvoiceNo
# 547246.0        10  276.0  27.600000     24.60
# 538178.0         6   82.0  13.666667     17.62
# 576677.0        29  143.0   4.931034     58.91
# C542593          1  -10.0 -10.000000      3.75
# 544888.0        19  117.0   6.157895     80.35

# %%
df[df.Quantity==0].shape[0]
# Out:
# 0

# %%
df[df.UnitPrice==0].shape[0]
# Out:
# 2510

# %%
df[df['UnitPrice']==0].sample(5)
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 150595  549456.0    47341A         NaN      -6.0 2011-04-08 14:19:00
# 115813  546147.0   21320.0      broken     -63.0 2011-03-09 16:42:00
# 521333  580359.0   20775.0         NaN     -35.0 2011-12-02 16:11:00
# 478929  577116.0   21165.0       check     -28.0 2011-11-17 18:04:00
# 96374   544554.0   22588.0         NaN     -41.0 2011-02-21 12:12:00
#
#         UnitPrice  CustomerID         Country
# 150595        0.0         NaN  United Kingdom
# 115813        0.0         NaN  United Kingdom
# 521333        0.0         NaN  United Kingdom
# 478929        0.0         NaN  United Kingdom
# 96374         0.0         NaN  United Kingdom

# %%
df[df['UnitPrice']==0]['CustomerID'].unique()
# Out:
# array([   nan, 12647., 16560., 14911., 13081., 15107., 17560., 13239.,
#        13113., 14410., 12457., 17667., 12415., 16818., 12507., 15581.,
#        14646., 16133., 12748., 15804., 12446., 18059., 14110., 12437.,
#        12431., 13014., 13985., 15602., 12603., 12444., 16406., 13256.])

# %% [markdown]
# ***We see that there are negative values in the Quantity and UnitPrice columns. These are possibly canceled and returned orders. Let's check it out.***

# %%
# Negative values in UnitPrice

# %%
df[df.UnitPrice<0]
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 299983   A563186         B  Adjust bad debt       1.0 2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt       1.0 2011-08-12 14:52:00
#
#         UnitPrice  CustomerID         Country
# 299983  -11062.06         NaN  United Kingdom
# 299984  -11062.06         NaN  United Kingdom

# %%
df.iloc[299970:299990]
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 302323  563426.0   23306.0      SET OF 36 DOILIES PANTRY DESIGN      12.0
# 302324  563427.0   17003.0                  BROCADE RING PURSE        6.0
# 302325  563427.0   20777.0               CHRYSANTHEMUM NOTEBOOK       1.0
# 302326  563427.0   22560.0           TRADITIONAL MODELLING CLAY       3.0
# 302327  563427.0   22491.0          PACK OF 12 COLOURED PENCILS       3.0
# 302328  563427.0   22544.0                 MINI JIGSAW SPACEBOY       4.0
# 302329  563427.0   22559.0                  SEASIDE FLYING DISC       2.0
# 302330  563427.0   22545.0                  MINI JIGSAW BUNNIES       4.0
# 302331  563427.0   20658.0            RED RETROSPOT LUGGAGE TAG       3.0
# 302332  563427.0   22278.0   OVERNIGHT BAG VINTAGE ROSE PAISLEY       6.0
# 302333  563427.0   20665.0                 RED RETROSPOT PURSE        3.0
# 302334  563427.0   22629.0                  SPACEBOY LUNCH BOX        2.0
# ...

# %%
# Negative Values in Quantity

# %%
df[df.Quantity<0].shape[0]
# Out:
# 10587

# %%
df[df.Quantity<0].head()
# Out:
#     InvoiceNo StockCode                       Description  Quantity  \
# 141   C536379         D                          Discount      -1.0
# 154   C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS      -1.0
# 235   C536391   22556.0    PLASTERS IN TIN CIRCUS PARADE      -12.0
# 236   C536391   21984.0  PACK OF 12 PINK PAISLEY TISSUES      -24.0
# 237   C536391   21983.0  PACK OF 12 BLUE PAISLEY TISSUES      -24.0
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 141 2010-12-01 09:41:00      27.50     14527.0  United Kingdom
# 154 2010-12-01 09:49:00       4.65     15311.0  United Kingdom
# 235 2010-12-01 10:24:00       1.65     17548.0  United Kingdom
# 236 2010-12-01 10:24:00       0.29     17548.0  United Kingdom
# 237 2010-12-01 10:24:00       0.29     17548.0  United Kingdom

# %%
print(df[df.InvoiceNo.str.contains('C', na=False) & (df['Quantity'] < 0)].shape[0])
df[df.InvoiceNo.str.contains('C', na=False) & (df['Quantity'] < 0)].sample(5)
# All Invoice Numbers starting with 'C' have a negative value of quantity
# Out:
# 9251
#        InvoiceNo StockCode                      Description  Quantity  \
# 198055   C554006   22284.0             HEN HOUSE DECORATION     -12.0
# 112062   C545866   21424.0      WOODLAND STORAGE BOX LARGE       -1.0
# 37738    C539476   22138.0    BAKING SET 9 PIECE RETROSPOT       -1.0
# 88802    C543818   22622.0   BOX OF VINTAGE ALPHABET BLOCKS      -2.0
# 238569   C557941   22900.0  SET 2 TEA TOWELS I LOVE LONDON     -160.0
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 198055 2011-05-20 12:25:00       1.65     13418.0  United Kingdom
# 112062 2011-03-07 14:27:00       2.95     17841.0  United Kingdom
# 37738  2010-12-19 14:43:00       4.95     16686.0  United Kingdom
# 88802  2011-02-13 15:45:00       9.95     16897.0  United Kingdom
# 238569 2011-06-23 16:00:00       2.32     12901.0  United Kingdom

# %%
print(df[~df.InvoiceNo.str.contains('C', na=False) & (df['Quantity'] < 0)].shape[0])
df[~df.InvoiceNo.str.contains('C', na=False) & (df['Quantity'] < 0)].sample(5)
# Apart from Invoice Numbers starting with 'C', there are also negative quantities
# Out:
# 1336
#        InvoiceNo StockCode         Description  Quantity         InvoiceDate  \
# 432117  573815.0   20902.0               check      -3.0 2011-11-01 11:31:00
# 456796  575717.0   85175.0               check     -42.0 2011-11-10 18:02:00
# 139595  548328.0   21527.0                 NaN     -21.0 2011-03-30 13:11:00
# 173271  551672.0   84631.0                 NaN      -4.0 2011-05-03 12:39:00
# 323389  565296.0   84929.0  code mix up? 84930    -967.0 2011-09-02 12:04:00
#
#         UnitPrice  CustomerID         Country
# 432117        0.0         NaN  United Kingdom
# 456796        0.0         NaN  United Kingdom
# 139595        0.0         NaN  United Kingdom
# 173271        0.0         NaN  United Kingdom
# 323389        0.0         NaN  United Kingdom

# %% [markdown]
# ### ii. What does the letter "C" in the InvoiceNo column mean?

# %%
df[df.Quantity<0].head()
# Out:
#     InvoiceNo StockCode                       Description  Quantity  \
# 141   C536379         D                          Discount      -1.0
# 154   C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS      -1.0
# 235   C536391   22556.0    PLASTERS IN TIN CIRCUS PARADE      -12.0
# 236   C536391   21984.0  PACK OF 12 PINK PAISLEY TISSUES      -24.0
# 237   C536391   21983.0  PACK OF 12 BLUE PAISLEY TISSUES      -24.0
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 141 2010-12-01 09:41:00      27.50     14527.0  United Kingdom
# 154 2010-12-01 09:49:00       4.65     15311.0  United Kingdom
# 235 2010-12-01 10:24:00       1.65     17548.0  United Kingdom
# 236 2010-12-01 10:24:00       0.29     17548.0  United Kingdom
# 237 2010-12-01 10:24:00       0.29     17548.0  United Kingdom

# %%
# SAMPLE
df[df.CustomerID==17548]
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 235      C536391   22556.0     PLASTERS IN TIN CIRCUS PARADE      -12.0
# 236      C536391   21984.0   PACK OF 12 PINK PAISLEY TISSUES      -24.0
# 237      C536391   21983.0   PACK OF 12 BLUE PAISLEY TISSUES      -24.0
# 238      C536391   21980.0  PACK OF 12 RED RETROSPOT TISSUES      -24.0
# 239      C536391   21484.0        CHICK GREY HOT WATER BOTTLE     -12.0
# 240      C536391   22557.0   PLASTERS IN TIN VINTAGE PAISLEY      -12.0
# 241      C536391   22553.0             PLASTERS IN TIN SKULLS     -24.0
# 165024  550755.0   22585.0          PACK OF 6 BIRDY GIFT TAGS      24.0
# 165025  550755.0   22082.0        RIBBON REEL STRIPES DESIGN       10.0
# 165026  550755.0   22081.0         RIBBON REEL FLORA + FAUNA       10.0
# 165027  550755.0   22079.0         RIBBON REEL HEARTS DESIGN       10.0
# 165028  550755.0   22926.0     IVORY GIANT GARDEN THERMOMETER       4.0
# ...

# %% [markdown]
# ***If the invoice number starts with the letter "C", it means the order was cancelled. Or those who abandon their order.***

# %%
df.InvoiceNo.str.contains('C').value_counts()
# Out:
# True     9251
# False       3
# Name: InvoiceNo, dtype: int64

# %%
df[(df.Quantity<0) & (df.InvoiceNo.str.startswith('C')==True)].shape[0]
# Out:
# 9251

# %% [markdown]
# ***When we filter canceled orders by Quantity> 0 or filter non-canceled orders by Quantity <0 nothing returns, this confirms that negative values mean the order was canceled. So lets find out how many orders were cancelled?***

# %%
df[(df.Quantity>0) & (df.InvoiceNo.str.startswith('C')==True)].shape[0]
# No InvoiceNo that starts with 'C' and has a positive quantity value
# Out:
# 0

# %%
# There are also quantity values whose InvoiceNo does not start with 'C' but is negative.
df[(df.Quantity<0) & (df.InvoiceNo.map(type)==float)].shape[0]
# Out:
# 1336

# %% [markdown]
# #### 9288 or about 36% of the orders were cancelled. Looking deeper into why these orders were cancelled may prevent future cancellations. Now let's find out what a negative UnitPrice means.

# %%
df[df.UnitPrice<0]
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 299983   A563186         B  Adjust bad debt       1.0 2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt       1.0 2011-08-12 14:52:00
#
#         UnitPrice  CustomerID         Country
# 299983  -11062.06         NaN  United Kingdom
# 299984  -11062.06         NaN  United Kingdom

# %%
df[df.InvoiceNo.str.contains('A')==True]
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 299982   A563185         B  Adjust bad debt       1.0 2011-08-12 14:50:00
# 299983   A563186         B  Adjust bad debt       1.0 2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt       1.0 2011-08-12 14:52:00
#
#         UnitPrice  CustomerID         Country
# 299982   11062.06         NaN  United Kingdom
# 299983  -11062.06         NaN  United Kingdom
# 299984  -11062.06         NaN  United Kingdom

# %%
df[(df.Quantity<0) & (df.InvoiceNo.str.startswith('C')==True)].shape[0]
# Out:
# 9251

# %%
df[df['InvoiceNo'].str.startswith('C')==True]['CustomerID'].nunique() / df['CustomerID'].nunique()
# percentage of orders that are cancelled
# Out:
# 0.3634492223238792

# %% [markdown]
# ### iii. Handling Missing Values

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135037
# Country             0
# dtype: int64

# %% [markdown]
# ***Since the customer ID's are missing, lets assume these orders were not made by the customers already in the data set because those customers already have ID's.***
#
# ***We also don't want to assign these orders to those customers because this would alter the insights we draw from the data.***

# %%
df.groupby('InvoiceNo')['CustomerID'].nunique().value_counts()
# Out:
# 1    22190
# 0     3710
# Name: CustomerID, dtype: int64

# %%
df[df.Description.isna()]['CustomerID'].unique()
# Out:
# array([nan])

# %%
# df['CustomerID'] = df['CustomerID'].astype(str)

# %% [markdown]
# ### iv. Clean the Data from the Noise and Missing Values

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df = df[(df.UnitPrice > 0) & (df.Quantity > 0)].reset_index(drop=True)

# %%
df.shape
# Out:
# (392692, 8)

# %% [markdown]
# ### v. Explore the Orders

# %% [markdown]
# ***1. Find the unique number of InvoiceNo  per customer***

# %%
df.InvoiceNo.nunique(), df.CustomerID.nunique()
# Out:
# (18532, 4338)

# %%
df.groupby('CustomerID')['InvoiceNo'].nunique().nlargest(10)
# Out:
# CustomerID
# 12748.0    209
# 14911.0    201
# 17841.0    124
# 13089.0     97
# 14606.0     93
# 15311.0     91
# 12971.0     86
# 14646.0     73
# 16029.0     63
# 13408.0     62
# Name: InvoiceNo, dtype: int64

# %% [markdown]
# ***2. What's the average number of unique items per order or per customer?***

# %%
df.InvoiceNo.nunique(), df.CustomerID.nunique()
# Out:
# (18532, 4338)

# %%
df.groupby('InvoiceNo')['StockCode'].nunique().nlargest()
# Out:
# InvoiceNo
# 576339.0    541
# 579196.0    529
# 580727.0    525
# 578270.0    439
# 573576.0    434
# Name: StockCode, dtype: int64

# %%
df.groupby('InvoiceNo')['StockCode'].nunique().mean().round()
# Out:
# 21.0

# %%
df.groupby('CustomerID')['StockCode'].nunique().nlargest()
# Out:
# CustomerID
# 14911.0    1787
# 12748.0    1768
# 17841.0    1323
# 14096.0    1119
# 14298.0     884
# Name: StockCode, dtype: int64

# %%
df.groupby('CustomerID')['StockCode'].nunique().mean().round()
# Out:
# 62.0

# %%
df.groupby(['StockCode','Description'])['Quantity'].mean().sort_values(ascending=False)
# Out:
# StockCode  Description
# 23843.0    PAPER CRAFT , LITTLE BIRDIE            80995.000000
# 47556B     TEA TIME TEA TOWELS                     1300.000000
# 84568.0    GIRLS ALPHABET IRON ON PATCHES           480.000000
# 23166.0    MEDIUM CERAMIC TOP STORAGE JAR           393.515152
# 18007.0    ESSENTIAL BALM 3.5g TIN IN ENVELOPE      325.333333
#                                                       ...
# 90189A     SILVER 2 STRAND NECKLACE-LEAF CHARM        1.000000
# 23366.0    SET 12 COLOURING PENCILS DOILEY            1.000000
# 90026D     GLASS BEAD HOOP NECKLACE AMETHYST          1.000000
# 23444.0    Next Day Carriage                          1.000000
# 23574.0    PACKING CHARGE                             1.000000
# Name: Quantity, Length: 3897, dtype: float64

# %% [markdown]
# ***3. Let's see how this compares to the number of unique products per customer.***

# %%
df.groupby('CustomerID').StockCode.nunique().sort_values(ascending=False)
# Out:
# CustomerID
# 14911.0    1787
# 12748.0    1768
# 17841.0    1323
# 14096.0    1119
# 14298.0     884
#            ...
# 15389.0       1
# 18174.0       1
# 12823.0       1
# 14576.0       1
# 12346.0       1
# Name: StockCode, Length: 4338, dtype: int64

# %% [markdown]
# ### vi. Explore Customers by Country

# %% [markdown]
# ***1. What's the total revenue per country?***

# %%
total_price = df.Quantity * df.UnitPrice

# %%
df.insert(6, 'TotalPrice', total_price)

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0  536365.0    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1  536365.0   71053.0                  WHITE METAL LANTERN       6.0
# 2  536365.0    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3  536365.0    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4  536365.0    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
#
#           InvoiceDate  UnitPrice  TotalPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55       15.30     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39       20.34     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75       22.00     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39       20.34     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39       20.34     17850.0  United Kingdom

# %%
df.Country.unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Finland',
#        'Austria', 'Greece', 'Singapore', 'Lebanon',
#        'United Arab Emirates', 'Israel', 'Saudi Arabia', 'Czech Republic',
#        'Canada', 'Unspecified', 'Brazil', 'USA', 'European Community',
#        'Bahrain', 'Malta', 'RSA'], dtype=object)

# %%
df.groupby('Country')['TotalPrice'].sum().sort_values(ascending=False)
# Out:
# Country
# United Kingdom          7285024.644
# Netherlands              285446.340
# EIRE                     265262.460
# Germany                  228678.400
# France                   208934.310
# Australia                138453.810
# Spain                     61558.560
# Switzerland               56443.950
# Belgium                   41196.340
# Sweden                    38367.830
# Japan                     37416.370
# Norway                    36165.440
# Portugal                  33375.840
# Finland                   22546.080
# Singapore                 21279.290
# Channel Islands           20440.540
# Denmark                   18955.340
# Italy                     17483.240
# Cyprus                    13502.850
# Austria                   10198.680
# Poland                     7334.650
# Israel                     7215.840
# Greece                     4760.520
# Iceland                    4310.000
# Canada                     3666.380
# USA                        3580.390
# ...

# %% [markdown]
# ***2. Visualize number of customer per country***

# %%
df.CustomerID.nunique()
# Out:
# 4338

# %%
df.groupby('CustomerID').Country.nunique().value_counts()
# two different country information available for 8 customers
# Out:
# 1    4330
# 2       8
# Name: Country, dtype: int64

# %%
y = df.groupby('CustomerID').Country.nunique()
y[y.values>1].index
# Out:
# Float64Index([12370.0, 12394.0, 12417.0, 12422.0, 12429.0, 12431.0, 12455.0,
#               12457.0],
#              dtype='float64', name='CustomerID')

# %%
# SAMPLE
df[df.CustomerID==12457]['Country'].unique()
# Out:
# array(['Switzerland', 'Cyprus'], dtype=object)

# %%
df.groupby('Country')['CustomerID'].nunique().sort_values(ascending=False)
# Out:
# Country
# United Kingdom          3920
# Germany                   94
# France                    87
# Spain                     30
# Belgium                   25
# Switzerland               21
# Portugal                  19
# Italy                     14
# Finland                   12
# Austria                   11
# Norway                    10
# Netherlands                9
# Australia                  9
# Denmark                    9
# Channel Islands            9
# Cyprus                     8
# Sweden                     8
# Japan                      8
# Poland                     6
# USA                        4
# Canada                     4
# Unspecified                4
# Greece                     4
# EIRE                       3
# Israel                     3
# Malta                      2
# United Arab Emirates       2
# Bahrain                    2
# Czech Republic             1
# Lithuania                  1
# Lebanon                    1
# ...

# %%
# except United Kingdom
df.groupby('Country')['CustomerID'].nunique().sort_values(ascending=False)[1:].plot(kind='bar', figsize=(16,6))
# Out:
# <AxesSubplot:xlabel='Country'>

# %% [markdown]
# ***3. Visualize total cost per country***

# %%
df.groupby('Country')['TotalPrice'].sum().sort_values(ascending=False)
# Out:
# Country
# United Kingdom          7285024.644
# Netherlands              285446.340
# EIRE                     265262.460
# Germany                  228678.400
# France                   208934.310
# Australia                138453.810
# Spain                     61558.560
# Switzerland               56443.950
# Belgium                   41196.340
# Sweden                    38367.830
# Japan                     37416.370
# Norway                    36165.440
# Portugal                  33375.840
# Finland                   22546.080
# Singapore                 21279.290
# Channel Islands           20440.540
# Denmark                   18955.340
# Italy                     17483.240
# Cyprus                    13502.850
# Austria                   10198.680
# Poland                     7334.650
# Israel                     7215.840
# Greece                     4760.520
# Iceland                    4310.000
# Canada                     3666.380
# USA                        3580.390
# ...

# %%
# except United Kingdom
df.groupby('Country')['TotalPrice'].sum().sort_values(ascending=False)[1:].plot(kind='bar', figsize=(16,6))
# Out:
# <AxesSubplot:xlabel='Country'>

# %% [markdown]
# #### The UK not only has the most sales revenue, but also the most customers. Since the majority of this data set contains orders from the UK, we can explore the UK market further by finding out what products the customers buy together and any other buying behaviors to improve our sales and targeting strategy.

# %%
df.groupby('Country')['CustomerID'].nunique().nlargest(7)
# Out:
# Country
# United Kingdom    3920
# Germany             94
# France              87
# Spain               30
# Belgium             25
# Switzerland         21
# Portugal            19
# Name: CustomerID, dtype: int64

# %%
df.groupby('Country')['TotalPrice'].sum().nlargest(7)
# Out:
# Country
# United Kingdom    7285024.644
# Netherlands        285446.340
# EIRE               265262.460
# Germany            228678.400
# France             208934.310
# Australia          138453.810
# Spain               61558.560
# Name: TotalPrice, dtype: float64

# %%
df.groupby('Country')['InvoiceNo'].nunique().nlargest(7)
# Out:
# Country
# United Kingdom    16646
# Germany             457
# France              389
# EIRE                260
# Belgium              98
# Netherlands          94
# Spain                90
# Name: InvoiceNo, dtype: int64

# %% [markdown]
# ### vii. Explore the UK Market

# %% [markdown]
# ***1. Create df_uk DataFrame***

# %%
df_uk = df[df.Country=='United Kingdom'].drop('Country', axis=1).reset_index(drop=True)

# %%
print(df_uk.shape)
df_uk.head()
# Out:
# (349203, 8)
#   InvoiceNo StockCode                          Description  Quantity  \
# 0  536365.0    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1  536365.0   71053.0                  WHITE METAL LANTERN       6.0
# 2  536365.0    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3  536365.0    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4  536365.0    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
#
#           InvoiceDate  UnitPrice  TotalPrice  CustomerID
# 0 2010-12-01 08:26:00       2.55       15.30     17850.0
# 1 2010-12-01 08:26:00       3.39       20.34     17850.0
# 2 2010-12-01 08:26:00       2.75       22.00     17850.0
# 3 2010-12-01 08:26:00       3.39       20.34     17850.0
# 4 2010-12-01 08:26:00       3.39       20.34     17850.0

# %% [markdown]
# ***2. What are the most popular products that are bought in the UK?***

# %%
# by quantity
df_uk.groupby('StockCode').Quantity.sum().nlargest(10)
# Out:
# StockCode
# 23843.0    80995.0
# 23166.0    76919.0
# 84077.0    49086.0
# 22197.0    45609.0
# 85099B     41878.0
# 85123A     34687.0
# 84879.0    32628.0
# 22616.0    24321.0
# 17003.0    22675.0
# 21212.0    22442.0
# Name: Quantity, dtype: float64

# %%
# by total amount
df_uk.groupby('StockCode').TotalPrice.sum().nlargest(10)
# Out:
# StockCode
# 23843.0    168469.60
# 22423.0    110713.00
# 85123A      94960.85
# 23166.0     80291.44
# 85099B      77191.33
# 47566.0     63050.28
# 84879.0     52228.68
# 22502.0     46520.45
# 79321.0     45483.91
# 22086.0     40392.08
# Name: TotalPrice, dtype: float64

# %%
# df_uk.to_csv('Online Retail UK.csv', index=False)

# %% [markdown]
# ### We will continue analyzing the UK transactions with customer segmentation.

# %% [markdown]
# # 2. RFM Analysis

# %% [markdown]
# In the age of the internet and e-commerce, companies that do not expand their businesses online or utilize digital tools to reach their customers will run into issues like scalability and a lack of digital precsence. An important marketing strategy e-commerce businesses use for analyzing and predicting customer value is customer segmentation. Customer data is used to sort customers into group based on their behaviors and preferences.
#
# **[RFM](https://www.putler.com/rfm-analysis/) (Recency, Frequency, Monetary) Analysis** is a customer segmentation technique for analyzing customer value based on past buying behavior. RFM analysis was first used by the direct mail industry more than four decades ago, yet it is still an effective way to optimize your marketing.
# <br>
# <br>
# Our goal in this Notebook is to cluster the customers in our data set to:
#  - Recognize who are our most valuable customers
#  - Increase revenue
#  - Increase customer retention
#  - Learn more about the trends and behaviors of our customers
#  - Define customers that are at risk
#
# We will start with **RFM Analysis** and then compliment our findings with predictive analysis using **K-Means Clustering Algorithms.**
#
# - RECENCY (R): Time since last purchase
# - FREQUENCY (F): Total number of purchases
# - MONETARY VALUE (M): Total monetary value
#
#
#
#
# Benefits of RFM Analysis
#
# - Increased customer retention
# - Increased response rate
# - Increased conversion rate
# - Increased revenue
#
# RFM Analysis answers the following questions:
#  - Who are our best customers?
#  - Who has the potential to be converted into more profitable customers?
#  - Which customers do we need to retain?
#  - Which group of customers is most likely to respond to our marketing campaign?

# %% [markdown]
# ### i. Import Libraries

# %%
import datetime as dt
from datetime import datetime

# %% [markdown]
# ### ii. Review df_uk DataFrame

# %%
df_uk.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0  536365.0    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1  536365.0   71053.0                  WHITE METAL LANTERN       6.0
# 2  536365.0    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3  536365.0    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4  536365.0    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
#
#           InvoiceDate  UnitPrice  TotalPrice  CustomerID
# 0 2010-12-01 08:26:00       2.55       15.30     17850.0
# 1 2010-12-01 08:26:00       3.39       20.34     17850.0
# 2 2010-12-01 08:26:00       2.75       22.00     17850.0
# 3 2010-12-01 08:26:00       3.39       20.34     17850.0
# 4 2010-12-01 08:26:00       3.39       20.34     17850.0

# %%
df_uk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 349203 entries, 0 to 349202
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    349203 non-null  object
#  1   StockCode    349203 non-null  object
#  2   Description  349203 non-null  object
#  3   Quantity     349203 non-null  float64
#  4   InvoiceDate  349203 non-null  datetime64[ns]
#  5   UnitPrice    349203 non-null  float64
#  6   TotalPrice   349203 non-null  float64
#  7   CustomerID   349203 non-null  float64
# dtypes: datetime64[ns](1), float64(4), object(3)
# memory usage: 21.3+ MB

# %%
df_uk.shape, df_uk.size
# Out:
# ((349203, 8), 2793624)

# %%
df_uk.isnull().sum().any()
# Out:
# False

# %%
pd.DataFrame([{'Customers': df_uk['CustomerID'].nunique(),
               'Products': df_uk['StockCode'].nunique(),
               'Transactions': df_uk['InvoiceNo'].nunique()
              }], index=['Quantity'])
# Out:
#           Customers  Products  Transactions
# Quantity       3920      3645         16646

# %%
# top 20 most purchased products
df_uk.StockCode.value_counts().head(20).plot(kind='bar', color='purple', edgecolor='black', figsize=(16,6))
# Out:
# <AxesSubplot:>

# %%
# top 20 most demanded products by quantity
df_uk.groupby('StockCode').Quantity.sum().nlargest(20).plot(kind='bar', color='purple', edgecolor='black', figsize=(16,6))
# Out:
# <AxesSubplot:xlabel='StockCode'>

# %%
# top 20 most paid products
df_uk.groupby('StockCode').TotalPrice.sum().nlargest(20).plot(kind='bar', color='purple', edgecolor='black', figsize=(16,6))
# Out:
# <AxesSubplot:xlabel='StockCode'>

# %% [markdown]
# ### iii. Recency: Days since last purchase
# To calculate the recency values, follow these steps in order:
#
# 1. To calculate recency, we need to choose a date as a point of reference to evaluate how many days ago was the customer's last purchase.
# 2. Create a new column called Date which contains the invoice date without the timestamp
# 3. Group by CustomerID and check the last date of purchase
# 4. Calculate the days since last purchase
# 5. Drop Last_Purchase_Date since we don't need it anymore
# 6. Plot RFM distributions

# %% [markdown]
# ***1. Choose a date as a point of reference to evaluate how many days ago was the customer's last purchase.***

# %%
print('First InvoiceDate :', df_uk['InvoiceDate'].min(), '\nLast InvoiceDate  :', df_uk['InvoiceDate'].max())
# Out:
# First InvoiceDate : 2010-12-01 08:26:00
# Last InvoiceDate  : 2011-12-09 12:49:00

# %%
reference_date = dt.date(2011,12,10)  #one day after last invoice date
reference_date
# Out:
# datetime.date(2011, 12, 10)

# %% [markdown]
# ***2. Create a new column called Date which contains the invoice date without the timestamp***

# %%
df_uk['InvoiceDate'].dtype.type
# Out:
# numpy.datetime64

# %%
df_uk['Date'] = df_uk.InvoiceDate.dt.date

# %%
df_uk.sample(5)
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 313893  577696.0   23301.0  GARDENERS KNEELING PAD KEEP CALM        2.0
# 193354  564304.0   21115.0              ROSE CARAVAN DOORSTOP       1.0
# 69991   546784.0   23052.0    RECYCLED ACAPULCO MAT TURQUOISE       2.0
# 117752  553540.0   23301.0  GARDENERS KNEELING PAD KEEP CALM       48.0
# 205534  566094.0   20679.0              EDWARDIAN PARASOL RED       1.0
#
#                InvoiceDate  UnitPrice  TotalPrice  CustomerID        Date
# 313893 2011-11-21 11:57:00       1.65        3.30     16406.0  2011-11-21
# 193354 2011-08-24 12:11:00       6.75        6.75     14527.0  2011-08-24
# 69991  2011-03-17 09:49:00       8.25       16.50     18189.0  2011-03-17
# 117752 2011-05-17 15:32:00       1.45       69.60     17511.0  2011-05-17
# 205534 2011-09-09 10:42:00       5.95        5.95     17965.0  2011-09-09

# %%
df_uk['Date'].dtype.type
# Out:
# numpy.object_

# %% [markdown]
# ***3. Group by CustomerID and check the last date of purchase***

# %%
df_uk['Last_Purchase_Date'] = df_uk.groupby('CustomerID')['Date'].transform(max) 
df_uk.sample(5)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 36602   541997.0   21868.0                 POTTING SHED TEA MUG      12.0
# 282409  574514.0   16008.0  SMALL FOLDING SCISSOR(POINTED EDGE)      12.0
# 122948  554163.0   82578.0                   KITCHEN METAL SIGN       2.0
# 155739  559200.0   85202.0          HANGING WOOD AND FELT HEART       6.0
# 260846  572188.0   22112.0           CHOCOLATE HOT WATER BOTTLE      48.0
#
#                InvoiceDate  UnitPrice  TotalPrice  CustomerID        Date  \
# 36602  2011-01-25 10:38:00       1.25       15.00     18077.0  2011-01-25
# 282409 2011-11-04 13:34:00       0.12        1.44     15311.0  2011-11-04
# 122948 2011-05-23 11:52:00       0.55        1.10     14573.0  2011-05-23
# 155739 2011-07-07 10:36:00       0.42        2.52     13291.0  2011-07-07
# 260846 2011-10-21 11:06:00       4.25      204.00     14967.0  2011-10-21
#
#        Last_Purchase_Date
# 36602          2011-12-01
# ...

# %% [markdown]
# ***4. Calculate the days since last purchase***

# %%
df_uk['Recency'] = (reference_date - df_uk['Last_Purchase_Date']).dt.days

# %%
df_uk.sample(5)
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 78656   547890.0   22094.0          RED RETROSPOT TISSUE BOX       1.0
# 224092  568164.0   23265.0  SET OF 3 WOODEN TREE DECORATIONS      12.0
# 5425    537135.0   22732.0    3D VINTAGE CHRISTMAS STICKERS        6.0
# 288558  575040.0   22730.0        ALARM CLOCK BAKELIKE IVORY       4.0
# 224835  568193.0   22414.0      DOORMAT NEIGHBOURHOOD WITCH       10.0
#
#                InvoiceDate  UnitPrice  TotalPrice  CustomerID        Date  \
# 78656  2011-03-28 10:03:00       1.25        1.25     17227.0  2011-03-28
# 224092 2011-09-25 12:39:00       1.25       15.00     14561.0  2011-09-25
# 5425   2010-12-05 12:35:00       1.25        7.50     17059.0  2010-12-05
# 288558 2011-11-08 11:58:00       3.75       15.00     13381.0  2011-11-08
# 224835 2011-09-25 14:37:00       7.08       70.80     17107.0  2011-09-25
#
#        Last_Purchase_Date  Recency
# 78656          2011-11-21       19
# ...

# %% [markdown]
# ***5. Drop Last_Purchase_Date since we don't need it anymore***

# %%
del df_uk['Last_Purchase_Date']

# %%
df_uk.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0  536365.0    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1  536365.0   71053.0                  WHITE METAL LANTERN       6.0
# 2  536365.0    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3  536365.0    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4  536365.0    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
#
#           InvoiceDate  UnitPrice  TotalPrice  CustomerID        Date  Recency
# 0 2010-12-01 08:26:00       2.55       15.30     17850.0  2010-12-01      373
# 1 2010-12-01 08:26:00       3.39       20.34     17850.0  2010-12-01      373
# 2 2010-12-01 08:26:00       2.75       22.00     17850.0  2010-12-01      373
# 3 2010-12-01 08:26:00       3.39       20.34     17850.0  2010-12-01      373
# 4 2010-12-01 08:26:00       3.39       20.34     17850.0  2010-12-01      373

# %% [markdown]
# ***6. Plot RFM distributions***

# %%
cus_recency = df_uk.groupby('CustomerID', as_index=False, sort=False).Recency.mean().astype('int64')
cus_recency.reset_index(drop=True, inplace=True)

# %%
print(cus_recency.shape)
cus_recency.head()
# Out:
# (3920, 2)
#    CustomerID  Recency
# 0       17850      373
# 1       13047       32
# 2       13748       96
# 3       15100      334
# 4       15291       26

# %%
cus_recency.Recency.describe()
# Out:
# count    3920.000000
# mean       92.742092
# std        99.533485
# min         1.000000
# 25%        18.000000
# 50%        51.000000
# 75%       143.000000
# max       374.000000
# Name: Recency, dtype: float64

# %%
plt.figure(figsize=(12,6))
sns.histplot(cus_recency.Recency, bins=50)
# Out:
# <AxesSubplot:xlabel='Recency', ylabel='Count'>

# %%
plt.figure(figsize=(12,6))
sns.boxplot(cus_recency.Recency)
# Out:
# <AxesSubplot:xlabel='Recency'>

# %% [markdown]
# ### iv. Frequency: Number of purchases
#
# To calculate how many times a customer purchased something, we need to count how many invoices each customer has. To calculate the frequency values, follow these steps in order:

# %% [markdown]
# ***1. Make a copy of df_uk and drop duplicates***

# %%
df_uk2 = df_uk.copy()

# %%
df_uk2.duplicated().sum()
# Out:
# 0

# %%
df_uk2.shape
# Out:
# (349203, 10)

# %% [markdown]
# ***2. Calculate the frequency of purchases***

# %%
cus_freq = df_uk2.groupby('CustomerID', as_index=False, sort=False).InvoiceNo.nunique()
cus_freq = cus_freq.rename(columns={'InvoiceNo': 'Frequency'}).reset_index(drop=True)

# %%
print(cus_freq.shape)
cus_freq.head()
# Out:
# (3920, 2)
#    CustomerID  Frequency
# 0     17850.0         34
# 1     13047.0         10
# 2     13748.0          5
# 3     15100.0          3
# 4     15291.0         15

# %% [markdown]
# ***3. Plot RFM distributions***

# %%
cus_freq.Frequency.describe()
# Out:
# count    3920.000000
# mean        4.246429
# std         7.199202
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         5.000000
# max       209.000000
# Name: Frequency, dtype: float64

# %%
plt.figure(figsize=(12,6))
sns.histplot(cus_freq.Frequency, bins=50)
# Out:
# <AxesSubplot:xlabel='Frequency', ylabel='Count'>

# %%
plt.figure(figsize=(12,6))
sns.boxplot(cus_freq.Frequency)
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %% [markdown]
# ### v. Monetary: Total amount of money spent
#
# The monetary value is calculated by adding together the cost of the customers' purchases.

# %% [markdown]
# ***1. Calculate sum total cost by customers and named "Monetary"***

# %%
cus_monetary = df_uk2.groupby('CustomerID', as_index=False, sort=False).TotalPrice.sum()
cus_monetary = cus_monetary.rename(columns={'TotalPrice': 'Monetary'}).reset_index(drop=True)

# %%
print(cus_monetary.shape)
cus_monetary.head()
# Out:
# (3920, 2)
#    CustomerID  Monetary
# 0     17850.0   5391.21
# 1     13047.0   3237.54
# 2     13748.0    948.25
# 3     15100.0    876.00
# 4     15291.0   4668.30

# %% [markdown]
# ***2. Plot RFM distributions***

# %%
cus_monetary.Monetary.describe()
# Out:
# count      3920.000000
# mean       1858.424654
# std        7478.631256
# min           3.750000
# 25%         298.185000
# 50%         644.975000
# 75%        1571.285000
# max      259657.300000
# Name: Monetary, dtype: float64

# %%
plt.figure(figsize=(12,6))
sns.histplot(cus_monetary.Monetary, bins=50)
# Out:
# <AxesSubplot:xlabel='Monetary', ylabel='Count'>

# %%
plt.figure(figsize=(12,6))
sns.boxplot(cus_monetary.Monetary)
# Out:
# <AxesSubplot:xlabel='Monetary'>

# %% [markdown]
# ### vi. Create RFM Table
# Merge the recency, frequency and motetary dataframes

# %%
df_rfm = pd.merge(pd.merge(cus_recency, cus_freq, on='CustomerID'), cus_monetary, on='CustomerID')

# %%
df_rfm = df_rfm.set_index('CustomerID')

# %%
df_rfm.head()
# Out:
#             Recency  Frequency  Monetary
# CustomerID
# 17850           373         34   5391.21
# 13047            32         10   3237.54
# 13748            96          5    948.25
# 15100           334          3    876.00
# 15291            26         15   4668.30

# %%
df_rfm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3920 entries, 17850 to 14569
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Recency    3920 non-null   int64
#  1   Frequency  3920 non-null   int64
#  2   Monetary   3920 non-null   float64
# dtypes: float64(1), int64(2)
# memory usage: 122.5 KB

# %% [markdown]
# # 3. Customer Segmentation with RFM Scores

# %% [markdown]
# Businesses have this ever-lasting urge to understand their customers. The better you understand the customer, the better you serve them, and the higher the financial gain you receive from that customer. Since the dawn of trade, this process of understanding customers for a strategic gain has been there practiced and this task is known majorly as [Customer Segmentation](https://clevertap.com/blog/rfm-analysis/).
# Well as the name suggests, Customer Segmentation could segment customers according to their precise needs. Some of the common ways of segmenting customers are based on their Recency-Frequency-Monatory values, their demographics like gender, region, country, etc, and some of their business-crafted scores. You will use Recency-Frequency-Monatory values for this case.
#
# In this section, you will create an RFM Segmentation Table where you segment your customers by using the RFM table. For example, you can label the best customer as "Big Spenders" and the lost customer as "Lost Customer".

# %% [markdown]
# ## Calculate RFM Scoring
#
# The simplest way to create customer segments from an RFM model is by using **Quartiles**. We will assign a score from 1 to 4 to each category (Recency, Frequency, and Monetary) with 4 being the highest/best value. The final RFM score is calculated by combining all RFM values. For Customer Segmentation, you will use the df_rfm data set resulting from the RFM analysis.
# <br>
# <br>
# **Note**: Data can be assigned into more groups for better granularity, but we will use 4 in this case.

# %% [markdown]
# ***1. Divide the df_rfm into quarters***

# %%
df_rfm.describe()
# Out:
#            Recency    Frequency       Monetary
# count  3920.000000  3920.000000    3920.000000
# mean     92.742092     4.246429    1858.424654
# std      99.533485     7.199202    7478.631256
# min       1.000000     1.000000       3.750000
# 25%      18.000000     1.000000     298.185000
# 50%      51.000000     2.000000     644.975000
# 75%     143.000000     5.000000    1571.285000
# max     374.000000   209.000000  259657.300000

# %%
quantiles = df_rfm.quantile([.25, .5, .75])
quantiles
# Out:
#       Recency  Frequency  Monetary
# 0.25     18.0        1.0   298.185
# 0.50     51.0        2.0   644.975
# 0.75    143.0        5.0  1571.285

# %%
# SAMPLE
quantiles.loc[0.25, 'Frequency']
# Out:
# 1.0

# %%
# METHOD-2
# qcut is used to divide the data into 4 equal parts

# rfm["recency_score"] = pd.qcut(rfm["recency"], 4, labels = [4,3,2,1])
# rfm["frequency_score"] = pd.qcut(rfm["frequency"].rank(method = "first"), 4, labels = [1,2,3,4])
# rfm["monetary_score"] = pd.qcut(rfm["monetary"], 4, labels = [1,2,3,4])

# %% [markdown]
# ### i. Creating the RFM Segmentation Table

# %% [markdown]
# ***1. Create two functions, one for Recency and one for Frequency and Monetary. For Recency, customers in the first quarter should be scored as 4, this represents the highest Recency value. Conversely, for Frequency and Monetary, customers in the last quarter should be scored as 4, representing the highest Frequency and Monetary values.***

# %%
def recency_scoring(row, col):
    
    if row <= quantiles.loc[0.25, col]:
        return 4
    elif row <= quantiles.loc[0.5, col]:
        return 3
    elif row <= quantiles.loc[0.75, col]:
        return 2
    else:
        return 1

# %%
def freq_monetary_scoring(row, col):
    
    if row <= quantiles.loc[0.25, col]:
        return 1
    elif row <= quantiles.loc[0.5, col]:
        return 2
    elif row <= quantiles.loc[0.75, col]:
        return 3
    else:
        return 4

# %% [markdown]
# ***2. Score customers from 1 to 4 by applying the functions you have created. Also create separate score column for each value.***

# %%
df_rfm['R_Score'] = df_rfm['Recency'].apply(recency_scoring, args=('Recency',))
df_rfm['F_Score'] = df_rfm['Frequency'].apply(freq_monetary_scoring, args=('Frequency',))
df_rfm['M_Score'] = df_rfm['Monetary'].apply(freq_monetary_scoring, args=('Monetary',))

# %%
df_rfm.head()
# Out:
#             Recency  Frequency  Monetary  R_Score  F_Score  M_Score
# CustomerID
# 17850           373         34   5391.21        1        4        4
# 13047            32         10   3237.54        3        4        4
# 13748            96          5    948.25        2        3        3
# 15100           334          3    876.00        1        3        3
# 15291            26         15   4668.30        3        4        4

# %%
a = df_rfm.R_Score.value_counts()
b = df_rfm.F_Score.value_counts()
c = df_rfm.M_Score.value_counts()

# %%
pd.concat([a,b,c], axis=1)
# Out:
#    R_Score  F_Score  M_Score
# 1      979     1350      980
# 2      969      746      980
# 3      969     1033      980
# 4     1003      791      980

# %%
df_rfm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3920 entries, 17850 to 14569
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Recency    3920 non-null   int64
#  1   Frequency  3920 non-null   int64
#  2   Monetary   3920 non-null   float64
#  3   R_Score    3920 non-null   int64
#  4   F_Score    3920 non-null   int64
#  5   M_Score    3920 non-null   int64
# dtypes: float64(1), int64(5)
# memory usage: 214.4 KB

# %% [markdown]
# ***3. Now that scored each customer, you'll combine the scores for segmentation.***

# %%
df_rfm['RFM_Segment'] = df_rfm['R_Score'].astype(str) \
                        + df_rfm['F_Score'].astype(str) \
                        + df_rfm['M_Score'].astype(str)
df_rfm.head()
# Out:
#             Recency  Frequency  Monetary  R_Score  F_Score  M_Score  \
# CustomerID
# 17850           373         34   5391.21        1        4        4
# 13047            32         10   3237.54        3        4        4
# 13748            96          5    948.25        2        3        3
# 15100           334          3    876.00        1        3        3
# 15291            26         15   4668.30        3        4        4
#
#            RFM_Segment
# CustomerID
# 17850              144
# 13047              344
# 13748              233
# 15100              133
# 15291              344

# %%
df_rfm['RFM_Segment'].dtype.type
# Out:
# numpy.object_

# %%
df_rfm['RFM_Segment'].value_counts()[:10]
# Out:
# 444    423
# 111    395
# 112    212
# 333    190
# 211    185
# 344    165
# 433    159
# 233    141
# 212    141
# 311    136
# Name: RFM_Segment, dtype: int64

# %%
plt.figure(figsize=(16,7))
sns.countplot(data=df_rfm, x='RFM_Segment', order=df_rfm.RFM_Segment.value_counts()[:30].index, palette='twilight')
# Out:
# <AxesSubplot:xlabel='RFM_Segment', ylabel='count'>

# %%
def rfm_score(score):
    
    total=0
    for i in score: total += int(i)
        
    return total

df_rfm['RFM_Score'] = df_rfm.RFM_Segment.apply(rfm_score)

print(df_rfm.head())
# Out:
#             Recency  Frequency  Monetary  R_Score  F_Score  M_Score  \
# CustomerID
# 17850           373         34   5391.21        1        4        4
# 13047            32         10   3237.54        3        4        4
# 13748            96          5    948.25        2        3        3
# 15100           334          3    876.00        1        3        3
# 15291            26         15   4668.30        3        4        4
#
#            RFM_Segment  RFM_Score
# CustomerID
# 17850              144          9
# 13047              344         11
# 13748              233          8
# 15100              133          7
# 15291              344         11

# %%
df_rfm['RFM_Score'].describe()
# Out:
# count    3920.000000
# mean        7.331888
# std         2.888027
# min         3.000000
# 25%         5.000000
# 50%         7.000000
# 75%        10.000000
# max        12.000000
# Name: RFM_Score, dtype: float64

# %%
plt.figure(figsize=(14,7))
a = sns.countplot(data=df_rfm, x='RFM_Score', order=df_rfm.RFM_Score.value_counts().index, palette='twilight')
plt.bar_label(a.containers[0], padding=2, fontsize=11)
plt.ylim(0,550);

# %% [markdown]
# ***4. Define rfm_level function that tags customers by using RFM_Scores and Create a new variable RFM_Level***

# %%
# Define rfm_level
seg_map = {r'44[3-4]': 'Champions',                      
           r'[3-4][3-4][1-2-3-4]': 'Loyal',
           r'[3-4][1-2][1-2-3-4]': 'New Customers',
           r'[1-2][3-4][1-2-3-4]': 'Need Attention',
           r'[1-2][1-2][3-4]': 'Can\'t Lose Them',            
           r'[1-2][1-2][1-2]':'Hibernating'
}  

# Champions are your best customers, who bought most recently, most often, and are heavy spenders.
# Potential Loyalists are your recent customers with average frequency and who spent a good amount.
# New Customers are your customers who have a high overall RFM score but are not frequent shoppers.
# Can’t Lose Them are customers who used to visit and purchase quite often, but haven’t been visiting recently.
# At Risk Customers are your customers who purchased often and spent big amounts, but haven’t purchased recently.
# Hibernating are customers who have a low overall RFM score and are not frequent shoppers.

# %%
df_rfm['RFM_Level'] = df_rfm['RFM_Segment'].replace(seg_map, regex=True)
df_rfm.head()
# Out:
#             Recency  Frequency  Monetary  R_Score  F_Score  M_Score  \
# CustomerID
# 17850           373         34   5391.21        1        4        4
# 13047            32         10   3237.54        3        4        4
# 13748            96          5    948.25        2        3        3
# 15100           334          3    876.00        1        3        3
# 15291            26         15   4668.30        3        4        4
#
#            RFM_Segment  RFM_Score       RFM_Level
# CustomerID
# 17850              144          9  Need Attention
# 13047              344         11           Loyal
# 13748              233          8  Need Attention
# 15100              133          7  Need Attention
# 15291              344         11           Loyal

# %% [raw]
# # METHOD-2 (Define rfm_level function)
#
# def rfm_level(df):
#     if df['RFM_Score'] > 10:
#         return 'Platinum'
#     elif df['RFM_Score'] > 8:
#         return 'Gold'
#     elif df['RFM_Score'] > 6:
#         return 'Silver'
#     else:
#         return 'Bronze'
#
# # Create a new variable RFM_Level by applying function to table
#
# df_rfm['RFM_Level'] = df_rfm.apply(rfm_level, axis=1)

# %% [markdown]
# ***5. Calculate average values for each RFM_Level, and return a size of each segment***

# %%
rfm_plot= pd.DataFrame(df_rfm['RFM_Level'].value_counts()).reset_index() \
                       .rename(columns={'index':'RFM_Level', 'RFM_Level':'Customers'})
rfm_plot
# Out:
#          RFM_Level  Customers
# 0      Hibernating       1195
# 1            Loyal        834
# 2    New Customers        663
# 3   Need Attention        515
# 4        Champions        475
# 5  Can't Lose Them        238

# %%
df_rfm.groupby(df_rfm['RFM_Level']).agg({'Recency':'mean', 'Frequency':'mean', 
                                         'Monetary':'mean', 'RFM_Score': ['mean','size']})
# Out:
#                     Recency  Frequency     Monetary  RFM_Score
#                        mean       mean         mean       mean  size
# RFM_Level
# Can't Lose Them  143.596639   1.621849  1425.570761   6.352941   238
# Champions          7.856842  14.861053  7637.089789  11.890526   475
# Hibernating      192.783264   1.219247   278.894930   4.025105  1195
# Loyal             23.737410   5.273381  1965.609641   9.832134   834
# Need Attention   113.978641   4.557282  1689.275983   8.031068   515
# New Customers     25.292609   1.506787   717.264163   6.689291   663

# %% [markdown]
# ## Plot RFM Segments

# %% [markdown]
# ***1. Create your plot and resize it.***

# %%
import squarify

fig = plt.gcf()
ax = fig.add_subplot()
fig.set_size_inches(16, 9)
squarify.plot(sizes=list(rfm_plot['Customers'].values), 
              label=list(rfm_plot['RFM_Level'].values), alpha=0.8,
              text_kwargs={'fontsize':12},color = ['brown', '#34495E', 'rosybrown', 'seagreen', 'goldenrod', 'steelblue'])
plt.title("RFM Labels", fontsize=22, fontweight="bold", pad=13)
plt.axis('off')
plt.show()

# %% [markdown]
# Using customer segmentation categories found [here](http://www.blastam.com/blog/rfm-analysis-boosts-sales) we can formulate different marketing strategies and approaches for customer engagement for each type of customer.
#
# Note: The author in the article scores 1 as the highest and 4 as the lowest

# %% [markdown]
# ***2. How many customers do we have in each segment?***

# %%
plt.figure(figsize=(12,6))
ax = sns.countplot(data=df_rfm, x='RFM_Level', order=df_rfm.RFM_Level.value_counts().index)
ax.bar_label(ax.containers[0], fontsize=11)
plt.ylim(0,1400)
plt.title('Segment Distribution', pad=10, fontsize=16);

# %% [markdown]
# # 3. Applying K-Means Clustering

# %% [markdown]
# Now that we have our customers segmented into 6 different categories, we can gain further insight into customer behavior by using predictive models in conjuction with out RFM model.
# Possible algorithms include **Logistic Regression**, **K-means Clustering**, and **K-nearest Neighbor**. We will go with [K-Means](https://towardsdatascience.com/understanding-k-means-clustering-in-machine-learning-6a6e67336aa1) since we already have our distinct groups determined. K-means has also been widely used for market segmentation and has the advantage of being simple to implement.

# %% [markdown]
# ## Data Pre-Processing and Exploring

# %%
df_rfm.head()
# Out:
#             Recency  Frequency  Monetary  R_Score  F_Score  M_Score  \
# CustomerID
# 17850           373         34   5391.21        1        4        4
# 13047            32         10   3237.54        3        4        4
# 13748            96          5    948.25        2        3        3
# 15100           334          3    876.00        1        3        3
# 15291            26         15   4668.30        3        4        4
#
#            RFM_Segment  RFM_Score       RFM_Level
# CustomerID
# 17850              144          9  Need Attention
# 13047              344         11           Loyal
# 13748              233          8  Need Attention
# 15100              133          7  Need Attention
# 15291              344         11           Loyal

# %%
rfm = df_rfm[['Recency', 'Frequency', 'Monetary']]
rfm.head()
# Out:
#             Recency  Frequency  Monetary
# CustomerID
# 17850           373         34   5391.21
# 13047            32         10   3237.54
# 13748            96          5    948.25
# 15100           334          3    876.00
# 15291            26         15   4668.30

# %% [markdown]
# ### i. Define and Plot Feature Correlations

# %% [markdown]
# Create Heatmap and evaluate the results

# %%
sns.heatmap(rfm.corr(), annot=True, cmap='viridis', linewidth=1, linecolor='black')
# Out:
# <AxesSubplot:>

# %%
# There are negative correlations between Recency and others
# On the other hand, the correlation between Monetary and Frequency is positive but not strong

# %% [markdown]
# ### ii. Visualize Feature Distributions
#
# To get a better understanding of the dataset, you can costruct a scatter matrix of each of the three features in the RFM data.

# %%
sns.pairplot(rfm, diag_kind='kde', diag_kws={'color': 'brown', 'alpha': 0.6}, aspect=1.5)

# %%
rfm.Recency.skew(), rfm.Frequency.skew(), rfm.Monetary.skew()
# Out:
# (1.24499294569519, 10.751932091802606, 20.217580960310592)

# %%
# We can notice that we have a skewed distribution of the 3 variables and there exist outliers
# All distributions are highly right skewed. We should make these distributions normal in order to create meaningful clusters

# %% [markdown]
# ### iii. Data Normalization

# %% [markdown]
# ***1. You can use the logarithm method to normalize the values in a column.***

# %%
rfm_log = (rfm + 0.1).apply(np.log)

# %%
rfm_log.head()
# Out:
#              Recency  Frequency  Monetary
# CustomerID
# 17850       5.921846   3.529297  8.592544
# 13047       3.468856   2.312535  8.082600
# 13748       4.565389   1.629241  6.854724
# 15100       5.811440   1.131402  6.775480
# 15291       3.261935   2.714695  8.448572

# %%
rfm_log.describe()
# Out:
#            Recency    Frequency     Monetary
# count  3920.000000  3920.000000  3920.000000
# mean      3.804993     0.996996     6.537986
# std       1.373269     0.868809     1.247523
# min       0.095310     0.095310     1.348073
# 25%       2.895912     0.095310     5.698049
# 50%       3.933784     0.741937     6.469366
# 75%       4.963544     1.629241     7.359713
# max       5.924523     5.342813    12.467118

# %% [markdown]
# ***2. Plot normalized data with scatter matrix or pairplot. Also evaluate results.***

# %%
sns.pairplot(rfm_log, diag_kind='kde', diag_kws={'color': 'red', 'alpha': 0.6}, aspect=1.5)

# %%
rfm_log.Recency.skew(), rfm_log.Frequency.skew(), rfm_log.Monetary.skew()
# Out:
# (-0.44605986644233736, 0.8198373313550306, 0.3611525816017648)

# %% [markdown]
# ## K-Means Implementation
#
# For k-means, you have to set k to the number of clusters you want, but figuring out how many clusters is not obvious from the beginning. We will try different cluster numbers and check their [silhouette coefficient](http://scikit-learn.org/stable/auto_examples/cluster/plot_kmeans_silhouette_analysis.html). The silhouette coefficient for a data point measures how similar it is to its assigned cluster from -1 (dissimilar) to 1 (similar).
# <br>
# <br>
# **Note**: K-means is sensitive to initializations because they are critical to qualifty of optima found. Thus, we will use smart initialization called "Elbow Method".

# %%
X = rfm_log.copy()

# %%
X.shape
# Out:
# (3920, 3)

# %%
# Hopkins Test
from pyclustertend import hopkins
hopkins(X, X.shape[0])
# Out:
# 0.06720794499079571

# %% [markdown]
# ### i. Define the Optimal Number of Clusters

# %% [markdown]
# [The Elbow Method](https://en.wikipedia.org/wiki/Elbow_method_(clustering)

# %%
from sklearn.cluster import KMeans

ssd = []
for k in range(2,11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X)
    ssd.append(kmeans.inertia_)
    
plt.plot(range(2,11), ssd, "bo-", markersize=6)
plt.xlabel("number of clusters")
plt.ylabel("inertia-error") 
plt.title("elbow method")
# Out:
# Text(0.5, 1.0, 'elbow method')

# %%
ssd
# Out:
# [8314.562149678448,
#  6312.46787475584,
#  4887.167453202809,
#  4153.486804849085,
#  3557.527023573242,
#  3191.884168774245,
#  2875.3460998559744,
#  2621.3327619828083,
#  2412.461461120137]

# %%
# yellowbrick

from yellowbrick.cluster import KElbowVisualizer
kmeans = KMeans(random_state=42)
visualizer = KElbowVisualizer(kmeans, k=(2,11))

visualizer.fit(X)        
visualizer.show();

# %% [markdown]
# [Silhouette Coefficient](http://scikit-learn.org/stable/auto_examples/cluster/plot_kmeans_silhouette_analysis.html)

# %%
from sklearn.metrics import silhouette_score

for num_clusters in range(2,11):
    kmeans = KMeans(n_clusters=num_clusters, random_state=42)
    kmeans.fit(X)
    
    silhouette_avg = silhouette_score(X, kmeans.labels_)
    print(f"For n_clusters={num_clusters}, the silhouette score is {silhouette_avg}")
# Out:
# For n_clusters=2, the silhouette score is 0.42109133135865706
# For n_clusters=3, the silhouette score is 0.3288098673708004
# For n_clusters=4, the silhouette score is 0.34717062653609576
# For n_clusters=5, the silhouette score is 0.3269382735772792
# For n_clusters=6, the silhouette score is 0.31855164925284524
# For n_clusters=7, the silhouette score is 0.31367225736705884
# For n_clusters=8, the silhouette score is 0.3156088014416155
# For n_clusters=9, the silhouette score is 0.2952874728773418
# For n_clusters=10, the silhouette score is 0.294063182922987

# %%
from yellowbrick.cluster import SilhouetteVisualizer

model = KMeans(n_clusters=4, random_state=42)
visualizer = SilhouetteVisualizer(model)

visualizer.fit(X)
visualizer.poof();

# %%
model = KMeans(n_clusters=3, random_state=42)
visualizer = SilhouetteVisualizer(model)

visualizer.fit(X)
visualizer.poof();

# %% [markdown]
# ### ii. Model Fitting

# %% [markdown]
# Fit the K-Means Algorithm with the optimal number of clusters you decided and save the model to disk.

# %%
km_model1 = KMeans(n_clusters=3, random_state=42)
km_model1.fit(X)
# Out:
# KMeans(n_clusters=3, random_state=42)

# %%
km_model2 = KMeans(n_clusters=4, random_state=42)
km_model2.fit(X)
# Out:
# KMeans(n_clusters=4, random_state=42)

# %%
X['ClusterID_3'] = km_model1.labels_
X['ClusterID_4'] = km_model2.labels_

# %%
plt.figure(figsize = (20,6))

plt.subplot(121)
ax1 = sns.countplot(x='ClusterID_3', data=X)

for p in ax1.patches:
    ax1.annotate((p.get_height()), (p.get_x()+0.3, p.get_height()+100), fontsize=11)
    
plt.subplot(122)  
ax2 = sns.countplot(x='ClusterID_4', data=X)

for p in ax2.patches:
    ax2.annotate((p.get_height()), (p.get_x()+0.3, p.get_height()+100), fontsize=11)
    
ax1.set_title('Distribution of Clusters For 4-Class', size=13, pad=11)  
ax2.set_title('Distribution of Clusters For 5-Class', size=13, pad=11) 
ax1.set_ylim(0, 2500), ax2.set_ylim(0, 2500);

# %%
X.sample(10)
# Out:
#              Recency  Frequency   Monetary  ClusterID_3  ClusterID_4
# CustomerID
# 12948       2.839078   1.960095   7.632910            0            3
# 17962       4.963544   0.095310   4.629960            1            0
# 17125       3.933784   0.095310   5.440685            1            0
# 14000       5.357058   0.095310   6.454821            1            0
# 13867       3.468856   1.131402   6.912932            2            2
# 14669       5.489351   1.131402   7.138343            1            2
# 14538       4.175925   0.741937   5.961907            1            0
# 17786       4.455509   0.741937   5.587061            1            0
# 15098       5.210032   1.131402  10.594548            0            2
# 15733       5.645800   0.095310   5.090062            1            0

# %% [markdown]
# ### iii. Visualize the Clusters

# %% [markdown]
# ***1. Create a scatter plot and select cluster centers***

# %%
plt.figure(figsize = (20,7))

plt.subplot(121)
centers1 = km_model1.cluster_centers_
sns.scatterplot(data=X, x='Recency', y='Monetary', hue=X.ClusterID_3, palette='viridis')
plt.scatter(centers1[:, 0], centers1[:, 2], c='black', s=200, alpha=0.6)
plt.title('Recency-Monetary\n(3-CLUSTERS)', size=14, pad=12)

plt.subplot(122)
centers2 = km_model2.cluster_centers_
sns.scatterplot(data=X, x='Recency', y='Monetary', hue=X.ClusterID_4, palette='viridis')
plt.scatter(centers2[:, 0], centers2[:, 2], c='black', s=200, alpha=0.6)
plt.title('Recency-Monetary\n(4-CLUSTERS)', size=14, pad=12)

plt.tight_layout();

# %%
plt.figure(figsize = (20,7))

plt.subplot(121)
centers1 = km_model1.cluster_centers_
sns.scatterplot(data=X, x='Frequency', y='Monetary', hue=X.ClusterID_3, palette='viridis')
plt.scatter(centers1[:, 1], centers1[:, 2], c='black', s=200, alpha=0.6)
plt.title('Frequency-Monetary\n(3-CLUSTERS)', size=14, pad=12)

plt.subplot(122)
centers2 = km_model2.cluster_centers_
sns.scatterplot(data=X, x='Frequency', y='Monetary', hue=X.ClusterID_4, palette='viridis')
plt.scatter(centers2[:, 1], centers2[:, 2], c='black', s=200, alpha=0.6)
plt.title('Frequency-Monetary\n(4-CLUSTERS)', size=14, pad=12)

plt.tight_layout();

# %%
plt.figure(figsize = (20,7))

plt.subplot(121)
centers1 = km_model1.cluster_centers_
sns.scatterplot(data=X, x='Recency', y='Frequency', hue=X.ClusterID_3, palette='viridis')
plt.scatter(centers1[:, 0], centers1[:, 1], c='black', s=200, alpha=0.6)
plt.title('Recency-Frequency\n(3-CLUSTERS)', size=14, pad=12)

plt.subplot(122)
centers2 = km_model2.cluster_centers_
sns.scatterplot(data=X, x='Recency', y='Frequency', hue=X.ClusterID_4, palette='viridis')
plt.scatter(centers2[:, 0], centers2[:, 1], c='black', s=200, alpha=0.6)
plt.title('Recency-Frequency\n(4-CLUSTERS)', size=14, pad=12)

plt.tight_layout();

# %%
from mpl_toolkits.mplot3d import Axes3D 
fig = plt.figure(figsize=(14,6))

ax1 = fig.add_subplot(121, projection='3d')
ax1.scatter(X['Recency'], X['Frequency'], X['Monetary'],c=X.ClusterID_3, cmap='viridis')
ax1.set_title('ClusterID-3', fontsize=13)

ax2 = fig.add_subplot(122, projection='3d')
ax2.scatter(X['Recency'], X['Frequency'], X['Monetary'],c=X.ClusterID_4, cmap='viridis')
ax2.set_title('ClusterID-4', fontsize=13)

plt.tight_layout();

# %% [markdown]
# ***2. Visualize Cluster Id vs Recency, Cluster Id vs Frequency and Cluster Id vs Monetary using Box plot. Also evaluate the results.***

# %%
print(f'Inertia Score (n=3)    : {km_model1.inertia_}')
print(f'Silhouette Score (n=3) : {silhouette_score(X, km_model1.labels_)}')
print()
print(f'Inertia Score (n=4)    : {km_model2.inertia_}')
print(f'Silhouette Score (n=4) : {silhouette_score(X, km_model2.labels_)}')
# Out:
# Inertia Score (n=3)    : 6312.46787475584
# Silhouette Score (n=3) : 0.4600649092387284
#
# Inertia Score (n=4)    : 4887.167453202809
# Silhouette Score (n=4) : 0.45281731657889374

# %%
rfm['ClusterID_3'] = km_model1.labels_
rfm['ClusterID_4'] = km_model2.labels_

# %%
rfm.insert(3, 'RFM_Level', df_rfm.RFM_Level)

# %%
rfm.head()
# Out:
#             Recency  Frequency  Monetary       RFM_Level  ClusterID_3  \
# CustomerID
# 17850           373         34   5391.21  Need Attention            2
# 13047            32         10   3237.54           Loyal            0
# 13748            96          5    948.25  Need Attention            2
# 15100           334          3    876.00  Need Attention            1
# 15291            26         15   4668.30           Loyal            0
#
#             ClusterID_4
# CustomerID
# 17850                 2
# 13047                 2
# 13748                 2
# 15100                 0
# 15291                 3

# %%
index = 0
plt.figure(figsize=(18,10))
for col in rfm.iloc[:, :3]:    
    index += 1
    plt.subplot(2,2,index)
    sns.boxplot(x='ClusterID_3', y=col, data=rfm)
    plt.title(f'{col}')
plt.suptitle('FOR 3 CLUSTERS');

# %%
index = 0
plt.figure(figsize=(18,10))
for col in rfm.iloc[:, :3]:    
    index += 1
    plt.subplot(2,2,index)
    sns.boxplot(x='ClusterID_4', y=col, data=rfm)
    plt.title(f'{col}')
plt.suptitle('FOR 4 CLUSTERS');

# %%
rfm.groupby('ClusterID_3')[['Recency','Frequency','Monetary']].agg({'Recency': ['count',np.mean,min,'median',max],
                                                                    'Frequency': [np.mean,min,'median',max],
                                                                    'Monetary': [np.mean,min,'median',max]})
# Out:
#             Recency                              Frequency                  \
#               count        mean min median  max       mean min median  max
# ClusterID_3
# 0               782   12.152174   1    9.0  236  11.799233   1    8.0  209
# 1              1531  181.620509  15  178.0  374   1.392554   1    1.0    7
# 2              1607   47.283759   2   34.0  373   3.289981   1    3.0   34
#
#                 Monetary
#                     mean     min    median        max
# ClusterID_3
# 0            6332.919041  398.70  3039.195  259657.30
# 1             331.040608    3.75   271.050    2184.42
# 2            1136.190904   41.99   843.000   77183.60

# %%
rfm.groupby('ClusterID_4')[['Recency','Frequency','Monetary']].agg({'Recency': ['count',np.mean,min,'median',max],
                                                                    'Frequency': [np.mean,min,'median',max],
                                                                    'Monetary': [np.mean,min,'median',max]})
# Out:
#             Recency                              Frequency                  \
#               count        mean min median  max       mean min median  max
# ClusterID_4
# 0              1358  194.818851  39  190.0  374   1.361561   1    1.0    6
# 1               810   23.182716   2   20.0   61   1.962963   1    2.0    7
# 2              1077   68.734448  13   54.0  373   4.363045   1    4.0   34
# 3               675    9.155556   1    8.0   43  12.604444   1    9.0  209
#
#                 Monetary
#                     mean     min   median        max
# ClusterID_4
# 0             324.274618    3.75   288.30    2002.40
# 1             442.083247   20.80   387.56    1463.04
# 2            1798.296168  381.00  1324.84   77183.60
# 3            6740.455274  518.19  3124.72  259657.30

# %% [markdown]
# ### iv. Assign the Label

# %%
rfm['RFM_Label'] = rfm['ClusterID_3'].map({0: 'Lost/Needed Attention Customers',
                                           1: 'Current Customers',
                                           2: 'Best Customers'})

# %%
rfm.head()
# Out:
#             Recency  Frequency  Monetary       RFM_Level  ClusterID_3  \
# CustomerID
# 17850           373         34   5391.21  Need Attention            2
# 13047            32         10   3237.54           Loyal            0
# 13748            96          5    948.25  Need Attention            2
# 15100           334          3    876.00  Need Attention            1
# 15291            26         15   4668.30           Loyal            0
#
#             ClusterID_4                        RFM_Label
# CustomerID
# 17850                 2                   Best Customers
# 13047                 2  Lost/Needed Attention Customers
# 13748                 2                   Best Customers
# 15100                 0                Current Customers
# 15291                 3  Lost/Needed Attention Customers

# %% [markdown]
# **Conclusion**
#
# - ***Cluster 0 :*** The first cluster is more related to the "Almost Lost" segment as they haven’t purchased for some time (R=1), but used to purchase frequently and spent a lot.
# - ***Cluster 1 :*** Second cluster can be interpreted as current customers who have been shopping at different frequencies and spending in varying amounts. Company has to come up with new strategies to make them permanent members. Current customers
# - ***Cluster 2 :*** The third cluster belongs to the "Best Customers" segment which we saw earlier as they purchase recently (R=4), frequent buyers (F=4), and spent the most (M=4)

# %% [markdown]
# ### v. Conclusion
#
# Discuss your final results. Compare your own labels from the Customer Segmentation with the labels found by K-Means.

# %% [markdown]
# How we want to continue this analysis depends on how the business plans to use the results and the level of granularity the business stakeholders want to see in the clusters. We can also ask what range of customer behavior from high to low value customers are the stakeholders interested in exploring. From those answers, various methods of clustering can be used and applied on RFM variable or directly on the transaction data set.

# %%
pd.crosstab(rfm.ClusterID_3, rfm.RFM_Level)
# Out:
# RFM_Level    Can't Lose Them  Champions  Hibernating  Loyal  Need Attention  \
# ClusterID_3
# 0                          0        466            0    290              11
# 1                        114          0         1157      3             119
# 2                        124          9           38    541             385
#
# RFM_Level    New Customers
# ClusterID_3
# 0                       15
# 1                      138
# 2                      510

# %% [markdown]
# **Annotation:**
#
# Limitations of K-means clustering:
#
# 1. There is no assurance that it will lead to the global best solution.
# 2. Can't deal with different shapes(not circular) and consider one point's probability of belonging to more than one cluster.
#
# These disadvantages of K-means show that for many datasets (especially low-dimensional datasets), it may not perform as well as you might hope.

# %% [markdown]
# # 5. Create Cohort & Conduct Cohort Analysis
# [Cohort Analysis](https://medium.com/swlh/cohort-analysis-using-python-and-pandas-d2a60f4d0a4d) is specifically useful in analyzing user growth patterns for products. In terms of a product, a cohort can be a group of people with the same sign-up date, the same usage starts month/date, or the same traffic source.
# Cohort analysis is an analytics method by which these groups can be tracked over time for finding key insights. This analysis can further be used to do customer segmentation and track metrics like retention, churn, and lifetime value.
#
# For e-commerce organizations, cohort analysis is a unique opportunity to find out which clients are the most valuable to their business. by performing Cohort analysis you can get the following answers to the following questions:
#
# - How much effective was a marketing campaign held in a particular time period?
# - Did the strategy employ to improve the conversion rates of Customers worked?
# - Should I focus more on retention rather than acquiring new customers?
# - Are my customer nurturing strategies effective?
# - Which marketing channels bring me the best results?
# - Is there a seasonality pattern in Customer behavior?
# - Along with various performance measures/metrics for your organization.

# %% [markdown]
# Since we will be performing Cohort Analysis based on transaction records of customers, the columns we will be dealing with mainly:
# - Invoice Data
# - CustomerID
# - Price
# - Quantity
#
# The following steps will performed to generate the Cohort Chart of Retention Rate:
# - Month Extraction from InvioceDate column
# - Assigning Cohort to Each Transaction
# - Assigning Cohort Index to each transaction
# - Calculating number of unique customers in each Group of (ChortDate,Index)
# - Creating Cohort Table for Retention Rate
# - Creating the Cohort Chart using the Cohort Table
#
# The Detailed information about each step is given below:

# %% [markdown]
# ## Future Engineering

# %% [markdown]
# ### i. Extract the Month of the Purchase
# First we will create a function, which takes any date and returns the formatted date with day value as 1st of the same month and Year.

# %%
df_uk.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0  536365.0    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1  536365.0   71053.0                  WHITE METAL LANTERN       6.0
# 2  536365.0    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3  536365.0    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4  536365.0    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
#
#           InvoiceDate  UnitPrice  TotalPrice  CustomerID        Date  Recency
# 0 2010-12-01 08:26:00       2.55       15.30     17850.0  2010-12-01      373
# 1 2010-12-01 08:26:00       3.39       20.34     17850.0  2010-12-01      373
# 2 2010-12-01 08:26:00       2.75       22.00     17850.0  2010-12-01      373
# 3 2010-12-01 08:26:00       3.39       20.34     17850.0  2010-12-01      373
# 4 2010-12-01 08:26:00       3.39       20.34     17850.0  2010-12-01      373

# %%
cohort_df = df_uk.iloc[:, [7,0,4,3,5,6]]
cohort_df.head()
# Out:
#    CustomerID InvoiceNo         InvoiceDate  Quantity  UnitPrice  TotalPrice
# 0     17850.0  536365.0 2010-12-01 08:26:00       6.0       2.55       15.30
# 1     17850.0  536365.0 2010-12-01 08:26:00       6.0       3.39       20.34
# 2     17850.0  536365.0 2010-12-01 08:26:00       8.0       2.75       22.00
# 3     17850.0  536365.0 2010-12-01 08:26:00       6.0       3.39       20.34
# 4     17850.0  536365.0 2010-12-01 08:26:00       6.0       3.39       20.34

# %%
def first_of_month(date):    
    formatted_date = datetime.strptime(date.strftime('%Y-%m'), '%Y-%m')
    return dt.datetime(formatted_date.year, formatted_date.month, 1)

# OTHER METHODS
# cohort_df['InvoiceDate'].dt.to_period('M').dt.to_timestamp()
# cohort_df['InvoiceDate'].to_numpy().astype('datetime64[M]')

# %% [markdown]
# ***Now we will use the function created above to convert all the invoice dates into respective month date format.***

# %%
# month-year of the current purchase
cohort_df['InvoiceMonth'] = cohort_df['InvoiceDate'].apply(first_of_month)

# %%
# month-year of the first purchase
cohort_df['CohortMonth'] = cohort_df.groupby('CustomerID')['InvoiceMonth'].transform('min').dt.to_period('M')
cohort_df.sample(5)
# Out:
#         CustomerID InvoiceNo         InvoiceDate  Quantity  UnitPrice  \
# 260959     17832.0  572194.0 2011-10-21 11:43:00       1.0       1.25
# 177908     15249.0  562283.0 2011-08-04 10:43:00       8.0       3.75
# 35214      13659.0  541843.0 2011-01-23 12:08:00       8.0       1.25
# 197121     13709.0  564753.0 2011-08-30 10:20:00      10.0       1.25
# 346270     17735.0  581188.0 2011-12-07 16:47:00      24.0       0.55
#
#         TotalPrice InvoiceMonth CohortMonth
# 260959        1.25   2011-10-01     2011-10
# 177908       30.00   2011-08-01     2011-03
# 35214        10.00   2011-01-01     2011-01
# 197121       12.50   2011-08-01     2011-01
# 346270       13.20   2011-12-01     2010-12

# %% [markdown]
# ### ii. Calculating time offset in Months i.e. Cohort Index:
# ***Calculating time offset for each transaction will allows us to report the metrics for each cohort in a comparable fashion.
# First, you will create 4 variables that capture the integer value of years, months for Invoice and Cohort Date using the get_date_int() function which you'll create it below.***

# %%
def get_date_int(df, column):
    year = df[column].dt.year
    month = df[column].dt.month
    day = df[column].dt.day
    return year, month, day

# %% [markdown]
# ***You will use this function to extract the integer values for Invoice as well as Cohort Date in 3 seperate series for each of the two columns***

# %%
invoice_year, invoice_month, invoice_day = get_date_int(cohort_df, 'InvoiceMonth')
cohort_year, cohort_month, cohort_day = get_date_int(cohort_df, 'CohortMonth')

# %% [markdown]
# ***Use the variables created above to calcualte the difference in days and store them in cohort Index column.***
#
# (What is cohort index?
# Cohort period / Cohort Index: A integer representation a customer’s stage in its 'lifetime'. The number represents the number of months passed since the first purchase.)

# %%
year_diff = invoice_year - cohort_year 
month_diff = invoice_month - cohort_month 

cohort_df['CohortIndex'] = (year_diff * 12) + month_diff + 1
cohort_df.head()
# Out:
#    CustomerID InvoiceNo         InvoiceDate  Quantity  UnitPrice  TotalPrice  \
# 0     17850.0  536365.0 2010-12-01 08:26:00       6.0       2.55       15.30
# 1     17850.0  536365.0 2010-12-01 08:26:00       6.0       3.39       20.34
# 2     17850.0  536365.0 2010-12-01 08:26:00       8.0       2.75       22.00
# 3     17850.0  536365.0 2010-12-01 08:26:00       6.0       3.39       20.34
# 4     17850.0  536365.0 2010-12-01 08:26:00       6.0       3.39       20.34
#
#   InvoiceMonth CohortMonth  CohortIndex
# 0   2010-12-01     2010-12            1
# 1   2010-12-01     2010-12            1
# 2   2010-12-01     2010-12            1
# 3   2010-12-01     2010-12            1
# 4   2010-12-01     2010-12            1

# %%
# METHOD-2

# from operator import attrgetter
# cohort_df['CohortIndex'] = (cohort_df['InvoiceMonth'].dt.to_period('M')-cohort_df['CohortMonth']).apply(attrgetter('n'))

# %% [markdown]
# ## Create 1st Cohort: User number & Retention Rate

# %% [markdown]
# ### i. Pivot Cohort and Cohort Retention

# %%
first_cohort = cohort_df.groupby(['CohortMonth', 'CohortIndex'])['CustomerID'].nunique().reset_index()
first_cohort.head()
# Out:
#   CohortMonth  CohortIndex  CustomerID
# 0     2010-12            1         815
# 1     2010-12            2         289
# 2     2010-12            3         263
# 3     2010-12            4         304
# 4     2010-12            5         293

# %%
first_pivot = first_cohort.pivot(index='CohortMonth', columns='CohortIndex', values='CustomerID').round(1)
first_pivot
# each row contains information about a given cohort and each column contains values for a certain period
# the columns are recency values, highest recency is 373 days
# Out:
# CohortIndex     1      2      3      4      5      6      7      8      9   \
# CohortMonth
# 2010-12      815.0  289.0  263.0  304.0  293.0  323.0  291.0  278.0  289.0
# 2011-01      358.0   76.0   93.0   84.0  119.0   99.0   90.0   87.0  108.0
# 2011-02      340.0   64.0   66.0   97.0   98.0   86.0   87.0   96.0   90.0
# 2011-03      419.0   64.0  109.0   83.0   94.0   69.0  111.0   96.0  119.0
# 2011-04      277.0   58.0   56.0   60.0   56.0   61.0   61.0   73.0   20.0
# 2011-05      256.0   48.0   44.0   44.0   53.0   58.0   68.0   23.0    NaN
# 2011-06      214.0   38.0   31.0   51.0   51.0   69.0   21.0    NaN    NaN
# 2011-07      169.0   30.0   33.0   39.0   47.0   18.0    NaN    NaN    NaN
# 2011-08      141.0   32.0   32.0   34.0   17.0    NaN    NaN    NaN    NaN
# 2011-09      276.0   63.0   83.0   32.0    NaN    NaN    NaN    NaN    NaN
# 2011-10      324.0   79.0   36.0    NaN    NaN    NaN    NaN    NaN    NaN
# ...

# %%
size = first_pivot.iloc[:,0]
retention_matrix = first_pivot.divide(size, axis = 0)

# %% [markdown]
# ### ii. Visualize analysis of cohort 1 using seaborn and matplotlib modules

# %%
import matplotlib.colors as mcolors

with sns.axes_style("white"):
    fig, ax = plt.subplots(1, 2, figsize=(14, 8), sharey=True, gridspec_kw={'width_ratios': [1, 11]})
    
    # retention matrix
    sns.heatmap(retention_matrix, 
                mask=retention_matrix.isnull(), 
                annot=True, 
                fmt='.0%', 
                cmap='viridis',
                ax=ax[1])
    ax[1].set_title('Monthly Cohorts: User Retention', fontsize=15, pad=13)
    ax[1].set(xlabel='# of periods',
              ylabel='')

    # cohort size
    cohort_size_df = pd.DataFrame(size).rename(columns={1: 'cohort_size'})
    white_cmap = mcolors.ListedColormap(['white'])
    sns.heatmap(cohort_size_df, 
                annot=True, 
                cbar=False, 
                fmt='g', 
                cmap=white_cmap, 
                ax=ax[0])

    fig.tight_layout()

# %%
plt.figure(figsize=(12, 5))
g = sns.lineplot(data=first_pivot[1].values)
g.set_xticks(range(13)), g.set_xticklabels(first_pivot.index);

# %% [markdown]
# ## Create the 2nd Cohort: Average Quantity Sold

# %% [markdown]
# ### i. Pivot Cohort and Cohort Retention

# %%
second_cohort = cohort_df.groupby(['CohortMonth', 'CohortIndex'])['Quantity'].mean().reset_index()
second_cohort.head()
# Out:
#   CohortMonth  CohortIndex   Quantity
# 0     2010-12            1  11.363842
# 1     2010-12            2  12.862197
# 2     2010-12            3  13.931012
# 3     2010-12            4  13.873829
# 4     2010-12            5  13.343757

# %%
second_pivot = second_cohort.pivot(index='CohortMonth', columns='CohortIndex', values='Quantity').round(2)
second_pivot
# Out:
# CohortIndex     1      2      3      4      5      6      7       8      9   \
# CohortMonth
# 2010-12      11.36  12.86  13.93  13.87  13.34  13.29  14.27   13.77  16.15
# 2011-01      18.08   9.63   9.44  15.10  10.09  10.89  13.55   10.81  10.76
# 2011-02      11.00  14.05  15.96  12.13  12.32  11.93  13.87   13.72  11.00
# 2011-03       9.69  11.43  13.31  10.09  13.53  12.84  13.11   14.06  11.21
# 2011-04      10.07  10.16   9.72  11.94  11.86   8.26   9.87    9.36   7.48
# 2011-05      10.66   9.39  14.86  12.80  11.05   8.31  10.82  126.91    NaN
# 2011-06       9.55  14.79  11.98  12.74   9.82   8.89   9.35     NaN    NaN
# 2011-07      10.15  14.98   6.57   8.11   5.78   6.68    NaN     NaN    NaN
# 2011-08       9.39   6.03   5.03   5.91   6.56    NaN    NaN     NaN    NaN
# 2011-09      11.93   6.14   7.85   9.01    NaN    NaN    NaN     NaN    NaN
# 2011-10       8.71   7.23   8.19    NaN    NaN    NaN    NaN     NaN    NaN
# ...

# %%
avg_quantity_sold = second_pivot.iloc[:,0]
retention_matrix2 = second_pivot.divide(avg_quantity_sold, axis=0)

# %% [markdown]
# ### ii. Visualize analysis of cohort 2 using seaborn and matplotlib modules

# %%
with sns.axes_style("white"):
    fig, ax = plt.subplots(1, 2, figsize=(14, 8), sharey=True, gridspec_kw={'width_ratios': [1, 11]})
    
    sns.heatmap(retention_matrix2, 
                mask=retention_matrix2.isnull(), 
                annot=True, 
                fmt='.0%', 
                cmap='viridis', 
                ax=ax[1])
    ax[1].set_title('Monthly Cohorts: Average Quantity Sold', fontsize=15, pad=13)
    ax[1].set(xlabel='# of periods',
              ylabel='')

    avg_quantity_df = pd.DataFrame(avg_quantity_sold).rename(columns={1: 'Avg. Quantity Sold'})
    white_cmap = mcolors.ListedColormap(['white'])
    sns.heatmap(avg_quantity_df, 
                annot=True, 
                cbar=False, 
                fmt='g', 
                cmap=white_cmap, 
                ax=ax[0])

    fig.tight_layout()

# %%
plt.figure(figsize=(14, 8))
plt.title('Average Quantity')
sns.heatmap(data=second_pivot, annot=True, cmap='Greens', fmt='g');

# %% [markdown]
# ## Create the 3rd Cohort: Average Sales

# %% [markdown]
# ### i. Pivot Cohort and Cohort Retention

# %%
third_cohort = cohort_df.groupby(['CohortMonth', 'CohortIndex'])['TotalPrice'].mean().reset_index()
third_cohort.head()
# Out:
#   CohortMonth  CohortIndex  TotalPrice
# 0     2010-12            1   21.164521
# 1     2010-12            2   22.435683
# 2     2010-12            3   23.966176
# 3     2010-12            4   23.761526
# 4     2010-12            5   20.249368

# %%
third_pivot = third_cohort.pivot(index='CohortMonth', columns='CohortIndex', values='TotalPrice').round(2)
third_pivot
# Out:
# CohortIndex     1      2      3      4      5      6      7       8      9   \
# CohortMonth
# 2010-12      21.16  22.44  23.97  23.76  20.25  25.82  25.98   23.91  26.25
# 2011-01      26.73  18.77  15.37  28.20  18.57  19.14  24.18   17.80  17.80
# 2011-02      16.97  20.13  19.37  19.16  17.55  16.12  21.25   22.96  18.23
# 2011-03      16.72  20.17  22.71  17.66  20.56  18.41  20.71   19.81  16.48
# 2011-04      16.55  20.09  19.25  18.67  19.08  14.13  14.93   15.30  11.55
# 2011-05      18.05  16.99  22.00  21.07  18.70  13.49  16.65  261.76    NaN
# 2011-06      22.90  15.23  19.64  16.55  13.33  13.31  12.73     NaN    NaN
# 2011-07      14.86  24.68  10.28  12.90   9.28   9.35    NaN     NaN    NaN
# 2011-08      15.16  13.01  12.07  15.63  17.11    NaN    NaN     NaN    NaN
# 2011-09      18.26  11.50  13.65  13.97    NaN    NaN    NaN     NaN    NaN
# 2011-10      13.49  11.14  13.77    NaN    NaN    NaN    NaN     NaN    NaN
# ...

# %%
average_sales = third_pivot.iloc[:,0]
retention_matrix3 = third_pivot.divide(average_sales, axis=0)

# %% [markdown]
# ### ii. Visualize analysis of cohort 3 using seaborn and matplotlib modules

# %%
with sns.axes_style("white"):
    fig, ax = plt.subplots(1, 2, figsize=(13, 8), sharey=True, gridspec_kw={'width_ratios': [1, 11]})
    
    sns.heatmap(retention_matrix3, 
                mask=retention_matrix3.isnull(), 
                annot=True, 
                fmt='.0%', 
                cmap='viridis', 
                ax=ax[1])
    ax[1].set_title('Monthly Cohorts: Average Sales', fontsize=15, pad=13)
    ax[1].set(xlabel='# of periods',
              ylabel='')

    avg_sales_df = pd.DataFrame(average_sales).rename(columns={1: 'Average Sales'})
    white_cmap = mcolors.ListedColormap(['white'])
    sns.heatmap(avg_sales_df, 
                annot=True, 
                cbar=False, 
                fmt='g', 
                cmap=white_cmap, 
                ax=ax[0])

    fig.tight_layout()

# %%
plt.figure(figsize=(13,8))
plt.title('Average Revenue', size=13)
sns.heatmap(data=third_pivot, annot=True, cmap='Paired', fmt='g');

# %% [markdown]
# For e-commerce organisations, cohort analysis is a unique opportunity to find out which clients are the most valuable to their business. by performing Cohort analysis you can get answers to following questions:
#
# - How much effective was a marketing campaign held in a particular time period?
# - Did the strategy employed to improve the conversion rates of Customers worked?
# - Should I focus more on retention rather than acquiring new customers?
# - Are my customer nurturing strategies effective?
# - Which marketing channels bring me the best results?
# - Is there a seasoanlity pattern in Customer behahiour?

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
