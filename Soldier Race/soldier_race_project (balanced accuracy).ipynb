# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # WELCOME!

# %% [markdown]
# In this project, you must apply EDA processes for the development of predictive models. Handling outliers, domain knowledge and feature engineering will be challenges.
#
# Also, this project aims to improve your ability to implement algorithms for Multi-Class Classification. Thus, you will have the opportunity to implement many algorithms commonly used for Multi-Class Classification problems.
#
# Before diving into the project, please take a look at the determines and tasks.

# %% [markdown]
# # Determines

# %% [markdown]
# The 2012 US Army Anthropometric Survey (ANSUR II) was executed by the Natick Soldier Research, Development and Engineering Center (NSRDEC) from October 2010 to April 2012 and is comprised of personnel representing the total US Army force to include the US Army Active Duty, Reserves, and National Guard. In addition to the anthropometric and demographic data described below, the ANSUR II database also consists of 3D whole body, foot, and head scans of Soldier participants. These 3D data are not publicly available out of respect for the privacy of ANSUR II participants. The data from this survey are used for a wide range of equipment design, sizing, and tariffing applications within the military and has many potential commercial, industrial, and academic applications.
#
# The ANSUR II working databases contain 93 anthropometric measurements which were directly measured, and 15 demographic/administrative variables explained below. The ANSUR II Male working database contains a total sample of 4,082 subjects. The ANSUR II Female working database contains a total sample of 1,986 subjects.
#
#
# DATA DICT:
# https://data.world/datamil/ansur-ii-data-dictionary/workspace/file?filename=ANSUR+II+Databases+Overview.pdf
#
# ---
#
# To achieve high prediction success, you must understand the data well and develop different approaches that can affect the dependent variable.
#
# Firstly, try to understand the dataset column by column using pandas module. Do research within the scope of domain (body scales, and race characteristics) knowledge on the internet to get to know the data set in the fastest way.
#
# You will implement ***Logistic Regression, Support Vector Machine, XGBoost, Random Forest*** algorithms. Also, evaluate the success of your models with appropriate performance metrics.
#
# At the end of the project, choose the most successful model and try to enhance the scores with ***SMOTE*** make it ready to deploy. Furthermore, use ***SHAP*** to explain how the best model you choose works.

# %% [markdown]
# # Tasks

# %% [markdown]
# #### 1. Exploratory Data Analysis (EDA)
# - Import Libraries, Load Dataset, Exploring Data
#
#     *i. Import Libraries*
#
#     *ii. Ingest Data*
#
#     *iii. Explore Data*
#
#     *iv. Outlier Detection*
#
#     *v.  Drop unnecessary features*
#
# #### 2. Data Preprocessing
# - Scale (if needed)
# - Separete the data frame for evaluation purposes
#
# #### 3. Multi-class Classification
# - Import libraries
# - Implement SVM Classifer
# - Implement Decision Tree Classifier
# - Implement Random Forest Classifer
# - Implement XGBoost Classifer
# - Compare The Models

# %% [markdown]
# # EDA
# - Drop unnecessary colums
# - Drop DODRace class if value count below 500 (we assume that our data model can't learn if it is below 500)

# %% [markdown]
# ## Import Libraries
# Besides Numpy and Pandas, you need to import the necessary modules for data visualization, data preprocessing, Model building and tuning.
#
# *Note: Check out the course materials.*

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import pyforest
import plotly
import cufflinks as cf

#Enabling the offline mode for interactive plotting locally
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot
init_notebook_mode(connected=True)
cf.go_offline()

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score, make_scorer
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import plot_roc_curve, plot_precision_recall_curve, roc_auc_score, auc, roc_curve
from sklearn.metrics import average_precision_score, precision_recall_curve
from sklearn.metrics import classification_report, confusion_matrix, plot_confusion_matrix
from sklearn.model_selection import train_test_split, cross_val_score, cross_validate, GridSearchCV

from yellowbrick.classifier import ROCAUC, PrecisionRecallCurve

# Libraries for Style
from colorama import Fore
from colorama import Style

import warnings
warnings.filterwarnings('ignore')

plt.rcParams["figure.figsize"] = (8,5)

pd.set_option('display.max_rows', 300)
pd.set_option('display.max_columns', 300)
pd.set_option('display.width', 100)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Ingest Data from links below and make a dataframe
# - Soldiers Male : https://query.data.world/s/h3pbhckz5ck4rc7qmt2wlknlnn7esr
# - Soldiers Female : https://query.data.world/s/sq27zz4hawg32yfxksqwijxmpwmynq

# %%
df_male = pd.read_csv("ANSUR II FEMALE Public.csv", encoding='latin-1')
df_male.head()
# Out:
#    SubjectId  abdominalextensiondepthsitting  acromialheight  acromionradialelength  \
# 0      10037                             231            1282                    301
# 1      10038                             194            1379                    320
# 2      10042                             183            1369                    329
# 3      10043                             261            1356                    306
# 4      10051                             309            1303                    308
#
#    anklecircumference  axillaheight  balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0                 204          1180                      222               177                373
# 1                 207          1292                      225               178                372
# 2                 233          1271                      237               196                397
# 3                 214          1250                      240               188                384
# 4                 214          1210                      217               182                378
#
#    bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  bimalleolarbreadth  \
# 0                        315               263               466                  65
# 1                        272               250               430                  64
# 2                        300               276               450                  69
# 3                        364               276               484                  68
# 4                        320               336               525                  67
#
#    bitragionchinarc  bitragionsubmandibulararc  bizygomaticbreadth  buttockcircumference  \
# 0               338                        301                 141                  1011
# 1               294                        270                 126                   893
# 2               309                        270                 128                   987
# 3               340                        294                 144                  1012
# 4               300                        295                 135                  1281
#
#    buttockdepth  buttockheight  buttockkneelength  buttockpopliteallength  calfcircumference  \
# 0           223            836                587                     476                360
# 1           186            900                583                     483                350
# 2           204            861                583                     466                384
# 3           253            897                599                     471                372
# 4           284            811                607                     467                433
#
#    cervicaleheight  chestbreadth  chestcircumference  chestdepth  chestheight  crotchheight  \
# 0             1336           274                 922         245         1095           759
# 1             1440           261                 839         206         1234           835
# 2             1451           287                 874         223         1226           821
# 3             1430           269                1008         285         1170           804
# 4             1362           305                1089         290         1112           726
#
#    crotchlengthomphalion  crotchlengthposterioromphalion  earbreadth  earlength  earprotrusion  \
# 0                    557                             310          35         65             16
# 1                    549                             329          32         60             23
# 2                    643                             374          36         65             26
# 3                    640                             351          38         62             22
# 4                    686                             356          34         65             18
#
#    elbowrestheight  eyeheightsitting  footbreadthhorizontal  footlength  \
# 0              220               713                     91         246
# 1              208               726                     91         249
# 2              204               790                    100         265
# 3              244               775                     97         265
# 4              233               732                     88         247
#
#    forearmcenterofgriplength  forearmcircumferenceflexed  forearmforearmbreadth  \
# 0                        316                         265                    517
# 1                        341                         247                    468
# 2                        343                         262                    488
# 3                        331                         309                    529
# 4                        339                         260                    596
#
#    forearmhandlength  functionalleglength  handbreadth  handcircumference  handlength  \
# 0                432                 1028           75                182         184
# 1                463                 1117           78                187         189
# 2                469                 1060           84                198         195
# 3                455                 1069           80                192         186
# 4                447                 1039           78                183         187
#
#    headbreadth  headcircumference  headlength  heelanklecircumference  heelbreadth  hipbreadth  \
# 0          141                548         191                     314           69         345
# 1          138                535         180                     307           60         315
# 2          146                588         207                     331           70         356
# 3          153                593         206                     332           68         337
# 4          140                522         181                     308           63         448
#
#    hipbreadthsitting  iliocristaleheight  interpupillarybreadth  interscyei  interscyeii  \
# 0                388                 966                    645         363          399
# 1                335                1048                    595         340          375
# 2                399                1043                    655         345          399
# 3                402                1029                    655         392          435
# 4                499                 964                    635         428          435
#
#    kneeheightmidpatella  kneeheightsitting  lateralfemoralepicondyleheight  \
# 0                   435                496                             447
# 1                   483                532                             492
# 2                   470                530                             469
# 3                   469                520                             478
# 4                   440                491                             441
#
#    lateralmalleolusheight  lowerthighcircumference  mentonsellionlength  neckcircumference  \
# 0                      55                      404                  118                335
# 1                      69                      334                  115                302
# 2                      64                      401                  135                325
# 3                      67                      402                  118                357
# 4                      63                      479                  114                340
#
#    neckcircumferencebase  overheadfingertipreachsitting  palmlength  poplitealheight  \
# 0                    368                           1268         113              362
# 1                    345                           1389         110              426
# 2                    369                           1414         122              398
# 3                    386                           1329         115              394
# 4                    358                           1350         116              345
#
#    radialestylionlength  shouldercircumference  shoulderelbowlength  shoulderlength  \
# 0                   235                   1062                  327             148
# 1                   259                   1014                  346             142
# 2                   258                   1049                  362             164
# 3                   250                   1121                  333             157
# 4                   242                   1151                  329             156
#
#    sittingheight  sleevelengthspinewrist  sleeveoutseam  span  stature  suprasternaleheight  \
# 0            803                     809            513  1647     1560                 1280
# 1            835                     810            575  1751     1665                 1372
# 2            904                     855            568  1779     1711                 1383
# 3            875                     815            536  1708     1660                 1358
# 4            824                     810            559  1702     1572                 1292
#
#    tenthribheight  thighcircumference  thighclearance  thumbtipreach  tibialheight  \
# 0            1013                 622             174            736           430
# 1            1107                 524             152            771           475
# 2            1089                 577             164            814           458
# 3            1065                 679             187            736           463
# 4            1030                 766             197            766           429
#
#    tragiontopofhead  trochanterionheight  verticaltrunkcircumferenceusa  waistbacklength  \
# 0               110                  844                           1488              406
# 1               125                  901                           1470              422
# 2               129                  882                           1542              419
# 3               125                  866                           1627              451
# 4               116                  800                           1698              452
#
#    waistbreadth  waistcircumference  waistdepth  waistfrontlengthsitting  waistheightomphalion  \
# 0           295                 850         217                      345                   942
# 1           254                 708         168                      329                  1032
# 2           269                 727         159                      367                  1035
# 3           302                 923         235                      371                   999
# 4           405                1163         300                      380                   911
#
#    weightkg  wristcircumference  wristheight  Gender      Date Installation     Component  \
# 0       657                 152          756  Female  5-Oct-10    Fort Hood  Regular Army
# 1       534                 155          815  Female  5-Oct-10    Fort Hood  Regular Army
# 2       663                 162          799  Female  5-Oct-10    Fort Hood  Regular Army
# 3       782                 173          818  Female  5-Oct-10    Fort Hood  Regular Army
# 4       886                 152          762  Female  5-Oct-10    Fort Hood  Regular Army
#
#                    Branch PrimaryMOS SubjectsBirthLocation  SubjectNumericRace  \
# 0          Combat Support        92Y               Germany                   2
# 1  Combat Service Support        25U            California                   3
# 2  Combat Service Support        35D                 Texas                   1
# 3  Combat Service Support        25U  District of Columbia                   8
# 4             Combat Arms        42A                 Texas                   1
#
#             Ethnicity  DODRace  Age  Heightin  Weightlbs WritingPreference
# 0                 NaN        2   26        61        142        Right hand
# 1             Mexican        3   21        64        120        Right hand
# 2                 NaN        1   23        68        147        Right hand
# 3  Caribbean Islander        2   22        66        175        Right hand
# 4                 NaN        1   45        63        195        Right hand

# %%
df_female = pd.read_csv("ANSUR II MALE Public.csv", encoding='latin-1')
df_female.head()
# Out:
#    subjectid  abdominalextensiondepthsitting  acromialheight  acromionradialelength  \
# 0      10027                             266            1467                    337
# 1      10032                             233            1395                    326
# 2      10033                             287            1430                    341
# 3      10092                             234            1347                    310
# 4      10093                             250            1585                    372
#
#    anklecircumference  axillaheight  balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0                 222          1347                      253               202                401
# 1                 220          1293                      245               193                394
# 2                 230          1327                      256               196                427
# 3                 230          1239                      262               199                401
# 4                 247          1478                      267               224                435
#
#    bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  bimalleolarbreadth  \
# 0                        369               274               493                  71
# 1                        338               257               479                  67
# 2                        408               261               544                  75
# 3                        359               262               518                  73
# 4                        356               263               524                  80
#
#    bitragionchinarc  bitragionsubmandibulararc  bizygomaticbreadth  buttockcircumference  \
# 0               319                        291                 142                   979
# 1               344                        320                 135                   944
# 2               345                        330                 135                  1054
# 3               328                        309                 143                   991
# 4               340                        310                 138                  1029
#
#    buttockdepth  buttockheight  buttockkneelength  buttockpopliteallength  calfcircumference  \
# 0           240            882                619                     509                373
# 1           232            870                584                     468                357
# 2           258            901                623                     506                412
# 3           242            821                560                     437                395
# 4           275           1080                706                     567                425
#
#    cervicaleheight  chestbreadth  chestcircumference  chestdepth  chestheight  crotchheight  \
# 0             1535           291                1074         259         1292           877
# 1             1471           269                1021         253         1244           851
# 2             1501           288                1120         267         1288           854
# 3             1423           296                1114         262         1205           769
# 4             1684           304                1048         232         1452          1014
#
#    crotchlengthomphalion  crotchlengthposterioromphalion  earbreadth  earlength  earprotrusion  \
# 0                    607                             351          36         71             19
# 1                    615                             376          33         62             18
# 2                    636                             359          40         61             23
# 3                    590                             341          39         66             25
# 4                    682                             382          32         56             19
#
#    elbowrestheight  eyeheightsitting  footbreadthhorizontal  footlength  \
# 0              247               802                    101         273
# 1              232               781                     98         263
# 2              237               810                    103         270
# 3              272               794                    106         267
# 4              188               814                    111         305
#
#    forearmcenterofgriplength  forearmcircumferenceflexed  forearmforearmbreadth  \
# 0                        349                         299                    575
# 1                        348                         289                    523
# 2                        355                         357                    575
# 3                        352                         318                    593
# 4                        399                         324                    605
#
#    forearmhandlength  functionalleglength  handbreadth  handcircumference  handlength  \
# 0                477                 1136           90                214         193
# 1                476                 1096           86                203         195
# 2                491                 1115           93                220         203
# 3                467                 1034           91                217         194
# 4                550                 1279           94                222         218
#
#    headbreadth  headcircumference  headlength  heelanklecircumference  heelbreadth  hipbreadth  \
# 0          150                583         206                     326           70         332
# 1          146                568         201                     334           72         312
# 2          148                573         202                     356           70         349
# 3          158                576         199                     341           68         338
# 4          153                566         197                     374           69         332
#
#    hipbreadthsitting  iliocristaleheight  interpupillarybreadth  interscyei  interscyeii  \
# 0                366                1071                    685         422          441
# 1                356                1046                    620         441          447
# 2                393                1053                    665         462          475
# 3                367                 986                    640         458          461
# 4                372                1251                    675         481          505
#
#    kneeheightmidpatella  kneeheightsitting  lateralfemoralepicondyleheight  \
# 0                   502                560                             500
# 1                   490                540                             488
# 2                   496                556                             482
# 3                   460                511                             452
# 4                   612                666                             585
#
#    lateralmalleolusheight  lowerthighcircumference  mentonsellionlength  neckcircumference  \
# 0                      77                      391                  118                400
# 1                      73                      371                  131                380
# 2                      72                      409                  123                403
# 3                      76                      393                  106                407
# 4                      85                      458                  135                398
#
#    neckcircumferencebase  overheadfingertipreachsitting  palmlength  poplitealheight  \
# 0                    436                           1447         113              437
# 1                    420                           1380         118              417
# 2                    434                           1447         121              431
# 3                    446                           1357         118              393
# 4                    430                           1572         132              523
#
#    radialestylionlength  shouldercircumference  shoulderelbowlength  shoulderlength  \
# 0                   273                   1151                  368             145
# 1                   254                   1119                  353             141
# 2                   268                   1276                  367             167
# 3                   249                   1155                  330             148
# 4                   302                   1231                  400             180
#
#    sittingheight  sleevelengthspinewrist  sleeveoutseam  span  stature  suprasternaleheight  \
# 0            928                     883            600  1782     1776                 1449
# 1            884                     868            564  1745     1702                 1387
# 2            917                     910            604  1867     1735                 1438
# 3            903                     848            550  1708     1655                 1346
# 4            919                     995            641  2035     1914                 1596
#
#    tenthribheight  thighcircumference  thighclearance  thumbtipreach  tibialheight  \
# 0            1092                 610             164            786           491
# 1            1076                 572             169            822           476
# 2            1105                 685             198            807           477
# 3            1021                 604             180            803           445
# 4            1292                 672             194            962           584
#
#    tragiontopofhead  trochanterionheight  verticaltrunkcircumferenceusa  waistbacklength  \
# 0               140                  919                           1700              501
# 1               120                  918                           1627              432
# 2               125                  918                           1678              472
# 3               127                  847                           1625              461
# 4               122                 1090                           1679              467
#
#    waistbreadth  waistcircumference  waistdepth  waistfrontlengthsitting  waistheightomphalion  \
# 0           329                 933         240                      440                  1054
# 1           316                 870         225                      371                  1054
# 2           329                 964         255                      411                  1041
# 3           315                 857         205                      399                   968
# 4           303                 868         214                      379                  1245
#
#    weightkg  wristcircumference  wristheight Gender       Date Installation     Component  \
# 0       815                 175          853   Male   4-Oct-10    Fort Hood  Regular Army
# 1       726                 167          815   Male   4-Oct-10    Fort Hood  Regular Army
# 2       929                 180          831   Male   4-Oct-10    Fort Hood  Regular Army
# 3       794                 176          793   Male  12-Oct-10    Fort Hood  Regular Army
# 4       946                 188          954   Male  12-Oct-10    Fort Hood  Regular Army
#
#                    Branch PrimaryMOS SubjectsBirthLocation  SubjectNumericRace Ethnicity  DODRace  \
# 0             Combat Arms        19D          North Dakota                   1       NaN        1
# 1          Combat Support        68W              New York                   1       NaN        1
# 2          Combat Support        68W              New York                   2       NaN        2
# 3  Combat Service Support        88M             Wisconsin                   1       NaN        1
# 4  Combat Service Support        92G        North Carolina                   2       NaN        2
#
#    Age  Heightin  Weightlbs WritingPreference
# 0   41        71        180        Right hand
# 1   35        68        160         Left hand
# 2   42        68        205         Left hand
# 3   31        66        175        Right hand
# 4   21        77        213        Right hand

# %%
df_male.shape, df_female.shape
# Out:
# ((1986, 108), (4082, 108))

# %%
df_male.columns = df_male.columns.str.strip().str.title()
df_female.columns = df_female.columns.str.strip().str.title()

# %%
index_list = []
for x in range(108):
    if df_male.columns[x] != df_female.columns[x]:
        index_list.append(x)
        
print(index_list)
# Out:
# []

# %%
soldiers = pd.concat([df_male, df_female], axis=0, ignore_index=True)
df = soldiers.copy()

# %% [markdown]
# ## Explore Data

# %%
df
# Out:
#       Subjectid  Abdominalextensiondepthsitting  Acromialheight  Acromionradialelength  \
# 0         10037                             231            1282                    301
# 1         10038                             194            1379                    320
# 2         10042                             183            1369                    329
# 3         10043                             261            1356                    306
# 4         10051                             309            1303                    308
# ...         ...                             ...             ...                    ...
# 6063      29442                             235            1353                    312
# 6064      29443                             247            1473                    336
# 6065      29447                             264            1394                    313
# 6066      29451                             203            1417                    327
# 6067      29452                             327            1523                    358
#
#       Anklecircumference  Axillaheight  Balloffootcircumference  Balloffootlength  \
# 0                    204          1180                      222               177
# 1                    207          1292                      225               178
# 2                    233          1271                      237               196
# 3                    214          1250                      240               188
# 4                    214          1210                      217               182
# ...                  ...           ...                      ...               ...
# 6063                 216          1263                      228               193
# 6064                 234          1346                      253               196
# 6065                 227          1280                      245               193
# 6066                 223          1314                      250               196
# 6067                 226          1408                      269               225
#
#       Biacromialbreadth  Bicepscircumferenceflexed  Bicristalbreadth  Bideltoidbreadth  \
# 0                   373                        315               263               466
# 1                   372                        272               250               430
# 2                   397                        300               276               450
# 3                   384                        364               276               484
# 4                   378                        320               336               525
# ...                 ...                        ...               ...               ...
# 6063                384                        318               241               457
# 6064                428                        374               284               536
# 6065                407                        367               271               501
# 6066                419                        365               271               493
# 6067                442                        379               275               531
#
#       Bimalleolarbreadth  Bitragionchinarc  Bitragionsubmandibulararc  Bizygomaticbreadth  \
# 0                     65               338                        301                 141
# 1                     64               294                        270                 126
# 2                     69               309                        270                 128
# 3                     68               340                        294                 144
# 4                     67               300                        295                 135
# ...                  ...               ...                        ...                 ...
# 6063                  70               321                        301                 137
# 6064                  76               319                        316                 135
# 6065                  74               323                        316                 142
# 6066                  75               342                        327                 138
# 6067                  81               359                        364                 150
#
#       Buttockcircumference  Buttockdepth  Buttockheight  Buttockkneelength  \
# 0                     1011           223            836                587
# 1                      893           186            900                583
# 2                      987           204            861                583
# 3                     1012           253            897                599
# 4                     1281           284            811                607
# ...                    ...           ...            ...                ...
# 6063                   917           231            878                587
# 6064                  1049           252            899                632
# 6065                  1038           276            857                614
# 6066                   929           209            898                598
# 6067                  1009           254            981                659
#
#       Buttockpopliteallength  Calfcircumference  Cervicaleheight  Chestbreadth  \
# 0                        476                360             1336           274
# 1                        483                350             1440           261
# 2                        466                384             1451           287
# 3                        471                372             1430           269
# 4                        467                433             1362           305
# ...                      ...                ...              ...           ...
# 6063                     497                345             1444           266
# 6064                     517                399             1533           323
# 6065                     502                378             1469           290
# 6066                     499                389             1483           284
# 6067                     550                396             1595           308
#
#       Chestcircumference  Chestdepth  Chestheight  Crotchheight  Crotchlengthomphalion  \
# 0                    922         245         1095           759                    557
# 1                    839         206         1234           835                    549
# 2                    874         223         1226           821                    643
# 3                   1008         285         1170           804                    640
# 4                   1089         290         1112           726                    686
# ...                  ...         ...          ...           ...                    ...
# 6063                 954         238         1231           807                    606
# 6064                1072         242         1301           848                    695
# 6065                1045         247         1263           787                    668
# 6066                 984         228         1271           846                    603
# 6067                1144         281         1349           931                    637
#
#       Crotchlengthposterioromphalion  Earbreadth  Earlength  Earprotrusion  Elbowrestheight  \
# 0                                310          35         65             16              220
# 1                                329          32         60             23              208
# 2                                374          36         65             26              204
# 3                                351          38         62             22              244
# 4                                356          34         65             18              233
# ...                              ...         ...        ...            ...              ...
# 6063                             306          36         61             22              195
# 6064                             378          35         60             20              299
# 6065                             337          38         62             26              257
# 6066                             314          37         61             22              237
# 6067                             313          36         61             24              214
#
#       Eyeheightsitting  Footbreadthhorizontal  Footlength  Forearmcenterofgriplength  \
# 0                  713                     91         246                        316
# 1                  726                     91         249                        341
# 2                  790                    100         265                        343
# 3                  775                     97         265                        331
# 4                  732                     88         247                        339
# ...                ...                    ...         ...                        ...
# 6063               762                     95         255                        329
# 6064               807                    103         263                        341
# 6065               784                    101         263                        340
# 6066               782                     98         266                        322
# 6067               780                    111         295                        377
#
#       Forearmcircumferenceflexed  Forearmforearmbreadth  Forearmhandlength  Functionalleglength  \
# 0                            265                    517                432                 1028
# 1                            247                    468                463                 1117
# 2                            262                    488                469                 1060
# 3                            309                    529                455                 1069
# 4                            260                    596                447                 1039
# ...                          ...                    ...                ...                  ...
# 6063                         277                    533                460                 1073
# 6064                         327                    600                476                 1088
# 6065                         312                    540                455                 1045
# 6066                         299                    552                461                 1091
# 6067                         317                    601                519                 1212
#
#       Handbreadth  Handcircumference  Handlength  Headbreadth  Headcircumference  Headlength  \
# 0              75                182         184          141                548         191
# 1              78                187         189          138                535         180
# 2              84                198         195          146                588         207
# 3              80                192         186          153                593         206
# 4              78                183         187          140                522         181
# ...           ...                ...         ...          ...                ...         ...
# 6063           81                193         182          151                554         187
# 6064           94                222         191          149                558         196
# 6065           83                207         183          148                555         194
# 6066           92                218         192          150                560         197
# 6067           95                223         205          153                615         220
#
#       Heelanklecircumference  Heelbreadth  Hipbreadth  Hipbreadthsitting  Iliocristaleheight  \
# 0                        314           69         345                388                 966
# 1                        307           60         315                335                1048
# 2                        331           70         356                399                1043
# 3                        332           68         337                402                1029
# 4                        308           63         448                499                 964
# ...                      ...          ...         ...                ...                 ...
# 6063                     323           69         301                353                1025
# 6064                     327           67         356                395                1057
# 6065                     340           74         334                362                1032
# 6066                     326           65         320                352                1050
# 6067                     358           72         339                371                1127
#
#       Interpupillarybreadth  Interscyei  Interscyeii  Kneeheightmidpatella  Kneeheightsitting  \
# 0                       645         363          399                   435                496
# 1                       595         340          375                   483                532
# 2                       655         345          399                   470                530
# 3                       655         392          435                   469                520
# 4                       635         428          435                   440                491
# ...                     ...         ...          ...                   ...                ...
# 6063                    595         405          422                   474                523
# 6064                    590         468          473                   491                565
# 6065                    560         434          450                   464                527
# 6066                    630         440          445                   480                542
# 6067                    695         457          482                   544                596
#
#       Lateralfemoralepicondyleheight  Lateralmalleolusheight  Lowerthighcircumference  \
# 0                                447                      55                      404
# 1                                492                      69                      334
# 2                                469                      64                      401
# 3                                478                      67                      402
# 4                                441                      63                      479
# ...                              ...                     ...                      ...
# 6063                             476                      68                      371
# 6064                             510                      67                      420
# 6065                             466                      71                      413
# 6066                             489                      70                      364
# 6067                             536                      70                      410
#
#       Mentonsellionlength  Neckcircumference  Neckcircumferencebase  \
# 0                     118                335                    368
# 1                     115                302                    345
# 2                     135                325                    369
# 3                     118                357                    386
# 4                     114                340                    358
# ...                   ...                ...                    ...
# 6063                  123                378                    427
# 6064                  117                392                    430
# 6065                  118                416                    444
# 6066                  123                387                    414
# 6067                  136                439                    477
#
#       Overheadfingertipreachsitting  Palmlength  Poplitealheight  Radialestylionlength  \
# 0                              1268         113              362                   235
# 1                              1389         110              426                   259
# 2                              1414         122              398                   258
# 3                              1329         115              394                   250
# 4                              1350         116              345                   242
# ...                             ...         ...              ...                   ...
# 6063                           1304         112              418                   259
# 6064                           1433         114              447                   265
# 6065                           1310         110              407                   257
# 6066                           1388         115              432                   254
# 6067                           1399         116              464                   295
#
#       Shouldercircumference  Shoulderelbowlength  Shoulderlength  Sittingheight  \
# 0                      1062                  327             148            803
# 1                      1014                  346             142            835
# 2                      1049                  362             164            904
# 3                      1121                  333             157            875
# 4                      1151                  329             156            824
# ...                     ...                  ...             ...            ...
# 6063                   1096                  348             150            883
# 6064                   1199                  356             146            938
# 6065                   1181                  333             135            895
# 6066                   1162                  358             154            900
# 6067                   1231                  386             152            896
#
#       Sleevelengthspinewrist  Sleeveoutseam  Span  Stature  Suprasternaleheight  Tenthribheight  \
# 0                        809            513  1647     1560                 1280            1013
# 1                        810            575  1751     1665                 1372            1107
# 2                        855            568  1779     1711                 1383            1089
# 3                        815            536  1708     1660                 1358            1065
# 4                        810            559  1702     1572                 1292            1030
# ...                      ...            ...   ...      ...                  ...             ...
# 6063                     865            568  1688     1688                 1368            1079
# 6064                     903            606  1818     1765                 1456            1146
# 6065                     860            571  1642     1690                 1384            1096
# 6066                     874            576  1760     1718                 1405            1116
# 6067                     955            638  1885     1828                 1500            1208
#
#       Thighcircumference  Thighclearance  Thumbtipreach  Tibialheight  Tragiontopofhead  \
# 0                    622             174            736           430               110
# 1                    524             152            771           475               125
# 2                    577             164            814           458               129
# 3                    679             187            736           463               125
# 4                    766             197            766           429               116
# ...                  ...             ...            ...           ...               ...
# 6063                 579             162            758           447               140
# 6064                 662             171            785           472               135
# 6065                 605             178            750           439               127
# 6066                 544             170            779           453               118
# 6067                 622             196            861           509               135
#
#       Trochanterionheight  Verticaltrunkcircumferenceusa  Waistbacklength  Waistbreadth  \
# 0                     844                           1488              406           295
# 1                     901                           1470              422           254
# 2                     882                           1542              419           269
# 3                     866                           1627              451           302
# 4                     800                           1698              452           405
# ...                   ...                            ...              ...           ...
# 6063                  869                           1557              442           279
# 6064                  886                           1715              475           351
# 6065                  858                           1682              483           333
# 6066                  886                           1589              430           293
# 6067                  970                           1764              511           354
#
#       Waistcircumference  Waistdepth  Waistfrontlengthsitting  Waistheightomphalion  Weightkg  \
# 0                    850         217                      345                   942       657
# 1                    708         168                      329                  1032       534
# 2                    727         159                      367                  1035       663
# 3                    923         235                      371                   999       782
# 4                   1163         300                      380                   911       886
# ...                  ...         ...                      ...                   ...       ...
# 6063                 816         210                      347                  1016       675
# 6064                 978         235                      385                  1082       896
# 6065                 991         258                      353                  1011       832
# 6066                 783         192                      350                  1062       731
# 6067                1080         294                      389                  1119       985
#
#       Wristcircumference  Wristheight  Gender      Date Installation            Component  \
# 0                    152          756  Female  5-Oct-10    Fort Hood         Regular Army
# 1                    155          815  Female  5-Oct-10    Fort Hood         Regular Army
# 2                    162          799  Female  5-Oct-10    Fort Hood         Regular Army
# 3                    173          818  Female  5-Oct-10    Fort Hood         Regular Army
# 4                    152          762  Female  5-Oct-10    Fort Hood         Regular Army
# ...                  ...          ...     ...       ...          ...                  ...
# 6063                 163          778    Male  4-Apr-12  Camp Shelby  Army National Guard
# 6064                 178          873    Male  4-Apr-12  Camp Shelby  Army National Guard
# 6065                 178          822    Male  4-Apr-12  Camp Shelby  Army National Guard
# 6066                 172          837    Male  4-Apr-12  Camp Shelby  Army National Guard
# 6067                 182          894    Male  4-Apr-12  Camp Shelby  Army National Guard
#
#                       Branch Primarymos Subjectsbirthlocation  Subjectnumericrace  \
# 0             Combat Support        92Y               Germany                   2
# 1     Combat Service Support        25U            California                   3
# 2     Combat Service Support        35D                 Texas                   1
# 3     Combat Service Support        25U  District of Columbia                   8
# 4                Combat Arms        42A                 Texas                   1
# ...                      ...        ...                   ...                 ...
# 6063             Combat Arms        11B              Colorado                  51
# 6064             Combat Arms        91B              Oklahoma                   1
# 6065             Combat Arms        13B              Oklahoma                   1
# 6066             Combat Arms        13P              Oklahoma                   1
# 6067             Combat Arms        92Y              Oklahoma                   1
#
#                        Ethnicity  Dodrace  Age  Heightin  Weightlbs Writingpreference
# 0                            NaN        2   26        61        142        Right hand
# 1                        Mexican        3   21        64        120        Right hand
# 2                            NaN        1   23        68        147        Right hand
# 3             Caribbean Islander        2   22        66        175        Right hand
# 4                            NaN        1   45        63        195        Right hand
# ...                          ...      ...  ...       ...        ...               ...
# 6063  Blackfoot Cherokee Choctaw        1   22        67        160        Right hand
# 6064                         NaN        1   22        71        194        Right hand
# 6065                         NaN        1   23        67        186        Right hand
# 6066                         NaN        1   22        69        165        Right hand
# 6067                         NaN        1   38        73        218        Right hand
#
# [6068 rows x 108 columns]

# %%
df.shape
# Out:
# (6068, 108)

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6068 entries, 0 to 6067
# Data columns (total 108 columns):
#  #    Column                          Dtype
# ---   ------                          -----
#  0    Subjectid                       int64
#  1    Abdominalextensiondepthsitting  int64
#  2    Acromialheight                  int64
#  3    Acromionradialelength           int64
#  4    Anklecircumference              int64
#  5    Axillaheight                    int64
#  6    Balloffootcircumference         int64
#  7    Balloffootlength                int64
#  8    Biacromialbreadth               int64
#  9    Bicepscircumferenceflexed       int64
#  10   Bicristalbreadth                int64
#  11   Bideltoidbreadth                int64
#  12   Bimalleolarbreadth              int64
#  13   Bitragionchinarc                int64
#  14   Bitragionsubmandibulararc       int64
#  15   Bizygomaticbreadth              int64
#  16   Buttockcircumference            int64
#  17   Buttockdepth                    int64
#  18   Buttockheight                   int64
#  19   Buttockkneelength               int64
#  20   Buttockpopliteallength          int64
#  21   Calfcircumference               int64
#  22   Cervicaleheight                 int64
#  23   Chestbreadth                    int64
#  24   Chestcircumference              int64
#  25   Chestdepth                      int64
#  26   Chestheight                     int64
#  27   Crotchheight                    int64
#  28   Crotchlengthomphalion           int64
#  29   Crotchlengthposterioromphalion  int64
#  30   Earbreadth                      int64
#  31   Earlength                       int64
#  32   Earprotrusion                   int64
#  33   Elbowrestheight                 int64
#  34   Eyeheightsitting                int64
#  35   Footbreadthhorizontal           int64
#  36   Footlength                      int64
#  37   Forearmcenterofgriplength       int64
#  38   Forearmcircumferenceflexed      int64
#  39   Forearmforearmbreadth           int64
#  40   Forearmhandlength               int64
#  41   Functionalleglength             int64
#  42   Handbreadth                     int64
#  43   Handcircumference               int64
#  44   Handlength                      int64
#  45   Headbreadth                     int64
#  46   Headcircumference               int64
#  47   Headlength                      int64
#  48   Heelanklecircumference          int64
#  49   Heelbreadth                     int64
#  50   Hipbreadth                      int64
#  51   Hipbreadthsitting               int64
#  52   Iliocristaleheight              int64
#  53   Interpupillarybreadth           int64
#  54   Interscyei                      int64
#  55   Interscyeii                     int64
#  56   Kneeheightmidpatella            int64
#  57   Kneeheightsitting               int64
#  58   Lateralfemoralepicondyleheight  int64
#  59   Lateralmalleolusheight          int64
#  60   Lowerthighcircumference         int64
#  61   Mentonsellionlength             int64
#  62   Neckcircumference               int64
#  63   Neckcircumferencebase           int64
#  64   Overheadfingertipreachsitting   int64
#  65   Palmlength                      int64
#  66   Poplitealheight                 int64
#  67   Radialestylionlength            int64
#  68   Shouldercircumference           int64
#  69   Shoulderelbowlength             int64
#  70   Shoulderlength                  int64
#  71   Sittingheight                   int64
#  72   Sleevelengthspinewrist          int64
#  73   Sleeveoutseam                   int64
#  74   Span                            int64
#  75   Stature                         int64
#  76   Suprasternaleheight             int64
#  77   Tenthribheight                  int64
#  78   Thighcircumference              int64
#  79   Thighclearance                  int64
#  80   Thumbtipreach                   int64
#  81   Tibialheight                    int64
#  82   Tragiontopofhead                int64
#  83   Trochanterionheight             int64
#  84   Verticaltrunkcircumferenceusa   int64
#  85   Waistbacklength                 int64
#  86   Waistbreadth                    int64
#  87   Waistcircumference              int64
#  88   Waistdepth                      int64
#  89   Waistfrontlengthsitting         int64
#  90   Waistheightomphalion            int64
#  91   Weightkg                        int64
#  92   Wristcircumference              int64
#  93   Wristheight                     int64
#  94   Gender                          object
#  95   Date                            object
#  96   Installation                    object
#  97   Component                       object
#  98   Branch                          object
#  99   Primarymos                      object
#  100  Subjectsbirthlocation           object
#  101  Subjectnumericrace              int64
#  102  Ethnicity                       object
#  103  Dodrace                         int64
#  104  Age                             int64
#  105  Heightin                        int64
#  106  Weightlbs                       int64
#  107  Writingpreference               object
# dtypes: int64(99), object(9)
# memory usage: 5.0+ MB

# %%
df.dtypes.value_counts()
# Out:
# int64     99
# object     9
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 4647

# %%
for col in df.columns:
    if df[col].isnull().sum() != 0: print(col)
# Out:
# Ethnicity

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe().T
# Out:
#                                  count          mean           std      min       25%      50%  \
# Subjectid                       6068.0  20757.198418  13159.390894  10027.0  14841.75  20063.5
# Abdominalextensiondepthsitting  6068.0    246.468688     37.400106    155.0    219.00    242.0
# Acromialheight                  6068.0   1406.161338     79.091048   1115.0   1350.00   1410.0
# Acromionradialelength           6068.0    327.374423     20.720018    249.0    313.00    328.0
# Anklecircumference              6068.0    224.891397     16.051833    156.0    214.00    225.0
# Axillaheight                    6068.0   1299.608767     72.022286   1038.0   1249.00   1302.0
# Balloffootcircumference         6068.0    244.192650     16.845020    186.0    232.00    245.0
# Balloffootlength                6068.0    194.754614     13.516368    151.0    185.00    195.0
# Biacromialbreadth               6068.0    399.204186     30.236914    283.0    376.00    404.0
# Bicepscircumferenceflexed       6068.0    340.934245     41.519866    216.0    311.00    341.0
# Bicristalbreadth                6068.0    274.735003     19.221034    197.0    262.00    274.0
# Bideltoidbreadth                6068.0    490.754450     42.135535    357.0    460.00    492.0
# Bimalleolarbreadth              6068.0     72.252637      5.344590     55.0     68.00     72.0
# Bitragionchinarc                6068.0    324.896506     17.087501    267.0    314.00    326.0
# Bitragionsubmandibulararc       6068.0    306.636124     20.794166    245.0    292.00    307.0
# Bizygomaticbreadth              6068.0    139.723467      7.308457    116.0    135.00    140.0
# Buttockcircumference            6068.0   1020.084707     76.422643    737.0    968.00   1017.0
# Buttockdepth                    6068.0    241.619974     26.482986    168.0    222.00    241.0
# Buttockheight                   6068.0    870.152274     54.822574    656.0    832.00    868.0
# Buttockkneelength               6068.0    608.999176     33.792839    466.0    586.00    609.0
# Buttockpopliteallength          6068.0    497.097561     29.082390    367.0    477.00    497.0
# Calfcircumference               6068.0    386.041200     30.647180    266.0    364.75    385.0
# Cervicaleheight                 6068.0   1477.490442     84.323707   1184.0   1418.00   1484.0
# Chestbreadth                    6068.0    282.859097     20.659397    213.0    268.00    283.0
# Chestcircumference              6068.0   1022.098879    100.671751    695.0    949.00   1020.5
# Chestdepth                      6068.0    251.738464     26.777843    170.0    233.00    251.0
# Chestheight                     6068.0   1252.013184     79.583972    984.0   1196.00   1259.0
# Crotchheight                    6068.0    825.110086     54.748240    610.0    787.00    825.0
# Crotchlengthomphalion           6068.0    621.851681     45.332961    473.0    590.00    620.0
# Crotchlengthposterioromphalion  6068.0    351.315920     29.944868    243.0    330.00    350.0
# Earbreadth                      6068.0     35.132169      3.231469     25.0     33.00     35.0
# Earlength                       6068.0     62.625906      4.876264     46.0     59.00     62.0
# Earprotrusion                   6068.0     22.263349      3.172715     13.0     20.00     22.0
# Elbowrestheight                 6068.0    240.911338     28.509447    138.0    222.00    241.0
# Eyeheightsitting                6068.0    785.914469     41.865795    654.0    757.00    787.0
# Footbreadthhorizontal           6068.0     98.865359      6.657916     77.0     94.00     99.0
# Footlength                      6068.0    263.033619     17.390971    198.0    251.00    264.0
# Forearmcenterofgriplength       6068.0    338.766645     23.244742    258.0    322.00    340.0
# Forearmcircumferenceflexed      6068.0    295.010712     30.049715    200.0    272.00    297.0
# Forearmforearmbreadth           6068.0    552.075972     62.368049    376.0    505.00    553.0
# Forearmhandlength               6068.0    467.007086     30.034820    342.0    446.00    469.0
# Functionalleglength             6068.0   1102.049275     68.545784    835.0   1055.00   1104.0
# Handbreadth                     6068.0     84.953362      6.346510     67.0     80.00     86.0
# Handcircumference               6068.0    203.861404     15.551424    152.0    192.00    206.0
# Handlength                      6068.0    189.286585     11.505788    145.0    181.00    189.5
# Headbreadth                     6068.0    152.182762      6.235692    131.0    148.00    152.0
# Headcircumference               6068.0    570.035267     18.291139    500.0    557.00    570.0
# Headlength                      6068.0    196.334871      8.485374    168.0    191.00    197.0
# Heelanklecircumference          6068.0    332.622940     22.460776    258.0    316.00    334.0
# Heelbreadth                     6068.0     70.756922      5.932626     48.0     67.00     70.0
# Hipbreadth                      6068.0    348.385465     25.297828    264.0    332.00    347.0
# Hipbreadthsitting               6068.0    385.733355     32.399905    280.0    364.00    384.0
# Iliocristaleheight              6068.0   1040.059492     59.867016    816.0    998.00   1040.0
# Interpupillarybreadth           6068.0    632.602011     36.508997    510.0    610.00    635.0
# Interscyei                      6068.0    412.037739     43.065925    270.0    381.00    411.0
# Interscyeii                     6068.0    432.340804     38.658239    306.0    405.00    434.0
# Kneeheightmidpatella            6068.0    475.512854     33.074714    346.0    452.00    476.0
# Kneeheightsitting               6068.0    540.124918     34.203131    407.0    516.00    541.0
# Lateralfemoralepicondyleheight  6068.0    483.239618     29.359616    352.0    463.00    483.0
# Lateralmalleolusheight          6068.0     69.580422      7.270059     43.0     65.00     70.0
# Lowerthighcircumference         6068.0    406.479895     33.228317    290.0    384.00    405.0
# Mentonsellionlength             6068.0    119.518787      7.879897     91.0    114.00    120.0
# Neckcircumference               6068.0    375.441167     39.770240    275.0    342.00    380.0
# Neckcircumferencebase           6068.0    413.834707     38.156374    302.0    382.00    418.0
# Overheadfingertipreachsitting   6068.0   1388.404417     85.849174   1111.0   1327.00   1393.0
# Palmlength                      6068.0    113.916612      7.136566     88.0    109.00    114.0
# Poplitealheight                 6068.0    416.187047     31.266447    305.0    394.00    417.0
# Radialestylionlength            6068.0    259.192320     19.777577    169.0    245.00    260.0
# Shouldercircumference           6068.0   1129.362228     92.828849    852.0   1057.00   1139.0
# Shoulderelbowlength             6068.0    354.083553     22.598591    271.0    338.00    355.0
# Shoulderlength                  6068.0    145.072676     12.424295    107.0    137.00    145.0
# Sittingheight                   6068.0    898.107779     45.299042    750.0    866.00    900.0
# Sleevelengthspinewrist          6068.0    866.665293     57.524072    636.0    824.00    872.0
# Sleeveoutseam                   6068.0    576.899967     38.258587    410.0    550.00    578.0
# Span                            6068.0   1763.794825    110.832751   1323.0   1686.75   1771.0
# Stature                         6068.0   1714.406065     90.015336   1409.0   1651.75   1719.0
# Suprasternaleheight             6068.0   1402.949077     78.768058   1131.0   1348.00   1407.0
# Tenthribheight                  6068.0   1099.587179     60.540920    868.0   1057.00   1099.0
# Thighcircumference              6068.0    622.198748     57.750677    412.0    583.00    621.0
# Thighclearance                  6068.0    176.336355     16.220270    121.0    165.00    175.0
# Thumbtipreach                   6068.0    789.695616     53.823572    602.0    753.00    792.0
# Tibialheight                    6068.0    458.244562     29.759325    344.0    437.00    458.0
# Tragiontopofhead                6068.0    129.617996      6.659692    105.0    125.00    130.0
# Trochanterionheight             6068.0    882.739947     54.402819    660.0    845.00    882.0
# Verticaltrunkcircumferenceusa   6068.0   1630.309492     98.624125   1342.0   1558.00   1628.0
# Waistbacklength                 6068.0    460.524720     36.677909    345.0    435.00    463.0
# Waistbreadth                    6068.0    317.750000     36.363125    211.0    292.00    316.0
# Waistcircumference              6068.0    914.501483    114.274513    611.0    829.00    907.0
# Waistdepth                      6068.0    229.674028     35.613193    138.0    203.00    226.0
# Waistfrontlengthsitting         6068.0    377.003790     31.617723    289.0    355.00    375.0
# Waistheightomphalion            6068.0   1031.501154     62.702388    805.0    988.00   1033.0
# Weightkg                        6068.0    797.093935    156.528164    358.0    682.00    785.0
# Wristcircumference              6068.0    169.002966     13.124513    124.0    159.00    170.0
# Wristheight                     6068.0    830.059987     47.650519    672.0    797.00    830.0
# Subjectnumericrace              6068.0     17.515326    550.949948      1.0      1.00      1.0
# Dodrace                         6068.0      1.615030      0.979156      1.0      1.00      1.0
# Age                             6068.0     29.761206      8.674650     17.0     23.00     28.0
# Heightin                        6068.0     68.257251      3.861954     56.0     66.00     68.0
# Weightlbs                       6068.0    174.749670     33.691952      0.0    150.00    173.0
#
#                                      75%       max
# Subjectid                       27234.50  920103.0
# Abdominalextensiondepthsitting    271.00     451.0
# Acromialheight                   1462.00    1683.0
# Acromionradialelength             341.25     393.0
# Anklecircumference                235.00     293.0
# Axillaheight                     1349.00    1553.0
# Balloffootcircumference           256.00     306.0
# Balloffootlength                  204.00     245.0
# Biacromialbreadth                 421.00     489.0
# Bicepscircumferenceflexed         370.00     490.0
# Bicristalbreadth                  288.00     362.0
# Bideltoidbreadth                  520.00     637.0
# Bimalleolarbreadth                 76.00      91.0
# Bitragionchinarc                  336.00     385.0
# Bitragionsubmandibulararc         321.00     390.0
# Bizygomaticbreadth                145.00     174.0
# Buttockcircumference             1068.00    1341.0
# Buttockdepth                      259.00     349.0
# Buttockheight                     906.25    1080.0
# Buttockkneelength                 632.00     736.0
# Buttockpopliteallength            517.00     605.0
# Calfcircumference                 406.00     523.0
# Cervicaleheight                  1537.00    1738.0
# Chestbreadth                      297.00     363.0
# Chestcircumference               1092.00    1469.0
# Chestdepth                        270.00     383.0
# Chestheight                      1309.00    1506.0
# Crotchheight                      863.00    1031.0
# Crotchlengthomphalion             651.00     799.0
# Crotchlengthposterioromphalion    372.00     468.0
# Earbreadth                         37.00      46.0
# Earlength                          66.00      81.0
# Earprotrusion                      24.00      34.0
# Elbowrestheight                   261.00     345.0
# Eyeheightsitting                  815.00     912.0
# Footbreadthhorizontal             104.00     126.0
# Footlength                        276.00     323.0
# Forearmcenterofgriplength         355.00     416.0
# Forearmcircumferenceflexed        317.00     402.0
# Forearmforearmbreadth             597.00     778.0
# Forearmhandlength                 488.00     574.0
# Functionalleglength              1149.00    1316.0
# Handbreadth                        90.00     105.0
# Handcircumference                 215.00     248.0
# Handlength                        197.00     239.0
# Headbreadth                       156.00     180.0
# Headcircumference                 582.00     635.0
# Headlength                        202.00     225.0
# Heelanklecircumference            348.00     403.0
# Heelbreadth                        75.00      93.0
# Hipbreadth                        364.00     473.0
# Hipbreadthsitting                 406.00     541.0
# Iliocristaleheight               1081.00    1253.0
# Interpupillarybreadth             655.00     770.0
# Interscyei                        442.00     562.0
# Interscyeii                       460.00     577.0
# Kneeheightmidpatella              497.00     612.0
# Kneeheightsitting                 564.00     666.0
# Lateralfemoralepicondyleheight    503.00     594.0
# Lateralmalleolusheight             75.00      93.0
# Lowerthighcircumference           427.00     600.0
# Mentonsellionlength               125.00     156.0
# Neckcircumference                 404.00     514.0
# Neckcircumferencebase             442.00     545.0
# Overheadfingertipreachsitting    1449.00    1651.0
# Palmlength                        118.00     140.0
# Poplitealheight                   438.00     525.0
# Radialestylionlength              273.00     328.0
# Shouldercircumference            1197.00    1413.0
# Shoulderelbowlength               370.00     423.0
# Shoulderlength                    154.00     185.0
# Sittingheight                     930.00    1039.0
# Sleevelengthspinewrist            910.00    1058.0
# Sleeveoutseam                     603.00     709.0
# Span                             1842.00    2121.0
# Stature                          1779.00    1993.0
# Suprasternaleheight              1459.00    1650.0
# Tenthribheight                   1141.00    1305.0
# Thighcircumference                659.00     870.0
# Thighclearance                    187.00     259.0
# Thumbtipreach                     826.00     998.0
# Tibialheight                      478.00     584.0
# Tragiontopofhead                  134.00     150.0
# Trochanterionheight               918.00    1095.0
# Verticaltrunkcircumferenceusa    1695.00    1991.0
# Waistbacklength                   486.00     598.0
# Waistbreadth                      343.00     461.0
# Waistcircumference                992.00    1379.0
# Waistdepth                        252.25     406.0
# Waistfrontlengthsitting           398.00     494.0
# Waistheightomphalion             1076.00    1245.0
# Weightkg                          896.00    1442.0
# Wristcircumference                179.00     216.0
# Wristheight                       863.00    1009.0
# Subjectnumericrace                  2.00   42351.0
# Dodrace                             2.00       8.0
# Age                                36.00      58.0
# Heightin                           71.00      94.0
# Weightlbs                         196.00     321.0

# %% [markdown]
# ***

# %% [markdown]
# ### target column

# %% [markdown]
# ***dodrace***

# %%
df.Dodrace.value_counts()
# Out:
# 1    3792
# 2    1298
# 3     679
# 4     188
# 6      59
# 5      49
# 8       3
# Name: Dodrace, dtype: int64

# %%
df.Dodrace.value_counts().iplot(kind='barh')
# Out:
# <div>                            <div id="ddaf7be7-368e-47d2-81f9-4514462f256a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("ddaf7be7-368e-47d2-81f9-4514462f256a")) {                    Plotly.newPlot(                        "ddaf7be7-368e-47d2-81f9-4514462f256a",                        [{"marker":{"color":"rgba(255, 153, 51, 0.6)","line":{"color":"rgba(255, 153, 51, 1.0)","width":1}},"name":"Dodrace","orientation":"h","text":"","x":[3792,1298,679,188,59,49,3],"y":[1,2,3,4,6,5,8],"type":"bar"}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattergeo"}],"scattergl":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"s ...

# %%
# Drop DODRace class if value count below 500 (we assume that our data model can't learn if it is below 500)
df = df[df.Dodrace < 4].reset_index(drop=True)

# %%
df.shape
# Out:
# (5769, 108)

# %%
df['Dodrace'].replace([1,2,3], ['White', 'Black', 'Hispanic'], inplace=True)

# %%
df.Dodrace.value_counts()
# Out:
# White       3792
# Black       1298
# Hispanic     679
# Name: Dodrace, dtype: int64

# %% [markdown]
# ### object type columns

# %%
df.select_dtypes('object').columns
# Out:
# Index(['Gender', 'Date', 'Installation', 'Component', 'Branch', 'Primarymos',
#        'Subjectsbirthlocation', 'Ethnicity', 'Dodrace', 'Writingpreference'],
#       dtype='object')

# %%
df.select_dtypes('object').nunique()
# Out:
# Gender                     2
# Date                     253
# Installation              12
# Component                  3
# Branch                     3
# Primarymos               281
# Subjectsbirthlocation    136
# Ethnicity                157
# Dodrace                    3
# Writingpreference          3
# dtype: int64

# %% [markdown]
# ***Ethnicity***

# %%
df.Ethnicity.value_counts(dropna=False).head(10)
# Out:
# NaN                       4644
# Mexican                    356
# Puerto Rican               183
# Caribbean Islander         123
# Cherokee                    60
# Dominican                   32
# Cuban                       17
# Colombian                   17
# Arab or Middle Eastern      16
# Salvadoran                  16
# Name: Ethnicity, dtype: int64

# %%
4644 / 5769  # percentage of NaN values
# Out:
# 0.8049921996879875

# %%
del df['Ethnicity']

# %% [markdown]
# ***Gender***

# %%
df.Gender.value_counts()
# Out:
# Male      3899
# Female    1870
# Name: Gender, dtype: int64

# %%
df.groupby(df.Gender).Dodrace.value_counts()
# Out:
# Gender  Dodrace
# Female  White        975
#         Black        656
#         Hispanic     239
# Male    White       2817
#         Black        642
#         Hispanic     440
# Name: Dodrace, dtype: int64

# %% [markdown]
# ***Date***

# %%
# Date – Date the participant was measured
df.Date.value_counts().head()
# Out:
# 5-Apr-12     43
# 5-Mar-12     43
# 28-Feb-12    42
# 26-May-11    40
# 6-Mar-12     40
# Name: Date, dtype: int64

# %%
del df['Date']

# %% [markdown]
# ***Installation***

# %%
# Installation – U.S. Army installation where the measurement occurred
df.Installation.value_counts()
# Out:
# Camp Shelby       1111
# Fort Bliss         925
# Fort Gordon        636
# Camp Atterbury     432
# Fort McCoy         432
# Fort Hood          416
# Fort Huachuca      404
# Fort Bragg         373
# Fort Drum          369
# Fort Lee           356
# Fort Stewart       314
# Fort Rucker          1
# Name: Installation, dtype: int64

# %%
del df['Installation']

# %% [markdown]
# ***Component***

# %%
df.Component.value_counts()
# Out:
# Regular Army           2955
# Army National Guard    2607
# Army Reserve            207
# Name: Component, dtype: int64

# %%
df.groupby(df.Component).Dodrace.value_counts()
# Out:
# Component            Dodrace
# Army National Guard  White       1855
#                      Black        499
#                      Hispanic     253
# Army Reserve         White        114
#                      Black         52
#                      Hispanic      41
# Regular Army         White       1823
#                      Black        747
#                      Hispanic     385
# Name: Dodrace, dtype: int64

# %%
del df['Component']

# %% [markdown]
# ***Branch***

# %%
df.Branch.value_counts()
# Out:
# Combat Service Support    3021
# Combat Arms               1508
# Combat Support            1240
# Name: Branch, dtype: int64

# %%
df.groupby(df.Branch).Dodrace.value_counts()
# Out:
# Branch                  Dodrace
# Combat Arms             White       1146
#                         Hispanic     189
#                         Black        173
# Combat Service Support  White       1911
#                         Black        745
#                         Hispanic     365
# Combat Support          White        735
#                         Black        380
#                         Hispanic     125
# Name: Dodrace, dtype: int64

# %%
del df['Branch']

# %% [markdown]
# ***Primarymos***

# %%
df.Primarymos.value_counts().head(10)
# Out:
# 11B    641
# 88M    308
# 92A    275
# 91B    224
# 68W    207
# 92Y    200
# 25U    193
# 42A    189
# 31B    187
# 25B    169
# Name: Primarymos, dtype: int64

# %%
df[df.Primarymos=='11B'].groupby('Dodrace').size()
# Out:
# Dodrace
# Black        65
# Hispanic     76
# White       500
# dtype: int64

# %%
df[df.Primarymos=='88M'].groupby('Dodrace').size()
# Out:
# Dodrace
# Black        79
# Hispanic     32
# White       197
# dtype: int64

# %%
del df['Primarymos']

# %% [markdown]
# ***Subjectsbirthlocation***

# %%
df.Subjectsbirthlocation.value_counts().head(10)
# Out:
# California     417
# New York       411
# Texas          386
# Indiana        264
# Illinois       210
# Florida        210
# Oklahoma       205
# Michigan       194
# Minnesota      194
# Mississippi    193
# Name: Subjectsbirthlocation, dtype: int64

# %%
df[df.Subjectsbirthlocation == 'California']['Dodrace'].value_counts()
# Out:
# White       246
# Hispanic    125
# Black        46
# Name: Dodrace, dtype: int64

# %%
df[df.Subjectsbirthlocation == 'Ohio']['Dodrace'].value_counts()
# Out:
# White    121
# Black     18
# Name: Dodrace, dtype: int64

# %%
df[df.Subjectsbirthlocation == 'Puerto Rico']['Dodrace'].value_counts()
# Out:
# Hispanic    84
# White        4
# Name: Dodrace, dtype: int64

# %% [markdown]
# ***Writingpreference***

# %%
df.Writingpreference.value_counts()
# Out:
# Right hand                     5088
# Left hand                       622
# Either hand (No preference)      59
# Name: Writingpreference, dtype: int64

# %%
df.groupby(df.Writingpreference).Dodrace.value_counts()
# Out:
# Writingpreference            Dodrace
# Either hand (No preference)  White         43
#                              Black         13
#                              Hispanic       3
# Left hand                    White        422
#                              Black        150
#                              Hispanic      50
# Right hand                   White       3327
#                              Black       1135
#                              Hispanic     626
# Name: Dodrace, dtype: int64

# %%
# del df['Writingpreference']

# %% [markdown]
# ***

# %% [markdown]
# ### numeric columns

# %%
df.dtypes.value_counts()
# Out:
# int64     98
# object     4
# dtype: int64

# %%
df.select_dtypes(include=['int64']).columns
# Out:
# Index(['Subjectid', 'Abdominalextensiondepthsitting', 'Acromialheight', 'Acromionradialelength',
#        'Anklecircumference', 'Axillaheight', 'Balloffootcircumference', 'Balloffootlength',
#        'Biacromialbreadth', 'Bicepscircumferenceflexed', 'Bicristalbreadth', 'Bideltoidbreadth',
#        'Bimalleolarbreadth', 'Bitragionchinarc', 'Bitragionsubmandibulararc', 'Bizygomaticbreadth',
#        'Buttockcircumference', 'Buttockdepth', 'Buttockheight', 'Buttockkneelength',
#        'Buttockpopliteallength', 'Calfcircumference', 'Cervicaleheight', 'Chestbreadth',
#        'Chestcircumference', 'Chestdepth', 'Chestheight', 'Crotchheight', 'Crotchlengthomphalion',
#        'Crotchlengthposterioromphalion', 'Earbreadth', 'Earlength', 'Earprotrusion',
#        'Elbowrestheight', 'Eyeheightsitting', 'Footbreadthhorizontal', 'Footlength',
#        'Forearmcenterofgriplength', 'Forearmcircumferenceflexed', 'Forearmforearmbreadth',
#        'Forearmhandlength', 'Functionalleglength', 'Handbreadth', 'Handcircumference',
#        'Handlength', 'Headbreadth', 'Headcircumference', 'Headlength', 'Heelanklecircumference',
#        'Heelbreadth', 'Hipbreadth', 'Hipbreadthsitting', 'Iliocristaleheight',
#        'Interpupillarybreadth', 'Interscyei', 'Interscyeii', 'Kneeheightmidpatella',
#        'Kneeheightsitting', 'Lateralfemoralepicondyleheight', 'Lateralmalleolusheight',
#        'Lowerthighcircumference', 'Mentonsellionlength', 'Neckcircumference',
#        'Neckcircumferencebase', 'Overheadfingertipreachsitting', 'Palmlength', 'Poplitealheight',
#        'Radialestylionlength', 'Shouldercircumference', 'Shoulderelbowlength', 'Shoulderlength',
#        'Sittingheight', 'Sleevelengthspinewrist', 'Sleeveoutseam', 'Span', 'Stature',
#        'Suprasternaleheight', 'Tenthribheight', 'Thighcircumference', 'Thighclearance',
#        'Thumbtipreach', 'Tibialheight', 'Tragiontopofhead', 'Trochanterionheight',
#        'Verticaltrunkcircumferenceusa', 'Waistbacklength', 'Waistbreadth', 'Waistcircumference',
#        'Waistdepth', 'Waistfrontlengthsitting', 'Waistheightomphalion', 'Weightkg',
#        'Wristcircumference', 'Wristheight', 'Subjectnumericrace', 'Age', 'Heightin', 'Weightlbs'],
#       dtype='object')

# %%
# subjectid – A unique number for each participant measured in the anthropometric survey
del df['Subjectid']

# %%
# Weightlbs – Weight in Pounds; self-reported, comparable to measured “weightkg”
del df['Weightlbs']

# %%
# Heightin – Height in Inches; self-reported, comparable to measured “stature”
del df['Heightin']

# %%
# SubjectNumericRace – Subject Numeric Race; a single or multi-digit code indicating a subject’s self-reported race or races 
# (verified through interview)

df.Subjectnumericrace.value_counts().head(10)
# Out:
# 1      3559
# 2      1025
# 3       541
# 31      159
# 8       106
# 51      102
# 21       60
# 23       34
# 28       26
# 251      20
# Name: Subjectnumericrace, dtype: int64

# %%
del df['Subjectnumericrace']

# %%
for col in df.select_dtypes(include=['int64']).columns:
    if any(df[col].values==0): print(col)
        
# there are no columns with a value of 0 in it

# %%
# OUTLIERS

iqr_factor = [2, 3]
liste1, liste2 = [], []

for factor in iqr_factor:
    count = 0
    print(f'{Fore.RED}Outliers for {factor} IQR :{Style.RESET_ALL}')
    print('-------------------------------------')
    for col in df.select_dtypes(include=['int64']).columns:
    
        IQR = df[col].quantile(0.75) - df[col].quantile(0.25)
        lower_lim = df[col].quantile(0.25) - factor*IQR
        upper_lim = df[col].quantile(0.75) + factor*IQR
    
        cond = df[(df[col] < lower_lim) | (df[col] > upper_lim)].shape[0]
        
        if cond > 0 and factor == 2:
            liste1.append(df[(df[col] < lower_lim) | (df[col] > upper_lim)].index.tolist())
        if cond > 0 and factor == 3:
            liste2.append(df[(df[col] < lower_lim) | (df[col] > upper_lim)].index.tolist())
        
        if cond > 0: print(f'{col:<30} : ', cond); count += cond
    print(f'\n{Fore.BLUE}TOTAL OUTLIERS FOR {factor} IQR : {count}{Style.RESET_ALL}')
    print('')
# Out:
# Outliers for 2 IQR :
# -------------------------------------
# Abdominalextensiondepthsitting :  11
# Acromionradialelength          :  2
# Anklecircumference             :  10
# Axillaheight                   :  1
# Balloffootcircumference        :  4
# Balloffootlength               :  1
# Biacromialbreadth              :  1
# Bicepscircumferenceflexed      :  1
# Bicristalbreadth               :  8
# Bitragionchinarc               :  3
# Bitragionsubmandibulararc      :  2
# Buttockcircumference           :  14
# Buttockdepth                   :  8
# Buttockheight                  :  7
# Buttockkneelength              :  3
# Buttockpopliteallength         :  3
# Calfcircumference              :  9
# Chestbreadth                   :  3
# Chestcircumference             :  1
# Chestdepth                     :  2
# Crotchheight                   :  4
# Crotchlengthomphalion          :  10
# Crotchlengthposterioromphalion :  4
# Earbreadth                     :  8
# Earlength                      :  2
# Earprotrusion                  :  9
# Elbowrestheight                :  3
# Footbreadthhorizontal          :  1
# Forearmhandlength              :  4
# Functionalleglength            :  1
# Handlength                     :  6
# Headbreadth                    :  9
# Headcircumference              :  4
# Headlength                     :  2
# Heelbreadth                    :  9
# Hipbreadth                     :  21
# Hipbreadthsitting              :  17
# Iliocristaleheight             :  3
# Interpupillarybreadth          :  13
# Interscyeii                    :  1
# Kneeheightmidpatella           :  5
# Kneeheightsitting              :  3
# Lateralfemoralepicondyleheight :  8
# Lateralmalleolusheight         :  1
# Lowerthighcircumference        :  19
# Mentonsellionlength            :  3
# Palmlength                     :  1
# Poplitealheight                :  1
# Radialestylionlength           :  2
# Shoulderelbowlength            :  1
# Sleevelengthspinewrist         :  1
# Sleeveoutseam                  :  1
# Span                           :  1
# Tenthribheight                 :  1
# Thighcircumference             :  17
# Thighclearance                 :  17
# Thumbtipreach                  :  4
# Tibialheight                   :  6
# Tragiontopofhead               :  4
# Trochanterionheight            :  6
# Verticaltrunkcircumferenceusa  :  1
# Waistbacklength                :  1
# Waistbreadth                   :  3
# Waistcircumference             :  8
# Waistdepth                     :  14
# Waistfrontlengthsitting        :  2
# Waistheightomphalion           :  1
# Weightkg                       :  14
# Wristheight                    :  2
#
# TOTAL OUTLIERS FOR 2 IQR : 373
#
# Outliers for 3 IQR :
# -------------------------------------
# Abdominalextensiondepthsitting :  1
# Chestdepth                     :  1
# Hipbreadth                     :  2
# Hipbreadthsitting              :  2
# Lowerthighcircumference        :  1
# Thighclearance                 :  1
# Waistdepth                     :  1
#
# TOTAL OUTLIERS FOR 3 IQR : 9

# %%
len(sum(liste1, [])), len(sum(liste2, []))
# Out:
# (373, 9)

# %%
# I will keep outliers as most measurements are in millimeters and are real data 

# df = df.drop(index=sum(liste1, [])).reset_index(drop=True)  ===> DROPPING OUTLIERS WITH 2 IQR
# df = df.drop(index=sum(liste2, [])).reset_index(drop=True)  ===> DROPPING OUTLIERS WITH 3 IQR

# %%
# MULTICOLLINEARITY

df_temp = df.corr()
feature1, feature2, corrcoef = [], [], []

for ind in df_temp.index:
    for col in df_temp.columns:
        if (df_temp[ind][col] > 0.9 and df_temp[ind][col] < 1) or (df_temp[ind][col] < -0.9 and df_temp[ind][col] > -1):
            feature1.append(ind)
            feature2.append(col)
            corrcoef.append(df_temp[ind][col])
            
corr_dict = {'feature1': feature1, 'feature2': feature2, 'corrcoeff': corrcoef}
df_corr = pd.DataFrame(corr_dict)
df_corr
# Out:
#                            feature1                        feature2  corrcoeff
# 0    Abdominalextensiondepthsitting              Waistcircumference   0.939645
# 1    Abdominalextensiondepthsitting                      Waistdepth   0.958716
# 2                    Acromialheight                    Axillaheight   0.987115
# 3                    Acromialheight                 Cervicaleheight   0.983955
# 4                    Acromialheight                     Chestheight   0.959300
# 5                    Acromialheight              Iliocristaleheight   0.932232
# 6                    Acromialheight               Kneeheightsitting   0.931762
# 7                    Acromialheight                         Stature   0.979925
# 8                    Acromialheight             Suprasternaleheight   0.984711
# 9                    Acromialheight                  Tenthribheight   0.945019
# 10                   Acromialheight            Waistheightomphalion   0.930954
# 11                   Acromialheight                     Wristheight   0.921268
# 12            Acromionradialelength             Shoulderelbowlength   0.967500
# 13            Acromionradialelength                   Sleeveoutseam   0.939807
# 14                     Axillaheight                  Acromialheight   0.987115
# 15                     Axillaheight                 Cervicaleheight   0.976609
# 16                     Axillaheight                     Chestheight   0.956096
# 17                     Axillaheight                    Crotchheight   0.915316
# 18                     Axillaheight              Iliocristaleheight   0.946228
# 19                     Axillaheight            Kneeheightmidpatella   0.903028
# 20                     Axillaheight               Kneeheightsitting   0.933482
# 21                     Axillaheight                 Poplitealheight   0.905677
# 22                     Axillaheight                         Stature   0.975436
# 23                     Axillaheight             Suprasternaleheight   0.980594
# 24                     Axillaheight                  Tenthribheight   0.954317
# 25                     Axillaheight                    Tibialheight   0.904542
# 26                     Axillaheight            Waistheightomphalion   0.946468
# 27                     Axillaheight                     Wristheight   0.903063
# 28          Balloffootcircumference           Footbreadthhorizontal   0.922957
# 29                 Balloffootlength                      Footlength   0.959326
# 30                Biacromialbreadth           Shouldercircumference   0.900032
# 31        Bicepscircumferenceflexed      Forearmcircumferenceflexed   0.912778
# 32                 Bideltoidbreadth           Forearmforearmbreadth   0.928047
# 33                 Bideltoidbreadth           Shouldercircumference   0.947405
# 34                 Bideltoidbreadth                        Weightkg   0.906437
# 35             Buttockcircumference                      Hipbreadth   0.923805
# 36             Buttockcircumference              Thighcircumference   0.937563
# 37                    Buttockheight                    Crotchheight   0.927173
# 38                    Buttockheight              Iliocristaleheight   0.923156
# 39                    Buttockheight            Kneeheightmidpatella   0.918324
# 40                    Buttockheight               Kneeheightsitting   0.901859
# 41                    Buttockheight                  Tenthribheight   0.921393
# 42                    Buttockheight                    Tibialheight   0.907724
# 43                    Buttockheight             Trochanterionheight   0.965928
# 44                Buttockkneelength          Buttockpopliteallength   0.946531
# 45           Buttockpopliteallength               Buttockkneelength   0.946531
# 46                  Cervicaleheight                  Acromialheight   0.983955
# 47                  Cervicaleheight                    Axillaheight   0.976609
# 48                  Cervicaleheight                     Chestheight   0.967151
# 49                  Cervicaleheight                    Crotchheight   0.906494
# 50                  Cervicaleheight             Functionalleglength   0.901057
# 51                  Cervicaleheight              Iliocristaleheight   0.931575
# 52                  Cervicaleheight            Kneeheightmidpatella   0.900226
# 53                  Cervicaleheight               Kneeheightsitting   0.936604
# 54                  Cervicaleheight                 Poplitealheight   0.906663
# 55                  Cervicaleheight                            Span   0.905629
# 56                  Cervicaleheight                         Stature   0.991053
# 57                  Cervicaleheight             Suprasternaleheight   0.989112
# 58                  Cervicaleheight                  Tenthribheight   0.939214
# 59                  Cervicaleheight            Waistheightomphalion   0.939564
# 60               Chestcircumference                        Weightkg   0.915082
# 61                      Chestheight                  Acromialheight   0.959300
# 62                      Chestheight                    Axillaheight   0.956096
# 63                      Chestheight                 Cervicaleheight   0.967151
# 64                      Chestheight                    Crotchheight   0.904216
# 65                      Chestheight              Iliocristaleheight   0.908813
# 66                      Chestheight               Kneeheightsitting   0.917266
# 67                      Chestheight                 Poplitealheight   0.908508
# 68                      Chestheight                         Stature   0.964858
# 69                      Chestheight             Suprasternaleheight   0.967309
# 70                      Chestheight                  Tenthribheight   0.921442
# 71                      Chestheight            Waistheightomphalion   0.931688
# 72                     Crotchheight                    Axillaheight   0.915316
# 73                     Crotchheight                   Buttockheight   0.927173
# 74                     Crotchheight                 Cervicaleheight   0.906494
# 75                     Crotchheight                     Chestheight   0.904216
# 76                     Crotchheight              Iliocristaleheight   0.934151
# 77                     Crotchheight            Kneeheightmidpatella   0.937158
# 78                     Crotchheight               Kneeheightsitting   0.937542
# 79                     Crotchheight  Lateralfemoralepicondyleheight   0.917922
# 80                     Crotchheight                 Poplitealheight   0.930526
# 81                     Crotchheight             Suprasternaleheight   0.904751
# 82                     Crotchheight                  Tenthribheight   0.927420
# 83                     Crotchheight                    Tibialheight   0.929703
# 84                     Crotchheight             Trochanterionheight   0.939722
# 85                     Crotchheight            Waistheightomphalion   0.937215
# 86                 Eyeheightsitting                   Sittingheight   0.981732
# 87            Footbreadthhorizontal         Balloffootcircumference   0.922957
# 88                       Footlength                Balloffootlength   0.959326
# 89        Forearmcenterofgriplength               Forearmhandlength   0.962827
# 90        Forearmcenterofgriplength            Radialestylionlength   0.928518
# 91        Forearmcenterofgriplength                            Span   0.930132
# 92       Forearmcircumferenceflexed       Bicepscircumferenceflexed   0.912778
# 93            Forearmforearmbreadth                Bideltoidbreadth   0.928047
# 94                Forearmhandlength       Forearmcenterofgriplength   0.962827
# 95                Forearmhandlength               Kneeheightsitting   0.910910
# 96                Forearmhandlength            Radialestylionlength   0.938229
# 97                Forearmhandlength                   Sleeveoutseam   0.909445
# 98                Forearmhandlength                            Span   0.948404
# 99              Functionalleglength                 Cervicaleheight   0.901057
# 100             Functionalleglength               Kneeheightsitting   0.908377
# 101             Functionalleglength             Suprasternaleheight   0.902834
# 102                     Handbreadth               Handcircumference   0.962704
# 103               Handcircumference                     Handbreadth   0.962704
# 104               Handcircumference              Wristcircumference   0.900651
# 105                      Hipbreadth            Buttockcircumference   0.923805
# 106                      Hipbreadth               Hipbreadthsitting   0.915635
# 107               Hipbreadthsitting                      Hipbreadth   0.915635
# 108              Iliocristaleheight                  Acromialheight   0.932232
# 109              Iliocristaleheight                    Axillaheight   0.946228
# 110              Iliocristaleheight                   Buttockheight   0.923156
# 111              Iliocristaleheight                 Cervicaleheight   0.931575
# 112              Iliocristaleheight                     Chestheight   0.908813
# 113              Iliocristaleheight                    Crotchheight   0.934151
# 114              Iliocristaleheight            Kneeheightmidpatella   0.913308
# 115              Iliocristaleheight               Kneeheightsitting   0.942202
# 116              Iliocristaleheight                 Poplitealheight   0.905575
# 117              Iliocristaleheight                         Stature   0.924382
# 118              Iliocristaleheight             Suprasternaleheight   0.936484
# 119              Iliocristaleheight                  Tenthribheight   0.963818
# 120              Iliocristaleheight                    Tibialheight   0.918625
# 121              Iliocristaleheight             Trochanterionheight   0.930185
# 122              Iliocristaleheight            Waistheightomphalion   0.941566
# 123                      Interscyei                     Interscyeii   0.959271
# 124                     Interscyeii                      Interscyei   0.959271
# 125            Kneeheightmidpatella                    Axillaheight   0.903028
# 126            Kneeheightmidpatella                   Buttockheight   0.918324
# 127            Kneeheightmidpatella                 Cervicaleheight   0.900226
# 128            Kneeheightmidpatella                    Crotchheight   0.937158
# 129            Kneeheightmidpatella              Iliocristaleheight   0.913308
# 130            Kneeheightmidpatella               Kneeheightsitting   0.955674
# 131            Kneeheightmidpatella  Lateralfemoralepicondyleheight   0.941015
# 132            Kneeheightmidpatella                 Poplitealheight   0.928061
# 133            Kneeheightmidpatella                  Tenthribheight   0.918802
# 134            Kneeheightmidpatella                    Tibialheight   0.962721
# 135            Kneeheightmidpatella             Trochanterionheight   0.923715
# 136            Kneeheightmidpatella            Waistheightomphalion   0.910559
# 137               Kneeheightsitting                  Acromialheight   0.931762
# 138               Kneeheightsitting                    Axillaheight   0.933482
# 139               Kneeheightsitting                   Buttockheight   0.901859
# 140               Kneeheightsitting                 Cervicaleheight   0.936604
# 141               Kneeheightsitting                     Chestheight   0.917266
# 142               Kneeheightsitting                    Crotchheight   0.937542
# 143               Kneeheightsitting               Forearmhandlength   0.910910
# 144               Kneeheightsitting             Functionalleglength   0.908377
# 145               Kneeheightsitting              Iliocristaleheight   0.942202
# 146               Kneeheightsitting            Kneeheightmidpatella   0.955674
# 147               Kneeheightsitting  Lateralfemoralepicondyleheight   0.927546
# 148               Kneeheightsitting                 Poplitealheight   0.937336
# 149               Kneeheightsitting                            Span   0.912872
# 150               Kneeheightsitting                         Stature   0.925195
# 151               Kneeheightsitting             Suprasternaleheight   0.940518
# 152               Kneeheightsitting                  Tenthribheight   0.935949
# 153               Kneeheightsitting                    Tibialheight   0.952670
# 154               Kneeheightsitting             Trochanterionheight   0.916371
# 155               Kneeheightsitting            Waistheightomphalion   0.927421
# 156  Lateralfemoralepicondyleheight                    Crotchheight   0.917922
# 157  Lateralfemoralepicondyleheight            Kneeheightmidpatella   0.941015
# 158  Lateralfemoralepicondyleheight               Kneeheightsitting   0.927546
# 159  Lateralfemoralepicondyleheight                 Poplitealheight   0.902097
# 160  Lateralfemoralepicondyleheight                  Tenthribheight   0.902957
# 161  Lateralfemoralepicondyleheight                    Tibialheight   0.946444
# 162  Lateralfemoralepicondyleheight             Trochanterionheight   0.902769
# 163               Neckcircumference           Neckcircumferencebase   0.969495
# 164           Neckcircumferencebase               Neckcircumference   0.969495
# 165                 Poplitealheight                    Axillaheight   0.905677
# 166                 Poplitealheight                 Cervicaleheight   0.906663
# 167                 Poplitealheight                     Chestheight   0.908508
# 168                 Poplitealheight                    Crotchheight   0.930526
# 169                 Poplitealheight              Iliocristaleheight   0.905575
# 170                 Poplitealheight            Kneeheightmidpatella   0.928061
# 171                 Poplitealheight               Kneeheightsitting   0.937336
# 172                 Poplitealheight  Lateralfemoralepicondyleheight   0.902097
# 173                 Poplitealheight                    Tibialheight   0.915703
# 174                 Poplitealheight            Waistheightomphalion   0.928067
# 175            Radialestylionlength       Forearmcenterofgriplength   0.928518
# 176            Radialestylionlength               Forearmhandlength   0.938229
# 177            Radialestylionlength                   Sleeveoutseam   0.911328
# 178            Radialestylionlength                            Span   0.910243
# 179           Shouldercircumference               Biacromialbreadth   0.900032
# 180           Shouldercircumference                Bideltoidbreadth   0.947405
# 181             Shoulderelbowlength           Acromionradialelength   0.967500
# 182             Shoulderelbowlength                   Sleeveoutseam   0.942978
# 183             Shoulderelbowlength                            Span   0.918447
# 184                   Sittingheight                Eyeheightsitting   0.981732
# 185          Sleevelengthspinewrist                   Sleeveoutseam   0.903168
# 186          Sleevelengthspinewrist                            Span   0.928024
# 187                   Sleeveoutseam           Acromionradialelength   0.939807
# 188                   Sleeveoutseam               Forearmhandlength   0.909445
# 189                   Sleeveoutseam            Radialestylionlength   0.911328
# 190                   Sleeveoutseam             Shoulderelbowlength   0.942978
# 191                   Sleeveoutseam          Sleevelengthspinewrist   0.903168
# 192                   Sleeveoutseam                            Span   0.933722
# 193                            Span                 Cervicaleheight   0.905629
# 194                            Span       Forearmcenterofgriplength   0.930132
# 195                            Span               Forearmhandlength   0.948404
# 196                            Span               Kneeheightsitting   0.912872
# 197                            Span            Radialestylionlength   0.910243
# 198                            Span             Shoulderelbowlength   0.918447
# 199                            Span          Sleevelengthspinewrist   0.928024
# 200                            Span                   Sleeveoutseam   0.933722
# 201                            Span             Suprasternaleheight   0.905016
# 202                         Stature                  Acromialheight   0.979925
# 203                         Stature                    Axillaheight   0.975436
# 204                         Stature                 Cervicaleheight   0.991053
# 205                         Stature                     Chestheight   0.964858
# 206                         Stature              Iliocristaleheight   0.924382
# 207                         Stature               Kneeheightsitting   0.925195
# 208                         Stature             Suprasternaleheight   0.989120
# 209                         Stature                  Tenthribheight   0.931441
# 210                         Stature            Waistheightomphalion   0.935163
# 211             Suprasternaleheight                  Acromialheight   0.984711
# 212             Suprasternaleheight                    Axillaheight   0.980594
# 213             Suprasternaleheight                 Cervicaleheight   0.989112
# 214             Suprasternaleheight                     Chestheight   0.967309
# 215             Suprasternaleheight                    Crotchheight   0.904751
# 216             Suprasternaleheight             Functionalleglength   0.902834
# 217             Suprasternaleheight              Iliocristaleheight   0.936484
# 218             Suprasternaleheight               Kneeheightsitting   0.940518
# 219             Suprasternaleheight                            Span   0.905016
# 220             Suprasternaleheight                         Stature   0.989120
# 221             Suprasternaleheight                  Tenthribheight   0.943748
# 222             Suprasternaleheight            Waistheightomphalion   0.938366
# 223                  Tenthribheight                  Acromialheight   0.945019
# 224                  Tenthribheight                    Axillaheight   0.954317
# 225                  Tenthribheight                   Buttockheight   0.921393
# 226                  Tenthribheight                 Cervicaleheight   0.939214
# 227                  Tenthribheight                     Chestheight   0.921442
# 228                  Tenthribheight                    Crotchheight   0.927420
# 229                  Tenthribheight              Iliocristaleheight   0.963818
# 230                  Tenthribheight            Kneeheightmidpatella   0.918802
# 231                  Tenthribheight               Kneeheightsitting   0.935949
# 232                  Tenthribheight  Lateralfemoralepicondyleheight   0.902957
# 233                  Tenthribheight                         Stature   0.931441
# 234                  Tenthribheight             Suprasternaleheight   0.943748
# 235                  Tenthribheight                    Tibialheight   0.913310
# 236                  Tenthribheight             Trochanterionheight   0.916938
# 237                  Tenthribheight            Waistheightomphalion   0.940738
# 238              Thighcircumference            Buttockcircumference   0.937563
# 239                    Tibialheight                    Axillaheight   0.904542
# 240                    Tibialheight                   Buttockheight   0.907724
# 241                    Tibialheight                    Crotchheight   0.929703
# 242                    Tibialheight              Iliocristaleheight   0.918625
# 243                    Tibialheight            Kneeheightmidpatella   0.962721
# 244                    Tibialheight               Kneeheightsitting   0.952670
# 245                    Tibialheight  Lateralfemoralepicondyleheight   0.946444
# 246                    Tibialheight                 Poplitealheight   0.915703
# 247                    Tibialheight                  Tenthribheight   0.913310
# 248                    Tibialheight             Trochanterionheight   0.926698
# 249                    Tibialheight            Waistheightomphalion   0.909651
# 250             Trochanterionheight                   Buttockheight   0.965928
# 251             Trochanterionheight                    Crotchheight   0.939722
# 252             Trochanterionheight              Iliocristaleheight   0.930185
# 253             Trochanterionheight            Kneeheightmidpatella   0.923715
# 254             Trochanterionheight               Kneeheightsitting   0.916371
# 255             Trochanterionheight  Lateralfemoralepicondyleheight   0.902769
# 256             Trochanterionheight                  Tenthribheight   0.916938
# 257             Trochanterionheight                    Tibialheight   0.926698
# 258             Trochanterionheight            Waistheightomphalion   0.909454
# 259   Verticaltrunkcircumferenceusa                        Weightkg   0.900088
# 260                    Waistbreadth              Waistcircumference   0.960707
# 261              Waistcircumference  Abdominalextensiondepthsitting   0.939645
# 262              Waistcircumference                    Waistbreadth   0.960707
# 263              Waistcircumference                      Waistdepth   0.954323
# 264                      Waistdepth  Abdominalextensiondepthsitting   0.958716
# 265                      Waistdepth              Waistcircumference   0.954323
# 266            Waistheightomphalion                  Acromialheight   0.930954
# 267            Waistheightomphalion                    Axillaheight   0.946468
# 268            Waistheightomphalion                 Cervicaleheight   0.939564
# 269            Waistheightomphalion                     Chestheight   0.931688
# 270            Waistheightomphalion                    Crotchheight   0.937215
# 271            Waistheightomphalion              Iliocristaleheight   0.941566
# 272            Waistheightomphalion            Kneeheightmidpatella   0.910559
# 273            Waistheightomphalion               Kneeheightsitting   0.927421
# 274            Waistheightomphalion                 Poplitealheight   0.928067
# 275            Waistheightomphalion                         Stature   0.935163
# 276            Waistheightomphalion             Suprasternaleheight   0.938366
# 277            Waistheightomphalion                  Tenthribheight   0.940738
# 278            Waistheightomphalion                    Tibialheight   0.909651
# 279            Waistheightomphalion             Trochanterionheight   0.909454
# 280                        Weightkg                Bideltoidbreadth   0.906437
# 281                        Weightkg              Chestcircumference   0.915082
# 282                        Weightkg   Verticaltrunkcircumferenceusa   0.900088
# 283              Wristcircumference               Handcircumference   0.900651
# 284                     Wristheight                  Acromialheight   0.921268
# 285                     Wristheight                    Axillaheight   0.903063

# %% [markdown]
# ***

# %%
ax = sns.countplot(x='Dodrace', data=df)

for p in ax.patches:
    ax.annotate((p.get_height()), (p.get_x()+0.3, p.get_height()+100), fontsize=12)

ax.set_title('Distribution of DODRace', pad=15)
ax.set_ylim(0, 4500);

# %%
df.shape
# Out:
# (5769, 98)

# %%
df.select_dtypes('object').columns
# Out:
# Index(['Gender', 'Subjectsbirthlocation', 'Dodrace', 'Writingpreference'], dtype='object')

# %%
# df.to_csv('soldiers.csv', index=False)

# %%
# I will also create copies of the dataset by gender

df_m = df[df.Gender == 'Male'].reset_index(drop=True).drop(columns='Gender', axis=1)
df_f = df[df.Gender == 'Female'].reset_index(drop=True).drop(columns='Gender', axis=1)

df_m.to_csv('soldiers_male.csv', index=False)
df_f.to_csv('soldiers_female.csv', index=False)

# %% [markdown]
# # DATA Preprocessing
# - In this step we divide our data to X(Features) and y(Target) then ,
# - To train and evaluation purposes we create train and test sets,
# - Lastly, scale our data if features not in same scale. Why?

# %%
X = pd.get_dummies(df.drop('Dodrace', axis=1), drop_first=True)
y = df['Dodrace']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=30)

# %%
print("Train features shape : ", X_train.shape)
print("Train target shape   : ", y_train.shape)
print("Test features shape  : ", X_test.shape)
print("Test target shape    : ", y_test.shape)
# Out:
# Train features shape :  (4615, 232)
# Train target shape   :  (4615,)
# Test features shape  :  (1154, 232)
# Test target shape    :  (1154,)

# %%
def eval_metric(model, X_train, y_train, X_test, y_test):
    y_train_pred = model.predict(X_train)
    y_pred = model.predict(X_test)
    
    print("Test_Set")
    print(confusion_matrix(y_test, y_pred))
    print(classification_report(y_test, y_pred))
    print()
    print("Train_Set")
    print(confusion_matrix(y_train, y_train_pred))
    print(classification_report(y_train, y_train_pred))

# %% [markdown]
# # Modeling
# - Fit the model with train dataset
# - Get predict from vanilla model on both train and test sets to examine if there is over/underfitting
# - Apply GridseachCV for both hyperparemeter tuning and sanity test of our model.
# - Use hyperparameters that you find from gridsearch and make final prediction and evaluate the result according to chosen metric.

# %% [markdown]
# ## 1. Logistic model

# %% [markdown]
# ### Vanilla Logistic Model

# %%
from sklearn.pipeline import Pipeline
operations_log = [("scaler", MinMaxScaler()), ("log", LogisticRegression())]
pipe_log_model = Pipeline(steps=operations_log)

# %%
pipe_log_model.fit(X_train,y_train)
eval_metric(pipe_log_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[236   1  23]
#  [  7  82  47]
#  [ 12  12 734]]
#               precision    recall  f1-score   support
#
#        Black       0.93      0.91      0.92       260
#     Hispanic       0.86      0.60      0.71       136
#        White       0.91      0.97      0.94       758
#
#     accuracy                           0.91      1154
#    macro avg       0.90      0.83      0.86      1154
# weighted avg       0.91      0.91      0.91      1154
#
#
# Train_Set
# [[ 954   15   69]
#  [  31  307  205]
#  [  24   51 2959]]
#               precision    recall  f1-score   support
#
#        Black       0.95      0.92      0.93      1038
#     Hispanic       0.82      0.57      0.67       543
#        White       0.92      0.98      0.94      3034
#
#     accuracy                           0.91      4615
#    macro avg       0.89      0.82      0.85      4615
# weighted avg       0.91      0.91      0.91      4615

# %%
# I know I have an unbalanced dataset so I will set class_weight to 'balanced'
# and try to increase the recall_macro (balanced_accuracy) score 
# and check out the 'Hispanic' scores together with specific iteration

operations_log = [("scaler", MinMaxScaler()), ("log", LogisticRegression(class_weight='balanced', max_iter=1000))]
pipe_log_model = Pipeline(steps=operations_log)

pipe_log_model.fit(X_train,y_train)
eval_metric(pipe_log_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[245   4  11]
#  [  4 111  21]
#  [ 22  93 643]]
#               precision    recall  f1-score   support
#
#        Black       0.90      0.94      0.92       260
#     Hispanic       0.53      0.82      0.65       136
#        White       0.95      0.85      0.90       758
#
#     accuracy                           0.87      1154
#    macro avg       0.80      0.87      0.82      1154
# weighted avg       0.89      0.87      0.87      1154
#
#
# Train_Set
# [[ 969   41   28]
#  [  23  452   68]
#  [  61  360 2613]]
#               precision    recall  f1-score   support
#
#        Black       0.92      0.93      0.93      1038
#     Hispanic       0.53      0.83      0.65       543
#        White       0.96      0.86      0.91      3034
#
#     accuracy                           0.87      4615
#    macro avg       0.80      0.88      0.83      4615
# weighted avg       0.90      0.87      0.88      4615

# %%
y_pred = pipe_log_model.predict(X_test)
print(f'accuracy_score\t\t: {accuracy_score(y_test, y_pred)}')
print(f'balanced_accuracy_score : {balanced_accuracy_score(y_test, y_pred)}')  # recall_score(y_test, y_pred, average='macro')
# Out:
# accuracy_score		: 0.865684575389948
# balanced_accuracy_score : 0.8689230411060304

# %%
# CROSS VALIDATE
# I will use 5-fold cross-validation as standard to make correct comparisons across all models

operations_log = [("scaler", MinMaxScaler()), ("log", LogisticRegression(class_weight='balanced', max_iter=1000))]
pipe_log_model = Pipeline(steps=operations_log)

scoring = {'accuracy': make_scorer(accuracy_score), 'accuracy_balanced': make_scorer(balanced_accuracy_score),
           'precision_Hispanic' : make_scorer(precision_score, average=None, labels=['Hispanic']),
           'recall_Hispanic' : make_scorer(recall_score, average=None, labels=['Hispanic']),
           'f1_Hispanic' : make_scorer(f1_score, average=None, labels=['Hispanic'])}
         
scores = cross_validate(pipe_log_model, X_train, y_train, scoring=scoring, cv=5)
df_scores = pd.DataFrame(scores, index=range(1, 6))
df_scores.mean()[2:]
# Out:
# test_accuracy              0.855471
# test_accuracy_balanced     0.847296
# test_precision_Hispanic    0.492940
# test_recall_Hispanic       0.780819
# test_f1_Hispanic           0.603049
# dtype: float64

# %% [markdown]
# ### Logistic Model GridsearchCV

# %%
# for liblinear solver only
# For small datasets, ‘liblinear’ is a good choice for multiclass problems 

operations_log = [("scaler", MinMaxScaler()), ("log", LogisticRegression(class_weight='balanced', max_iter=1000,
                                                                             solver='liblinear'))]
pipe_log_model = Pipeline(steps=operations_log)

# with logistic regression, there is no overfitting problem so far, so I will mostly try values greater than the default (for C)
param_grid = {'log__penalty': ['l1', 'l2'], 'log__C': [0.1, 1, 5, 30, 50]}

log_grid_model1 = GridSearchCV(estimator = pipe_log_model,
                            param_grid = param_grid,
                            cv = 5,
                            scoring = 'recall_macro',
                            verbose = 2,
                            n_jobs = -1).fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits

# %%
log_grid_model1.best_params_
# Out:
# {'log__C': 5, 'log__penalty': 'l2'}

# %%
log_grid_model1.best_score_
# Out:
# 0.8354594036250826

# %%
eval_metric(log_grid_model1, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[241   1  18]
#  [  6  97  33]
#  [ 19  41 698]]
#               precision    recall  f1-score   support
#
#        Black       0.91      0.93      0.92       260
#     Hispanic       0.70      0.71      0.71       136
#        White       0.93      0.92      0.93       758
#
#     accuracy                           0.90      1154
#    macro avg       0.85      0.85      0.85      1154
# weighted avg       0.90      0.90      0.90      1154
#
#
# Train_Set
# [[ 983   17   38]
#  [  26  393  124]
#  [  41  144 2849]]
#               precision    recall  f1-score   support
#
#        Black       0.94      0.95      0.94      1038
#     Hispanic       0.71      0.72      0.72       543
#        White       0.95      0.94      0.94      3034
#
#     accuracy                           0.92      4615
#    macro avg       0.86      0.87      0.87      4615
# weighted avg       0.92      0.92      0.92      4615

# %%
y_pred = log_grid_model1.predict(X_test)
print(f'accuracy_score\t\t: {accuracy_score(y_test, y_pred)}')
print(f'balanced_accuracy_score : {balanced_accuracy_score(y_test, y_pred)}')  # recall_score(y_test, y_pred, average='macro')
# Out:
# accuracy_score		: 0.8977469670710572
# balanced_accuracy_score : 0.8536675660725016

# %%
# I tried the scores only for 'liblinear' solver and could not get better scores for balanced_accuracy
# I want especially try the 'elasticnet' solver because of balanced scores between train and test data

operations_log = [("scaler", MinMaxScaler()),("log", LogisticRegression(class_weight='balanced',max_iter=1000,random_state=30))]
pipe_log_model = Pipeline(steps=operations_log)

# 'sag' or 'saga' might be the best solver, so I used random_state instance above

param_grid = [
  {'log__solver': ['sag', 'newton-cg', 'lbfgs'], 'log__penalty': ['l2'], 'log__C': [0.1, 1, 5, 10]},
  {'log__solver': ['saga'], 'log__penalty': ['elasticnet'], 'log__l1_ratio':[0.1, 0.2, 0.5, 0.8, 1], 'log__C': [0.1, 1, 5, 10]}
 ]

log_grid_model2 = GridSearchCV(estimator = pipe_log_model,
                          param_grid = param_grid,
                          cv = 5,
                          scoring = 'recall_macro',
                          verbose = 2,
                          n_jobs = -1).fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits

# %%
log_grid_model2.best_params_
# Out:
# {'log__C': 5,
#  'log__l1_ratio': 0.1,
#  'log__penalty': 'elasticnet',
#  'log__solver': 'saga'}

# %%
log_grid_model2.best_score_
# Out:
# 0.8508543905700702

# %%
eval_metric(log_grid_model2, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[245   4  11]
#  [  5 111  20]
#  [ 25  88 645]]
#               precision    recall  f1-score   support
#
#        Black       0.89      0.94      0.92       260
#     Hispanic       0.55      0.82      0.65       136
#        White       0.95      0.85      0.90       758
#
#     accuracy                           0.87      1154
#    macro avg       0.80      0.87      0.82      1154
# weighted avg       0.89      0.87      0.87      1154
#
#
# Train_Set
# [[ 979   35   24]
#  [  17  463   63]
#  [  52  335 2647]]
#               precision    recall  f1-score   support
#
#        Black       0.93      0.94      0.94      1038
#     Hispanic       0.56      0.85      0.67       543
#        White       0.97      0.87      0.92      3034
#
#     accuracy                           0.89      4615
#    macro avg       0.82      0.89      0.84      4615
# weighted avg       0.91      0.89      0.89      4615

# %%
y_pred = log_grid_model2.predict(X_test)
print(f'accuracy_score\t\t: {accuracy_score(y_test, y_pred)}')
print(f'balanced_accuracy_score : {balanced_accuracy_score(y_test, y_pred)}')  # recall_score(y_test, y_pred, average='macro')
# Out:
# accuracy_score		: 0.8674176776429809
# balanced_accuracy_score : 0.8698025485818439

# %%
# Logistic regression vanilla model (with class_weight='balanced') and log_grid_model2 almost have the same scores
# I will prefer the log_grid_model2 because of the scores given by cross-validation (compared with grid search cv)

from yellowbrick.classifier import PrecisionRecallCurve

operations_log = [("scaler", MinMaxScaler()), ("log", LogisticRegression(class_weight='balanced', max_iter=1000, solver='saga',
                                                                l1_ratio=0.1, C=5, penalty='elasticnet', random_state=30))]
pipe_log_model = Pipeline(steps=operations_log)

viz = PrecisionRecallCurve(
        pipe_log_model,
        per_class=True, classes= ['Black', 'Hispanic', 'White'],
        cmap='Set1'
)

viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.show();

# %%
viz.score_
# Out:
# {'Black': 0.969273276015362,
#  'Hispanic': 0.7642765417919569,
#  'White': 0.973473770515348,
#  'micro': 0.9402495348629517}

# %%
y_pred = log_grid_model2.predict(X_test)

log_accuracy = accuracy_score(y_test, y_pred)
log_accuracy_balanced = balanced_accuracy_score(y_test, y_pred)
log_f1 = f1_score(y_test, y_pred, average=None, labels=['Hispanic'])
log_recall = recall_score(y_test, y_pred, average=None, labels=['Hispanic'])
log_AP = viz.score_['Hispanic']
log_AP_micro = viz.score_['micro']

# %% [markdown]
# ***

# %% [markdown]
# ## 2. SVC (Support Vector Classifier)

# %% [markdown]
# ### Vanilla SVC model

# %%
operations_svc = [("scaler", MinMaxScaler()), ("svc", SVC())]
pipe_svc_model = Pipeline(steps=operations_svc)

# %%
pipe_svc_model.fit(X_train, y_train)
eval_metric(pipe_svc_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[230   0  30]
#  [  8  51  77]
#  [  7   3 748]]
#               precision    recall  f1-score   support
#
#        Black       0.94      0.88      0.91       260
#     Hispanic       0.94      0.38      0.54       136
#        White       0.87      0.99      0.93       758
#
#     accuracy                           0.89      1154
#    macro avg       0.92      0.75      0.79      1154
# weighted avg       0.90      0.89      0.88      1154
#
#
# Train_Set
# [[ 926    2  110]
#  [  38  141  364]
#  [  18    3 3013]]
#               precision    recall  f1-score   support
#
#        Black       0.94      0.89      0.92      1038
#     Hispanic       0.97      0.26      0.41       543
#        White       0.86      0.99      0.92      3034
#
#     accuracy                           0.88      4615
#    macro avg       0.92      0.71      0.75      4615
# weighted avg       0.89      0.88      0.86      4615

# %%
# I got bad scores for 'Hispanic' on the vanilla model,
# so I will set class_weight to 'balanced' as I know I have an unbalanced dataset

operations_svc = [("scaler", MinMaxScaler()), ("svc", SVC(class_weight='balanced', random_state=30))]
pipe_svc_model = Pipeline(steps=operations_svc)

# %%
pipe_svc_model.fit(X_train, y_train)
eval_metric(pipe_svc_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[235   7  18]
#  [  6 104  26]
#  [ 18 118 622]]
#               precision    recall  f1-score   support
#
#        Black       0.91      0.90      0.91       260
#     Hispanic       0.45      0.76      0.57       136
#        White       0.93      0.82      0.87       758
#
#     accuracy                           0.83      1154
#    macro avg       0.77      0.83      0.78      1154
# weighted avg       0.87      0.83      0.85      1154
#
#
# Train_Set
# [[ 953   48   37]
#  [  22  457   64]
#  [  54  423 2557]]
#               precision    recall  f1-score   support
#
#        Black       0.93      0.92      0.92      1038
#     Hispanic       0.49      0.84      0.62       543
#        White       0.96      0.84      0.90      3034
#
#     accuracy                           0.86      4615
#    macro avg       0.79      0.87      0.81      4615
# weighted avg       0.90      0.86      0.87      4615

# %%
y_pred = pipe_svc_model.predict(X_test)
print(f'accuracy_score\t\t: {accuracy_score(y_test, y_pred)}')
print(f'balanced_accuracy_score : {balanced_accuracy_score(y_test, y_pred)}')  # recall_score(y_test, y_pred, average='macro')
# Out:
# accuracy_score		: 0.8327556325823223
# balanced_accuracy_score : 0.8297108370443773

# %%
# CROSS VALIDATE

operations_svc = [("scaler", MinMaxScaler()), ("svc", SVC(class_weight='balanced', random_state=30))]
pipe_svc_model = Pipeline(steps=operations_svc)

scoring = {'accuracy': make_scorer(accuracy_score), 'accuracy_balanced': make_scorer(balanced_accuracy_score),
           'precision_Hispanic' : make_scorer(precision_score, average=None, labels=['Hispanic']),
           'recall_Hispanic' : make_scorer(recall_score, average=None, labels=['Hispanic']),
           'f1_Hispanic' : make_scorer(f1_score, average=None, labels=['Hispanic'])}

scores = cross_validate(pipe_svc_model, X_train, y_train, scoring=scoring, cv=5)
df_scores = pd.DataFrame(scores, index=range(1, 6))
df_scores.mean()[2:]
# Out:
# test_accuracy              0.837486
# test_accuracy_balanced     0.834351
# test_precision_Hispanic    0.450366
# test_recall_Hispanic       0.775331
# test_f1_Hispanic           0.569427
# dtype: float64

# %% [markdown]
# ###  SVC Model GridsearchCV

# %%
# GridSearch for 'poly' kernel

operations_svc = [("scaler", MinMaxScaler()), ("svc", SVC(class_weight='balanced', random_state=30))]
pipe_svc_model = Pipeline(steps=operations_svc)

param_grid = [
  {'svc__kernel':['poly'], 'svc__degree':[1, 2, 3], 'svc__C':[0.1, 1, 10], 'svc__gamma':['scale', 'auto', 1, 0.1, 0.01]}
 ]

# I also tried the C regularization parameter for values greater than 10 before ('10' is the optimum value)

svc_grid_model1 = GridSearchCV(estimator = pipe_svc_model,
                          param_grid = param_grid,
                          cv = 5,
                          verbose = 2,
                          scoring = 'recall_macro',
                          n_jobs = -1).fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 45 candidates, totalling 225 fits

# %%
svc_grid_model1.best_params_
# Out:
# {'svc__C': 10, 'svc__degree': 2, 'svc__gamma': 'scale', 'svc__kernel': 'poly'}

# %%
svc_grid_model1.best_score_
# Out:
# 0.8475886868973571

# %%
eval_metric(svc_grid_model1, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[244   5  11]
#  [  7 111  18]
#  [ 26  89 643]]
#               precision    recall  f1-score   support
#
#        Black       0.88      0.94      0.91       260
#     Hispanic       0.54      0.82      0.65       136
#        White       0.96      0.85      0.90       758
#
#     accuracy                           0.86      1154
#    macro avg       0.79      0.87      0.82      1154
# weighted avg       0.89      0.86      0.87      1154
#
#
# Train_Set
# [[ 993   24   21]
#  [  14  482   47]
#  [  56  313 2665]]
#               precision    recall  f1-score   support
#
#        Black       0.93      0.96      0.95      1038
#     Hispanic       0.59      0.89      0.71       543
#        White       0.98      0.88      0.92      3034
#
#     accuracy                           0.90      4615
#    macro avg       0.83      0.91      0.86      4615
# weighted avg       0.92      0.90      0.90      4615

# %%
y_pred = svc_grid_model1.predict(X_test)
print(f'accuracy_score\t\t: {accuracy_score(y_test, y_pred)}')
print(f'balanced_accuracy_score : {balanced_accuracy_score(y_test, y_pred)}')  # recall_score(y_test, y_pred, average='macro')
# Out:
# accuracy_score		: 0.8648180242634316
# balanced_accuracy_score : 0.8676409898239791

# %%
# GridSearch with other kernels

operations_svc = [("scaler", MinMaxScaler()), ("svc", SVC(class_weight='balanced', random_state=30))]
pipe_svc_model = Pipeline(steps=operations_svc)

# I also tried the C regularization parameter for values less than '10' before
param_grid = [
  {'svc__kernel':['sigmoid', 'rbf'], 'svc__C':[1, 10, 100], 'svc__gamma':['scale', 'auto', 0.1, 0.01, 1]},
  {'svc__kernel':['linear', 'precomputed'], 'svc__C':[1, 10, 100]}
 ]

svc_grid_model2 = GridSearchCV(estimator = pipe_svc_model,
                          param_grid = param_grid,
                          cv = 5,
                          verbose = 2,
                          scoring = 'recall_macro',
                          n_jobs = -1).fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits

# %%
svc_grid_model2.best_params_
# Out:
# {'svc__C': 100, 'svc__gamma': 'auto', 'svc__kernel': 'rbf'}

# %%
svc_grid_model2.best_score_
# Out:
# 0.842470350409314

# %%
eval_metric(svc_grid_model2, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[243   5  12]
#  [  6 110  20]
#  [ 23  89 646]]
#               precision    recall  f1-score   support
#
#        Black       0.89      0.93      0.91       260
#     Hispanic       0.54      0.81      0.65       136
#        White       0.95      0.85      0.90       758
#
#     accuracy                           0.87      1154
#    macro avg       0.80      0.87      0.82      1154
# weighted avg       0.89      0.87      0.87      1154
#
#
# Train_Set
# [[ 977   37   24]
#  [  20  465   58]
#  [  57  353 2624]]
#               precision    recall  f1-score   support
#
#        Black       0.93      0.94      0.93      1038
#     Hispanic       0.54      0.86      0.67       543
#        White       0.97      0.86      0.91      3034
#
#     accuracy                           0.88      4615
#    macro avg       0.81      0.89      0.84      4615
# weighted avg       0.91      0.88      0.89      4615

# %%
y_pred = svc_grid_model2.predict(X_test)
print(f'accuracy_score\t\t: {accuracy_score(y_test, y_pred)}')
print(f'balanced_accuracy_score : {balanced_accuracy_score(y_test, y_pred)}')  # recall_score(y_test, y_pred, average='macro')
# Out:
# accuracy_score		: 0.865684575389948
# balanced_accuracy_score : 0.8652272193634913

# %%
from yellowbrick.classifier import PrecisionRecallCurve

operations_svc = [("scaler", MinMaxScaler()), ("svc", SVC(class_weight='balanced', gamma='auto', C=100, random_state=30))]
pipe_svc_model = Pipeline(steps=operations_svc)

viz = PrecisionRecallCurve(
        pipe_svc_model,
        per_class=True, classes= ['Black', 'Hispanic', 'White'],
        cmap='Set1'
)

viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.show();

# %%
viz.score_
# Out:
# {'Black': 0.9729958488956378,
#  'Hispanic': 0.7420900330704385,
#  'White': 0.9717003142967957,
#  'micro': 0.9420612048755549}

# %%
y_pred = svc_grid_model2.predict(X_test)

svc_accuracy = accuracy_score(y_test, y_pred)
svc_accuracy_balanced = balanced_accuracy_score(y_test, y_pred)
svc_f1 = f1_score(y_test, y_pred, average=None, labels=['Hispanic'])
svc_recall = recall_score(y_test, y_pred, average=None, labels=['Hispanic'])
svc_AP = viz.score_['Hispanic']
svc_AP_micro = viz.score_['micro']

# %% [markdown]
# ***

# %% [markdown]
# ## 3. RF (RANDOM FOREST)

# %% [markdown]
# ***DATA Preprocessing***

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
X2 = df.drop('Dodrace', axis=1)
y = df['Dodrace']

# %%
cat = X2.select_dtypes("object").columns
cat
# Out:
# Index(['Gender', 'Subjectsbirthlocation', 'Writingpreference'], dtype='object')

# %%
enc = OrdinalEncoder()
X2[cat] = enc.fit_transform(X2[cat])
X2.head()
# Out:
#    Abdominalextensiondepthsitting  Acromialheight  Acromionradialelength  Anklecircumference  \
# 0                             231            1282                    301                 204
# 1                             194            1379                    320                 207
# 2                             183            1369                    329                 233
# 3                             261            1356                    306                 214
# 4                             309            1303                    308                 214
#
#    Axillaheight  Balloffootcircumference  Balloffootlength  Biacromialbreadth  \
# 0          1180                      222               177                373
# 1          1292                      225               178                372
# 2          1271                      237               196                397
# 3          1250                      240               188                384
# 4          1210                      217               182                378
#
#    Bicepscircumferenceflexed  Bicristalbreadth  Bideltoidbreadth  Bimalleolarbreadth  \
# 0                        315               263               466                  65
# 1                        272               250               430                  64
# 2                        300               276               450                  69
# 3                        364               276               484                  68
# 4                        320               336               525                  67
#
#    Bitragionchinarc  Bitragionsubmandibulararc  Bizygomaticbreadth  Buttockcircumference  \
# 0               338                        301                 141                  1011
# 1               294                        270                 126                   893
# 2               309                        270                 128                   987
# 3               340                        294                 144                  1012
# 4               300                        295                 135                  1281
#
#    Buttockdepth  Buttockheight  Buttockkneelength  Buttockpopliteallength  Calfcircumference  \
# 0           223            836                587                     476                360
# 1           186            900                583                     483                350
# 2           204            861                583                     466                384
# 3           253            897                599                     471                372
# 4           284            811                607                     467                433
#
#    Cervicaleheight  Chestbreadth  Chestcircumference  Chestdepth  Chestheight  Crotchheight  \
# 0             1336           274                 922         245         1095           759
# 1             1440           261                 839         206         1234           835
# 2             1451           287                 874         223         1226           821
# 3             1430           269                1008         285         1170           804
# 4             1362           305                1089         290         1112           726
#
#    Crotchlengthomphalion  Crotchlengthposterioromphalion  Earbreadth  Earlength  Earprotrusion  \
# 0                    557                             310          35         65             16
# 1                    549                             329          32         60             23
# 2                    643                             374          36         65             26
# 3                    640                             351          38         62             22
# 4                    686                             356          34         65             18
#
#    Elbowrestheight  Eyeheightsitting  Footbreadthhorizontal  Footlength  \
# 0              220               713                     91         246
# 1              208               726                     91         249
# 2              204               790                    100         265
# 3              244               775                     97         265
# 4              233               732                     88         247
#
#    Forearmcenterofgriplength  Forearmcircumferenceflexed  Forearmforearmbreadth  \
# 0                        316                         265                    517
# 1                        341                         247                    468
# 2                        343                         262                    488
# 3                        331                         309                    529
# 4                        339                         260                    596
#
#    Forearmhandlength  Functionalleglength  Handbreadth  Handcircumference  Handlength  \
# 0                432                 1028           75                182         184
# 1                463                 1117           78                187         189
# 2                469                 1060           84                198         195
# 3                455                 1069           80                192         186
# 4                447                 1039           78                183         187
#
#    Headbreadth  Headcircumference  Headlength  Heelanklecircumference  Heelbreadth  Hipbreadth  \
# 0          141                548         191                     314           69         345
# 1          138                535         180                     307           60         315
# 2          146                588         207                     331           70         356
# 3          153                593         206                     332           68         337
# 4          140                522         181                     308           63         448
#
#    Hipbreadthsitting  Iliocristaleheight  Interpupillarybreadth  Interscyei  Interscyeii  \
# 0                388                 966                    645         363          399
# 1                335                1048                    595         340          375
# 2                399                1043                    655         345          399
# 3                402                1029                    655         392          435
# 4                499                 964                    635         428          435
#
#    Kneeheightmidpatella  Kneeheightsitting  Lateralfemoralepicondyleheight  \
# 0                   435                496                             447
# 1                   483                532                             492
# 2                   470                530                             469
# 3                   469                520                             478
# 4                   440                491                             441
#
#    Lateralmalleolusheight  Lowerthighcircumference  Mentonsellionlength  Neckcircumference  \
# 0                      55                      404                  118                335
# 1                      69                      334                  115                302
# 2                      64                      401                  135                325
# 3                      67                      402                  118                357
# 4                      63                      479                  114                340
#
#    Neckcircumferencebase  Overheadfingertipreachsitting  Palmlength  Poplitealheight  \
# 0                    368                           1268         113              362
# 1                    345                           1389         110              426
# 2                    369                           1414         122              398
# 3                    386                           1329         115              394
# 4                    358                           1350         116              345
#
#    Radialestylionlength  Shouldercircumference  Shoulderelbowlength  Shoulderlength  \
# 0                   235                   1062                  327             148
# 1                   259                   1014                  346             142
# 2                   258                   1049                  362             164
# 3                   250                   1121                  333             157
# 4                   242                   1151                  329             156
#
#    Sittingheight  Sleevelengthspinewrist  Sleeveoutseam  Span  Stature  Suprasternaleheight  \
# 0            803                     809            513  1647     1560                 1280
# 1            835                     810            575  1751     1665                 1372
# 2            904                     855            568  1779     1711                 1383
# 3            875                     815            536  1708     1660                 1358
# 4            824                     810            559  1702     1572                 1292
#
#    Tenthribheight  Thighcircumference  Thighclearance  Thumbtipreach  Tibialheight  \
# 0            1013                 622             174            736           430
# 1            1107                 524             152            771           475
# 2            1089                 577             164            814           458
# 3            1065                 679             187            736           463
# 4            1030                 766             197            766           429
#
#    Tragiontopofhead  Trochanterionheight  Verticaltrunkcircumferenceusa  Waistbacklength  \
# 0               110                  844                           1488              406
# 1               125                  901                           1470              422
# 2               129                  882                           1542              419
# 3               125                  866                           1627              451
# 4               116                  800                           1698              452
#
#    Waistbreadth  Waistcircumference  Waistdepth  Waistfrontlengthsitting  Waistheightomphalion  \
# 0           295                 850         217                      345                   942
# 1           254                 708         168                      329                  1032
# 2           269                 727         159                      367                  1035
# 3           302                 923         235                      371                   999
# 4           405                1163         300                      380                   911
#
#    Weightkg  Wristcircumference  Wristheight  Gender  Subjectsbirthlocation  Age  \
# 0       657                 152          756     0.0                   41.0   26
# 1       534                 155          815     0.0                   18.0   21
# 2       663                 162          799     0.0                  119.0   23
# 3       782                 173          818     0.0                   30.0   22
# 4       886                 152          762     0.0                  119.0   45
#
#    Writingpreference
# 0                2.0
# 1                2.0
# 2                2.0
# 3                2.0
# 4                2.0

# %%
X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y, test_size=0.2, stratify=y, random_state=30)

# %%
print("Train features shape : ", X_train2.shape)
print("Train target shape   : ", y_train2.shape)
print("Test features shape  : ", X_test2.shape)
print("Test target shape    : ", y_test2.shape)
# Out:
# Train features shape :  (4615, 97)
# Train target shape   :  (4615,)
# Test features shape  :  (1154, 97)
# Test target shape    :  (1154,)

# %% [markdown]
# ### Vanilla RF Model

# %%
rf_model = RandomForestClassifier().fit(X_train2, y_train2)
eval_metric(rf_model, X_train2, y_train2, X_test2, y_test2)
# Out:
# Test_Set
# [[197   0  63]
#  [ 17   8 111]
#  [ 17   6 735]]
#               precision    recall  f1-score   support
#
#        Black       0.85      0.76      0.80       260
#     Hispanic       0.57      0.06      0.11       136
#        White       0.81      0.97      0.88       758
#
#     accuracy                           0.81      1154
#    macro avg       0.74      0.60      0.60      1154
# weighted avg       0.79      0.81      0.77      1154
#
#
# Train_Set
# [[1038    0    0]
#  [   0  543    0]
#  [   0    0 3034]]
#               precision    recall  f1-score   support
#
#        Black       1.00      1.00      1.00      1038
#     Hispanic       1.00      1.00      1.00       543
#        White       1.00      1.00      1.00      3034
#
#     accuracy                           1.00      4615
#    macro avg       1.00      1.00      1.00      4615
# weighted avg       1.00      1.00      1.00      4615

# %%
# I know I have an unbalanced dataset so I will set class_weight to 'balanced'

rf_model = RandomForestClassifier(class_weight='balanced', random_state=30).fit(X_train2, y_train2)

eval_metric(rf_model, X_train2, y_train2, X_test2, y_test2)
# Out:
# Test_Set
# [[174   0  86]
#  [ 11   3 122]
#  [  6   1 751]]
#               precision    recall  f1-score   support
#
#        Black       0.91      0.67      0.77       260
#     Hispanic       0.75      0.02      0.04       136
#        White       0.78      0.99      0.87       758
#
#     accuracy                           0.80      1154
#    macro avg       0.81      0.56      0.56      1154
# weighted avg       0.81      0.80      0.75      1154
#
#
# Train_Set
# [[1038    0    0]
#  [   0  543    0]
#  [   0    0 3034]]
#               precision    recall  f1-score   support
#
#        Black       1.00      1.00      1.00      1038
#     Hispanic       1.00      1.00      1.00       543
#        White       1.00      1.00      1.00      3034
#
#     accuracy                           1.00      4615
#    macro avg       1.00      1.00      1.00      4615
# weighted avg       1.00      1.00      1.00      4615

# %%
# scores got worse, and there is a overfitting problem

# %%
# CROSS VALIDATE

model = RandomForestClassifier(class_weight='balanced', random_state=30)

scoring = {'accuracy': make_scorer(accuracy_score), 'accuracy_balanced': make_scorer(balanced_accuracy_score),
           'precision_Hispanic' : make_scorer(precision_score, average=None, labels=['Hispanic']),
           'recall_Hispanic' : make_scorer(recall_score, average=None, labels=['Hispanic']),
           'f1_Hispanic' : make_scorer(f1_score, average=None, labels=['Hispanic'])}

scores = cross_validate(model, X_train2, y_train2, scoring=scoring, cv=5)
df_scores = pd.DataFrame(scores, index=range(1, 6))
df_scores.mean()[2:]
# Out:
# test_accuracy              0.809751
# test_accuracy_balanced     0.575160
# test_precision_Hispanic    0.712727
# test_recall_Hispanic       0.044122
# test_f1_Hispanic           0.082293
# dtype: float64

# %% [markdown]
# ### RF Model GridsearchCV

# %%
# Grid Search

# this is the second try after seeing the values in the limit
model = RandomForestClassifier(class_weight='balanced', random_state=30)

param_grid = {'n_estimators':[100, 128, 200], 'ccp_alpha':[0.001, 0.0001], 'max_features':[len(X2.columns)/3, 20, 40, 'auto'],
              'max_depth':[11, 17], 'min_samples_split':[20, 40]}

rf_grid_model = GridSearchCV(estimator = model,
                        param_grid = param_grid,
                        cv = 5,
                        verbose = 2,
                        scoring = 'recall_macro',
                        n_jobs = -1).fit(X_train2, y_train2)
# Out:
# Fitting 5 folds for each of 96 candidates, totalling 480 fits

# %%
rf_grid_model.best_params_
# Out:
# {'ccp_alpha': 0.001,
#  'max_depth': 11,
#  'max_features': 'auto',
#  'min_samples_split': 40,
#  'n_estimators': 128}

# %%
rf_grid_model.best_score_
# Out:
# 0.6962220949422654

# %%
eval_metric(rf_grid_model, X_train2, y_train2, X_test2, y_test2)
# Out:
# Test_Set
# [[215  13  32]
#  [ 23  60  53]
#  [ 51  86 621]]
#               precision    recall  f1-score   support
#
#        Black       0.74      0.83      0.78       260
#     Hispanic       0.38      0.44      0.41       136
#        White       0.88      0.82      0.85       758
#
#     accuracy                           0.78      1154
#    macro avg       0.67      0.70      0.68      1154
# weighted avg       0.79      0.78      0.78      1154
#
#
# Train_Set
# [[ 970   17   51]
#  [  27  457   59]
#  [ 135  205 2694]]
#               precision    recall  f1-score   support
#
#        Black       0.86      0.93      0.89      1038
#     Hispanic       0.67      0.84      0.75       543
#        White       0.96      0.89      0.92      3034
#
#     accuracy                           0.89      4615
#    macro avg       0.83      0.89      0.85      4615
# weighted avg       0.90      0.89      0.90      4615

# %%
y_pred = rf_grid_model.predict(X_test2)
print(f'accuracy_score\t\t: {accuracy_score(y_test2, y_pred)}')
print(f'balanced_accuracy_score : {balanced_accuracy_score(y_test2, y_pred)}') # recall_score(y_test2,y_pred2,average='macro')
# Out:
# accuracy_score		: 0.7764298093587522
# balanced_accuracy_score : 0.6957869204105429

# %%
model = RandomForestClassifier(class_weight='balanced', n_estimators=128, max_depth=11, min_samples_split=40, 
                               ccp_alpha= 0.001, random_state=30)

viz = PrecisionRecallCurve(
        model,
        per_class=True, classes= ['Black', 'Hispanic', 'White'],
        cmap='Set1'
)

viz.fit(X_train2, y_train2)
viz.score(X_test2, y_test2)
viz.show();

# %%
viz.score_
# Out:
# {'Black': 0.8796741080698798,
#  'Hispanic': 0.40341761551327704,
#  'White': 0.9171660885079649,
#  'micro': 0.8716287406625545}

# %%
y_pred = rf_grid_model.predict(X_test2)

rf_accuracy = accuracy_score(y_test2, y_pred)
rf_accuracy_balanced = balanced_accuracy_score(y_test2, y_pred)
rf_f1 = f1_score(y_test2, y_pred, average=None, labels=['Hispanic'])
rf_recall = recall_score(y_test2, y_pred, average=None, labels=['Hispanic'])
rf_AP = viz.score_['Hispanic']
rf_AP_micro = viz.score_['micro']

# %% [markdown]
# ## 4. XGBoost

# %% [markdown]
# ### Vanilla XGBoost Model

# %%
from sklearn.utils import class_weight
classes_weights = class_weight.compute_sample_weight(class_weight='balanced', y=y_train2)
classes_weights
# Out:
# array([1.4820167 , 0.50703142, 0.50703142, ..., 1.4820167 , 2.8330264 ,
#        0.50703142])

# %%
xgb_model = XGBClassifier(eval_metric='mlogloss', random_state=30)

# %%
xgb_model.fit(X_train2, y_train2, sample_weight=classes_weights)
eval_metric(xgb_model, X_train2, y_train2, X_test2, y_test2)
# Out:
# Test_Set
# [[231   4  25]
#  [ 12  70  54]
#  [ 18  23 717]]
#               precision    recall  f1-score   support
#
#        Black       0.89      0.89      0.89       260
#     Hispanic       0.72      0.51      0.60       136
#        White       0.90      0.95      0.92       758
#
#     accuracy                           0.88      1154
#    macro avg       0.84      0.78      0.80      1154
# weighted avg       0.88      0.88      0.88      1154
#
#
# Train_Set
# [[1038    0    0]
#  [   0  543    0]
#  [   0    0 3034]]
#               precision    recall  f1-score   support
#
#        Black       1.00      1.00      1.00      1038
#     Hispanic       1.00      1.00      1.00       543
#        White       1.00      1.00      1.00      3034
#
#     accuracy                           1.00      4615
#    macro avg       1.00      1.00      1.00      4615
# weighted avg       1.00      1.00      1.00      4615

# %%
y_pred = xgb_model.predict(X_test2)
print(f'accuracy_score\t\t: {accuracy_score(y_test2, y_pred)}')
print(f'balanced_accuracy_score : {balanced_accuracy_score(y_test2, y_pred)}') # recall_score(y_test2,y_pred2,average='macro')
# Out:
# accuracy_score		: 0.8821490467937608
# balanced_accuracy_score : 0.7830259036839822

# %%
# CROSS VALIDATE

model = XGBClassifier(eval_metric='mlogloss', random_state=30)

scoring = {'accuracy': make_scorer(accuracy_score), 'accuracy_balanced': make_scorer(balanced_accuracy_score),
           'precision_Hispanic' : make_scorer(precision_score, average=None, labels=['Hispanic']),
           'recall_Hispanic' : make_scorer(recall_score, average=None, labels=['Hispanic']),
           'f1_Hispanic' : make_scorer(f1_score, average=None, labels=['Hispanic'])}

scores = cross_validate(model, X_train2, y_train2, scoring=scoring, cv=5, fit_params={"sample_weight":classes_weights})
df_scores = pd.DataFrame(scores, index=range(1, 6))
df_scores.mean()[2:]
# Out:
# test_accuracy              0.875840
# test_accuracy_balanced     0.755308
# test_precision_Hispanic    0.697426
# test_recall_Hispanic       0.436340
# test_f1_Hispanic           0.535031
# dtype: float64

# %% [markdown]
# ### XGBoost Model GridsearchCV

# %%
# Grid Search
# this is the second try after seeing the values in the limit 

xgb_model = XGBClassifier(eval_metric='mlogloss', random_state=30)

param_grid = {'n_estimators':[100, 128], 'max_depth':[3, 4, 6], 'learning_rate': [0.1, 0.3, 0.5],
              'min_child_weight':[1, 3], 'colsample_bytree':[0.5, 1], 'gamma': [0.01, 0.1]}

xgb_grid = GridSearchCV(xgb_model, param_grid, scoring = 'recall_macro', verbose=2, n_jobs = -1)
xgb_grid.fit(X_train2, y_train2, sample_weight=classes_weights)
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# GridSearchCV(estimator=XGBClassifier(base_score=None, booster=None,
#                                      colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None,
#                                      enable_categorical=False,
#                                      eval_metric='mlogloss', gamma=None,
#                                      gpu_id=None, importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None, max_delta_step=None,
#                                      max_depth=None, min_child_weight=None,
#                                      missing=nan, monotone...
#                                      num_parallel_tree=None, predictor=None,
#                                      random_state=30, reg_alpha=None,
#                                      reg_lambda=None, scale_pos_weight=None,
#                                      subsample=None, tree_method=None,
#                                      validate_parameters=None, verbosity=None),
#              n_jobs=-1,
#              param_grid={'colsample_bytree': [0.5, 1], 'gamma': [0.01, 0.1],
#                          'learning_rate': [0.1, 0.3, 0.5],
#                          'max_depth': [3, 4, 6], 'min_child_weight': [1, 3],
#                          'n_estimators': [100, 128]},
#              scoring='recall_macro', verbose=2)

# %%
xgb_grid.best_params_
# Out:
# {'colsample_bytree': 0.5,
#  'gamma': 0.1,
#  'learning_rate': 0.1,
#  'max_depth': 4,
#  'min_child_weight': 3,
#  'n_estimators': 128}

# %%
xgb_grid.best_score_
# Out:
# 0.7882613636545001

# %%
eval_metric(xgb_grid, X_train2, y_train2, X_test2, y_test2)
# Out:
# Test_Set
# [[231  12  17]
#  [ 14  82  40]
#  [ 26  63 669]]
#               precision    recall  f1-score   support
#
#        Black       0.85      0.89      0.87       260
#     Hispanic       0.52      0.60      0.56       136
#        White       0.92      0.88      0.90       758
#
#     accuracy                           0.85      1154
#    macro avg       0.77      0.79      0.78      1154
# weighted avg       0.86      0.85      0.85      1154
#
#
# Train_Set
# [[1019    5   14]
#  [   3  532    8]
#  [  33  144 2857]]
#               precision    recall  f1-score   support
#
#        Black       0.97      0.98      0.97      1038
#     Hispanic       0.78      0.98      0.87       543
#        White       0.99      0.94      0.97      3034
#
#     accuracy                           0.96      4615
#    macro avg       0.91      0.97      0.94      4615
# weighted avg       0.96      0.96      0.96      4615

# %%
y_pred = xgb_grid.predict(X_test2)
print(f'accuracy_score\t\t: {accuracy_score(y_test2, y_pred)}')
print(f'balanced_accuracy_score : {balanced_accuracy_score(y_test2, y_pred)}') # recall_score(y_test2,y_pred2,average='macro')
# Out:
# accuracy_score		: 0.8509532062391681
# balanced_accuracy_score : 0.7913294889703395

# %%
model = XGBClassifier(gamma=0.1, min_child_weight=3, max_depth=4, eval_metric='mlogloss',
                      n_estimators=128, colsample_bytree=0.5, learning_rate=0.1, random_state=30)

viz = PrecisionRecallCurve(
        model,
        per_class=True, classes= ['Black', 'Hispanic', 'White'],
        cmap='Set1',
        sample_weight=classes_weights
)

viz.fit(X_train2, y_train2)
viz.score(X_test2, y_test2)
viz.show();

# %%
viz.score_
# Out:
# {'Black': 0.9413897862762441,
#  'Hispanic': 0.6632756863344947,
#  'White': 0.9521451258505995,
#  'micro': 0.9302507664836311}

# %%
y_pred = xgb_grid.predict(X_test2)

xgb_accuracy = accuracy_score(y_test2, y_pred)
xgb_accuracy_balanced = balanced_accuracy_score(y_test2, y_pred)
xgb_f1 = f1_score(y_test2, y_pred, average=None, labels=['Hispanic'])
xgb_recall = recall_score(y_test2, y_pred, average=None, labels=['Hispanic'])
xgb_AP = viz.score_['Hispanic']
xgb_AP_micro = viz.score_['micro']

# %% [markdown]
# ***

# %% [markdown]
# ## Comparing Models

# %%
compare = pd.DataFrame({"Model": ["Logistic Regression", "SVM",  "Random Forest", "XGBoost"],
                "Accuracy": [log_accuracy, svc_accuracy, rf_accuracy, xgb_accuracy],
                "Accuracy_Balanced": [log_accuracy_balanced, svc_accuracy_balanced, rf_accuracy_balanced, xgb_accuracy_balanced],
                "F1": [log_f1[0], svc_f1[0], rf_f1[0], xgb_f1[0]],
                "Recall": [log_recall[0], svc_recall[0], rf_recall[0], xgb_recall[0]],
                "AP": [log_AP, svc_AP, rf_AP, xgb_AP],
                "AP_Micro": [log_AP_micro, svc_AP_micro, rf_AP_micro, xgb_AP_micro]})

# %%
# recall, f1 and AP scores were calculated for the 'Hispanic' class

fig, ax = plt.subplots(2,3, figsize=(16,10))

def labels(ax, i, k):
    for p in ax[i][k].patches:
        ax[i][k].annotate(format(p.get_height(), '.3f'), (p.get_x() + p.get_width() / 2., p.get_height()),
                       ha='center', va='center', xytext=(1,7), textcoords='offset points', fontsize=11)
        ax[i][k].set_ylim(0, 1)
        
palette = {'Logistic Regression': 'blueviolet', 'SVM': 'brown', 'Random Forest': 'orange', 'XGBoost': 'seagreen'}
        
sns.barplot(x='Model', y='Accuracy', data=compare.sort_values('Accuracy', ascending=False), palette=palette, 
            ax = ax[0][0]), labels(ax,0,0)
sns.barplot(x='Model', y='Accuracy_Balanced', data=compare.sort_values('Accuracy_Balanced', ascending=False), 
            palette=palette, ax = ax[0][1]), labels(ax,0,1)
sns.barplot(x='Model', y='F1', data=compare.sort_values('F1', ascending=False), palette=palette, ax = ax[0][2]), labels(ax,0,2)
sns.barplot(x='Model', y='Recall', data=compare.sort_values('Recall', ascending=False), palette=palette, 
            ax = ax[1][0]), labels(ax,1,0)
sns.barplot(x='Model', y='AP', data=compare.sort_values('AP', ascending=False), palette=palette, ax = ax[1][1]), labels(ax,1,1)
sns.barplot(x='Model', y='AP_Micro', data=compare.sort_values('AP_Micro', ascending=False), palette=palette, 
            ax = ax[1][2]), labels(ax,1,2)

fig.suptitle('MODEL COMPARISONS')
fig.tight_layout();

# %% [raw]
# # for this dataset, logistic regression model ensured better scores than the others

# %% [markdown]
# ***Other Evaluation Metrics***

# %%
# Overall performance scores for imbalanced datasets

# %%
from sklearn.metrics import matthews_corrcoef

y_pred = log_grid_model2.predict(X_test)

matthews_corrcoef(y_test, y_pred)
# Out:
# 0.7622944390084512

# %%
from sklearn.metrics import cohen_kappa_score

y_pred = log_grid_model2.predict(X_test)

cohen_kappa_score(y_test, y_pred)
# Out:
# 0.7548430991391281

# %%
# imbalance accuracy metric

def IAM(c):
    '''
    c is a nested list presenting the confusion matrix of the classifier (len(c)>=2)
    '''
    l  = len(c)
    iam = 0

    for i in range(l):
        sum_row, sum_col = 0, 0      
        sum_row_no_i, sum_col_no_i = 0, 0
     
        for j in range(l):
            sum_row += c[i][j]
            sum_col += c[j][i]
            if j is not i:
                sum_row_no_i += c[i][j] 
                sum_col_no_i += c[j][i]
        iam += (c[i][i] - max(sum_row_no_i, sum_col_no_i))/max(sum_row, sum_col)
    return   iam/l

# %%
y_pred = log_grid_model2.predict(X_test)
c = confusion_matrix(y_test, y_pred)
print(f'IAM : {IAM(c)}')
# Out:
# IAM : 0.5257537355435636

# %% [markdown]
# ---
# ---

# %% [markdown]
# ---
# ---

# %% [markdown]
# # SMOTE

# %% [markdown]
# ##  Smote implement

# %%
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline as imbpipeline

# %%
over = SMOTE(sampling_strategy={"Hispanic": 1050})
under = RandomUnderSampler(sampling_strategy={"White": 2600})

# %%
steps = [('o', over), ('u', under)]
pipeline = imbpipeline(steps=steps)
X_resampled, y_resampled = pipeline.fit_resample(X_train, y_train)

# %%
y_resampled.value_counts()
# Out:
# White       2600
# Hispanic    1050
# Black       1038
# Name: Dodrace, dtype: int64

# %%
y_train.value_counts()
# Out:
# White       3034
# Black       1038
# Hispanic     543
# Name: Dodrace, dtype: int64

# %% [markdown]
# ## Logistic Regression Over/Under Sampling

# %%
operations = [('o', over), ('u', under), ("scaler", MinMaxScaler()), 
              ("log", LogisticRegression(class_weight='balanced', max_iter=1000, solver='saga',
                l1_ratio=0.1, C=5, penalty='elasticnet', random_state=30))]

smote_pipeline = imbpipeline(steps=operations)
smote_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('o', SMOTE(sampling_strategy={'Hispanic': 1050})),
#                 ('u', RandomUnderSampler(sampling_strategy={'White': 2600})),
#                 ('scaler', MinMaxScaler()),
#                 ('log',
#                  LogisticRegression(C=5, class_weight='balanced', l1_ratio=0.1,
#                                     max_iter=1000, penalty='elasticnet',
#                                     random_state=30, solver='saga'))])

# %%
eval_metric(smote_pipeline, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[244   4  12]
#  [  8 102  26]
#  [ 21  84 653]]
#               precision    recall  f1-score   support
#
#        Black       0.89      0.94      0.92       260
#     Hispanic       0.54      0.75      0.63       136
#        White       0.95      0.86      0.90       758
#
#     accuracy                           0.87      1154
#    macro avg       0.79      0.85      0.81      1154
# weighted avg       0.89      0.87      0.87      1154
#
#
# Train_Set
# [[ 986   28   24]
#  [  25  424   94]
#  [  51  268 2715]]
#               precision    recall  f1-score   support
#
#        Black       0.93      0.95      0.94      1038
#     Hispanic       0.59      0.78      0.67       543
#        White       0.96      0.89      0.93      3034
#
#     accuracy                           0.89      4615
#    macro avg       0.83      0.88      0.85      4615
# weighted avg       0.91      0.89      0.90      4615

# %%
model = smote_pipeline = imbpipeline(steps=operations)

scores = cross_validate(model, X_train, y_train, scoring = scoring, cv = 10)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_accuracy              0.865868
# test_accuracy_balanced     0.831053
# test_precision_Hispanic    0.523541
# test_recall_Hispanic       0.696633
# test_f1_Hispanic           0.596632
# dtype: float64

# %%
# I couldn't get better scores

# %% [markdown]
# ## Xgboost Over/ Under Sampling

# %% [markdown]
# ***I'll check the XGBoost scores with smote just to try***

# %%
over2 = SMOTE(sampling_strategy={"Hispanic": 1400})
under2 = RandomUnderSampler(sampling_strategy={"White": 2500})

# %%
steps2 = [('o', over2), ('u', under2)]
pipeline2 = imbpipeline(steps=steps2)
X_resampled2, y_resampled2 = pipeline2.fit_resample(X_train2, y_train2)

# %%
operations2 = [('o', over2), ('u', under2), ("scaler", MinMaxScaler()), 
               ("log", XGBClassifier(gamma=0.01, subsample=1, max_depth=4, eval_metric='mlogloss',
                      n_estimators=128, colsample_bytree=0.5, learning_rate=0.1, random_state=30))]

smote_pipeline2 = imbpipeline(steps=operations2)
smote_pipeline2.fit(X_train2, y_train2)
# Out:
# Pipeline(steps=[('o', SMOTE(sampling_strategy={'Hispanic': 1400})),
#                 ('u', RandomUnderSampler(sampling_strategy={'White': 2500})),
#                 ('scaler', MinMaxScaler()),
#                 ('log',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=0.5, enable_categorical=False,
#                                eval_metric='mlogloss', gamma=0.01, gpu_id=-1,
#                                importance_type=No...ction_constraints='',
#                                learning_rate=0.1, max_delta_step=0, max_depth=4,
#                                min_child_weight=1, missing=nan,
#                                monotone_constraints='()', n_estimators=128,
#                                n_jobs=8, num_parallel_tree=1,
#                                objective='multi:softprob', predictor='auto',
#                                random_state=30, reg_alpha=0, reg_lambda=1,
#                                scale_pos_weight=None, subsample=1,
#                                tree_method='exact', validate_parameters=1,
#                                verbosity=None))])

# %%
eval_metric(smote_pipeline, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[244   4  12]
#  [  8 102  26]
#  [ 21  84 653]]
#               precision    recall  f1-score   support
#
#        Black       0.89      0.94      0.92       260
#     Hispanic       0.54      0.75      0.63       136
#        White       0.95      0.86      0.90       758
#
#     accuracy                           0.87      1154
#    macro avg       0.79      0.85      0.81      1154
# weighted avg       0.89      0.87      0.87      1154
#
#
# Train_Set
# [[ 986   28   24]
#  [  25  424   94]
#  [  51  268 2715]]
#               precision    recall  f1-score   support
#
#        Black       0.93      0.95      0.94      1038
#     Hispanic       0.59      0.78      0.67       543
#        White       0.96      0.89      0.93      3034
#
#     accuracy                           0.89      4615
#    macro avg       0.83      0.88      0.85      4615
# weighted avg       0.91      0.89      0.90      4615

# %%
model2 = smote_pipeline2 = imbpipeline(steps=operations2)

scores = cross_validate(model2, X_train2, y_train2, scoring = scoring, cv = 10)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_accuracy              0.855249
# test_accuracy_balanced     0.746241
# test_precision_Hispanic    0.544475
# test_recall_Hispanic       0.479057
# test_f1_Hispanic           0.508616
# dtype: float64

# %% [markdown]
# ***

# %% [markdown]
# #  SHAP

# %%
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Lasso regularization (l1) should be used as a penalty for feature selection
model_shap = LogisticRegression(class_weight='balanced', max_iter=1000, random_state=30, penalty='l1', solver='saga')
model_shap.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(class_weight='balanced', max_iter=1000, penalty='l1',
#                    random_state=30, solver='saga')

# %%
eval_metric(model_shap, X_train_scaled, y_train, X_test_scaled, y_test)
# Out:
# Test_Set
# [[243   6  11]
#  [  5 109  22]
#  [ 21  94 643]]
#               precision    recall  f1-score   support
#
#        Black       0.90      0.93      0.92       260
#     Hispanic       0.52      0.80      0.63       136
#        White       0.95      0.85      0.90       758
#
#     accuracy                           0.86      1154
#    macro avg       0.79      0.86      0.82      1154
# weighted avg       0.89      0.86      0.87      1154
#
#
# Train_Set
# [[ 970   39   29]
#  [  20  450   73]
#  [  64  352 2618]]
#               precision    recall  f1-score   support
#
#        Black       0.92      0.93      0.93      1038
#     Hispanic       0.54      0.83      0.65       543
#        White       0.96      0.86      0.91      3034
#
#     accuracy                           0.87      4615
#    macro avg       0.81      0.88      0.83      4615
# weighted avg       0.90      0.87      0.88      4615

# %%
import shap
explainer = shap.Explainer(model_shap, X_train_scaled)
shap_values = explainer.shap_values(X_test_scaled)

# %%
shap.summary_plot(shap_values, X_train_scaled, max_display=300, feature_names=X.columns)

# %%
# list(X.columns)
# I will choose pure features that can help to separate labels better

# %%
hispanic = ['Subjectsbirthlocation','Stature','Buttockkneelength','Bideltoidbreadth','Handcircumference','Wristcircumference', 
    'Bizygomaticbreadth', 'Calfcircumference', 'Waistfrontlengthsitting', 'Trochanterionheight', 'Waistcircumference', 
    'Neckcircumference','Sleevelengthspinewrist','Eyeheightsitting','Acromialheight','Forearmhandlength','Waistdepth', 
    'Tenthribheight','Kneeheightmidpatella','Earprotrusion','Elbowrestheight','Poplitealheight','Balloffootlength',
    'Thighcircumference']

# %%
X3 = df[hispanic]
X3 = pd.get_dummies(data=X3, drop_first=True)
y = df.Dodrace

# %%
X3.shape
# Out:
# (5769, 158)

# %%
X_train3, X_test3, y_train3, y_test3 = train_test_split(X3, y, test_size=0.2, random_state=30, stratify =y)

# %%
operations = [("scaler", MinMaxScaler()), ("log", LogisticRegression(class_weight='balanced', max_iter=1000, 
                                                                     random_state=30, penalty='l1', solver='saga'))]
pipe_shap_model = Pipeline(steps=operations)
pipe_shap_model.fit(X_train3, y_train3)
# Out:
# Pipeline(steps=[('scaler', MinMaxScaler()),
#                 ('log',
#                  LogisticRegression(class_weight='balanced', max_iter=1000,
#                                     penalty='l1', random_state=30,
#                                     solver='saga'))])

# %%
eval_metric(pipe_shap_model, X_train3, y_train3, X_test3, y_test3)
# Out:
# Test_Set
# [[230   8  22]
#  [  8 101  27]
#  [ 56 119 583]]
#               precision    recall  f1-score   support
#
#        Black       0.78      0.88      0.83       260
#     Hispanic       0.44      0.74      0.55       136
#        White       0.92      0.77      0.84       758
#
#     accuracy                           0.79      1154
#    macro avg       0.72      0.80      0.74      1154
# weighted avg       0.83      0.79      0.80      1154
#
#
# Train_Set
# [[ 914   56   68]
#  [  26  435   82]
#  [ 163  443 2428]]
#               precision    recall  f1-score   support
#
#        Black       0.83      0.88      0.85      1038
#     Hispanic       0.47      0.80      0.59       543
#        White       0.94      0.80      0.87      3034
#
#     accuracy                           0.82      4615
#    macro avg       0.75      0.83      0.77      4615
# weighted avg       0.86      0.82      0.83      4615

# %%
# scores got worse

# %%
# Cross Validate

model = Pipeline(steps=operations)

scores = cross_validate(model, X_train3, y_train3, scoring=scoring, cv=10)
df_scores = pd.DataFrame(scores, index=range(1, 11))
df_scores.mean()[2:]
# Out:
# test_accuracy              0.804983
# test_accuracy_balanced     0.801462
# test_precision_Hispanic    0.445215
# test_recall_Hispanic       0.742323
# test_f1_Hispanic           0.555995
# dtype: float64

# %%
from yellowbrick.classifier import PrecisionRecallCurve
model = Pipeline(steps=operations)

viz = PrecisionRecallCurve(
    model,
    per_class=True, classes= ["Black", "Hispanic", "White"],
    cmap="Set1"
)
viz.fit(X_train3, y_train3)
viz.score(X_test3, y_test3)
viz.show();

# %% [markdown]
# ## SMOTE for X3 dataset

# %%
operations = [('o', over), ('u', under), ("scaler", MinMaxScaler()), 
              ("log", LogisticRegression(class_weight='balanced', max_iter=1000, solver='saga',
                l1_ratio=0.1, C=5, penalty='elasticnet', random_state=30))]

smote_pipeline2 = imbpipeline(steps=operations)
smote_pipeline2.fit(X_train3, y_train3)
# Out:
# Pipeline(steps=[('o', SMOTE(sampling_strategy={'Hispanic': 1050})),
#                 ('u', RandomUnderSampler(sampling_strategy={'White': 2600})),
#                 ('scaler', MinMaxScaler()),
#                 ('log',
#                  LogisticRegression(C=5, class_weight='balanced', l1_ratio=0.1,
#                                     max_iter=1000, penalty='elasticnet',
#                                     random_state=30, solver='saga'))])

# %%
eval_metric(smote_pipeline2, X_train3, y_train3, X_test3, y_test3)
# Out:
# Test_Set
# [[221  16  23]
#  [ 10  90  36]
#  [ 61  90 607]]
#               precision    recall  f1-score   support
#
#        Black       0.76      0.85      0.80       260
#     Hispanic       0.46      0.66      0.54       136
#        White       0.91      0.80      0.85       758
#
#     accuracy                           0.80      1154
#    macro avg       0.71      0.77      0.73      1154
# weighted avg       0.82      0.80      0.80      1154
#
#
# Train_Set
# [[ 925   50   63]
#  [  48  380  115]
#  [ 170  333 2531]]
#               precision    recall  f1-score   support
#
#        Black       0.81      0.89      0.85      1038
#     Hispanic       0.50      0.70      0.58       543
#        White       0.93      0.83      0.88      3034
#
#     accuracy                           0.83      4615
#    macro avg       0.75      0.81      0.77      4615
# weighted avg       0.85      0.83      0.84      4615

# %%
# Cross Validate

model = imbpipeline(steps=operations)

scores = cross_validate(model, X_train3, y_train3, scoring=scoring, cv=10)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_accuracy              0.818201
# test_accuracy_balanced     0.789433
# test_precision_Hispanic    0.483098
# test_recall_Hispanic       0.672323
# test_f1_Hispanic           0.560117
# dtype: float64

# %% [markdown]
# ***

# %% [markdown]
# # Find the best threshold for multiclassification

# %%
# Since the worst scores belong to the 'hispanic' class, I will adjust it that way

# %%
y2 = y.map({"Hispanic":1, "White":0, "Black":0})

# %%
X_train4, X_test4, y_train4, y_test4 = train_test_split(X3, y2, test_size=0.2, random_state=30, stratify =y2)

# %%
operations = [("scaler", MinMaxScaler()), ("log", LogisticRegression(class_weight='balanced', max_iter=1000, solver='saga',
                                            l1_ratio=0.1, C=5, penalty='elasticnet', random_state=30))]

pipe_shap_model2 = Pipeline(steps=operations)
pipe_shap_model2.fit(X_train4, y_train4)
# Out:
# Pipeline(steps=[('scaler', MinMaxScaler()),
#                 ('log',
#                  LogisticRegression(C=5, class_weight='balanced', l1_ratio=0.1,
#                                     max_iter=1000, penalty='elasticnet',
#                                     random_state=30, solver='saga'))])

# %%
eval_metric(pipe_shap_model2, X_train4, y_train4, X_test4, y_test4)
# Out:
# Test_Set
# [[839 179]
#  [ 27 109]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.82      0.89      1018
#            1       0.38      0.80      0.51       136
#
#     accuracy                           0.82      1154
#    macro avg       0.67      0.81      0.70      1154
# weighted avg       0.90      0.82      0.85      1154
#
#
# Train_Set
# [[3347  725]
#  [  97  446]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.82      0.89      4072
#            1       0.38      0.82      0.52       543
#
#     accuracy                           0.82      4615
#    macro avg       0.68      0.82      0.71      4615
# weighted avg       0.90      0.82      0.85      4615

# %%
from sklearn.metrics import plot_roc_curve, plot_precision_recall_curve, roc_auc_score, auc, roc_curve
from sklearn.metrics import average_precision_score, precision_recall_curve

operations = [("scaler", MinMaxScaler()), ("log", LogisticRegression(max_iter=10000, random_state=30))]
log_basic_model = Pipeline(steps=operations)

log_basic_model.fit(X_train4, y_train4)
plot_precision_recall_curve(log_basic_model, X_train4, y_train4);

# %%
y_pred_proba = log_basic_model.predict_proba(X_train4)
average_precision_score(y_train4, y_pred_proba[:,1])
# Out:
# 0.6846256925958736

# %%
precisions, recalls, thresholds = precision_recall_curve(y_train4, y_pred_proba[:,1])

# %%
optimal_idx = np.argmax((2 * precisions * recalls) / (precisions + recalls))
optimal_threshold = thresholds[optimal_idx]
optimal_threshold
# Out:
# 0.2987902741160623

# %%
y_pred2 = pd.Series(pipe_shap_model2.predict_proba(X_test4)[:,1]).apply(lambda x : 1 if x >= optimal_threshold else 0)

# %%
print(confusion_matrix(y_test4,y_pred2))
print(classification_report(y_test4,y_pred2))
# Out:
# [[672 346]
#  [ 19 117]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.66      0.79      1018
#            1       0.25      0.86      0.39       136
#
#     accuracy                           0.68      1154
#    macro avg       0.61      0.76      0.59      1154
# weighted avg       0.89      0.68      0.74      1154

# %%
y_train_pred2 = pd.Series(pipe_shap_model2.predict_proba(X_train4)[:,1]).apply(lambda x : 1 if x >= optimal_threshold else 0)
print(confusion_matrix(y_train4, y_train_pred2))
print(classification_report(y_train4, y_train_pred2))
# Out:
# [[2787 1285]
#  [  36  507]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.68      0.81      4072
#            1       0.28      0.93      0.43       543
#
#     accuracy                           0.71      4615
#    macro avg       0.64      0.81      0.62      4615
# weighted avg       0.90      0.71      0.76      4615

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import precision_score, recall_score, accuracy_score, f1_score

def CV(n, est, X, y, optimal_threshold):
    skf = StratifiedKFold(n_splits = n, shuffle = True, random_state = 42)
    acc_scores = []
    pre_scores = []
    rec_scores = []
    f1_scores  = []
    
    X = X.reset_index(drop=True)
    y = y.reset_index(drop=True)
    
    for train_index, test_index in skf.split(X, y):
        
        X_train = X.loc[train_index]
        y_train = y.loc[train_index]
        X_test = X.loc[test_index]
        y_test = y.loc[test_index]
        
        
        est = est
        est.fit(X_train, y_train)
        y_pred = est.predict(X_test)
        y_pred_proba = est.predict_proba(X_test)
             
        y_pred2 = pd.Series(y_pred_proba[:,1]).apply(lambda x : 1 if x >= optimal_threshold else 0)
        
        acc_scores.append(accuracy_score(y_test, y_pred2))
        pre_scores.append(precision_score(y_test, y_pred2, pos_label=1))
        rec_scores.append(recall_score(y_test, y_pred2, pos_label=1))
        f1_scores.append(f1_score(y_test, y_pred2, pos_label=1))
    
    print(f'Accuracy {np.mean(acc_scores)*100:>10,.2f}%  std {np.std(acc_scores)*100:.2f}%')
    print(f'Precision-1 {np.mean(pre_scores)*100:>7,.2f}%  std {np.std(pre_scores)*100:.2f}%')
    print(f'Recall-1 {np.mean(rec_scores)*100:>10,.2f}%  std {np.std(rec_scores)*100:.2f}%')
    print(f'F1_score-1 {np.mean(f1_scores)*100:>8,.2f}%  std {np.std(f1_scores)*100:.2f}%')

# %%
operations = [("scaler", MinMaxScaler()), ("log", LogisticRegression(class_weight='balanced', max_iter=1000, solver='saga',
                                            l1_ratio=0.1, C=5, penalty='elasticnet', random_state=30))]
model = Pipeline(steps=operations)
CV(10, model, X_train4, y_train4, optimal_threshold)
# Out:
# Accuracy      69.92%  std 2.11%
# Precision-1   26.61%  std 1.65%
# Recall-1      88.02%  std 3.04%
# F1_score-1    40.84%  std 2.15%

# %% [markdown]
# # Before the Deployment
# - Choose the model that works best based on your chosen metric
# - For final step, fit the best model with whole dataset to get better performance.
# - And your model ready to deploy, dump your model and scaler.

# %%
operations = [("scaler", MinMaxScaler()), ("log", LogisticRegression(class_weight='balanced', max_iter=1000, solver='saga',
                                            l1_ratio=0.1, C=5, penalty='elasticnet', random_state=30))]
final_model = Pipeline(steps=operations)

# %%
final_model.fit(X, y)
# Out:
# Pipeline(steps=[('scaler', MinMaxScaler()),
#                 ('log',
#                  LogisticRegression(C=5, class_weight='balanced', l1_ratio=0.1,
#                                     max_iter=1000, penalty='elasticnet',
#                                     random_state=30, solver='saga'))])

# %%
import pickle
pickle.dump(final_model, open('final_model_soldiers', 'wb'))

# %%
X.describe()
# Out:
#        Abdominalextensiondepthsitting  Acromialheight  Acromionradialelength  Anklecircumference  \
# count                     5769.000000     5769.000000            5769.000000         5769.000000
# mean                       247.254290     1408.630265             328.071590          225.201768
# std                         37.457748       78.303123              20.444554           15.965783
# min                        155.000000     1146.000000             249.000000          156.000000
# 25%                        220.000000     1353.000000             314.000000          214.000000
# 50%                        243.000000     1412.000000             328.000000          225.000000
# 75%                        272.000000     1464.000000             342.000000          235.000000
# max                        451.000000     1683.000000             393.000000          293.000000
#
#        Axillaheight  Balloffootcircumference  Balloffootlength  Biacromialbreadth  \
# count   5769.000000              5769.000000       5769.000000        5769.000000
# mean    1301.902583               244.408043        195.118911         399.706015
# std       71.260913                16.803556         13.379000          30.124094
# min     1062.000000               186.000000        151.000000         283.000000
# 25%     1252.000000               233.000000        186.000000         377.000000
# 50%     1304.000000               245.000000        196.000000         404.000000
# 75%     1351.000000               256.000000        205.000000         422.000000
# max     1553.000000               306.000000        245.000000         489.000000
#
#        Bicepscircumferenceflexed  Bicristalbreadth  Bideltoidbreadth  Bimalleolarbreadth  \
# count                5769.000000       5769.000000       5769.000000         5769.000000
# mean                  341.663027        274.903449        491.454845           72.335413
# std                    41.270615         19.239580         42.011888            5.326965
# min                   216.000000        197.000000        357.000000           55.000000
# 25%                   312.000000        262.000000        461.000000           68.000000
# 50%                   342.000000        274.000000        493.000000           73.000000
# 75%                   370.000000        288.000000        520.000000           76.000000
# max                   490.000000        362.000000        637.000000           91.000000
#
#        Bitragionchinarc  Bitragionsubmandibulararc  Bizygomaticbreadth  Buttockcircumference  \
# count       5769.000000                5769.000000         5769.000000           5769.000000
# mean         324.962212                 306.677760          139.529381           1022.059456
# std           17.050426                  20.818789            7.248670             75.952953
# min          267.000000                 245.000000          116.000000            737.000000
# 25%          314.000000                 292.000000          134.000000            970.000000
# 50%          326.000000                 307.000000          140.000000           1019.000000
# 75%          336.000000                 321.000000          145.000000           1071.000000
# max          385.000000                 390.000000          166.000000           1341.000000
#
#        Buttockdepth  Buttockheight  Buttockkneelength  Buttockpopliteallength  Calfcircumference  \
# count   5769.000000    5769.000000        5769.000000             5769.000000        5769.000000
# mean     242.234356     872.112845         610.449991              498.331773         386.316519
# std       26.409001      54.064846          33.120828               28.512562          30.577787
# min      168.000000     656.000000         479.000000              380.000000         266.000000
# 25%      223.000000     834.000000         587.000000              478.000000         365.000000
# 50%      241.000000     870.000000         610.000000              498.000000         385.000000
# 75%      259.000000     908.000000         633.000000              518.000000         406.000000
# max      349.000000    1080.000000         736.000000              605.000000         523.000000
#
#        Cervicaleheight  Chestbreadth  Chestcircumference   Chestdepth  Chestheight  Crotchheight  \
# count      5769.000000   5769.000000         5769.000000  5769.000000  5769.000000   5769.000000
# mean       1479.952158    283.232623         1024.206622   252.322586  1254.290172    827.105738
# std          83.590746     20.612214          100.375776    26.660255    78.882449     54.056267
# min        1208.000000    213.000000          695.000000   170.000000  1000.000000    610.000000
# 25%        1421.000000    269.000000          952.000000   234.000000  1199.000000    789.000000
# 50%        1487.000000    283.000000         1023.000000   251.000000  1261.000000    827.000000
# 75%        1539.000000    297.000000         1093.000000   270.000000  1310.000000    864.000000
# max        1738.000000    363.000000         1469.000000   383.000000  1506.000000   1031.000000
#
#        Crotchlengthomphalion  Crotchlengthposterioromphalion   Earbreadth    Earlength  \
# count            5769.000000                     5769.000000  5769.000000  5769.000000
# mean              622.693708                      351.880222    35.175420    62.606171
# std                45.087220                       29.807293     3.221118     4.861629
# min               473.000000                      243.000000    25.000000    46.000000
# 25%               592.000000                      331.000000    33.000000    59.000000
# 50%               621.000000                      351.000000    35.000000    62.000000
# 75%               652.000000                      372.000000    37.000000    66.000000
# max               799.000000                      468.000000    46.000000    81.000000
#
#        Earprotrusion  Elbowrestheight  Eyeheightsitting  Footbreadthhorizontal   Footlength  \
# count    5769.000000      5769.000000       5769.000000            5769.000000  5769.000000
# mean       22.227249       240.553302        786.399203              98.915063   263.512394
# std         3.149012        28.595503         41.843182               6.658949    17.231642
# min        13.000000       138.000000        654.000000              77.000000   210.000000
# 25%        20.000000       222.000000        757.000000              94.000000   252.000000
# 50%        22.000000       241.000000        788.000000              99.000000   265.000000
# 75%        24.000000       260.000000        816.000000             104.000000   276.000000
# max        34.000000       345.000000        912.000000             126.000000   323.000000
#
#        Forearmcenterofgriplength  Forearmcircumferenceflexed  Forearmforearmbreadth  \
# count                5769.000000                 5769.000000            5769.000000
# mean                  339.458832                  295.661640             553.098284
# std                    23.081597                   29.857253              62.255490
# min                   258.000000                  200.000000             376.000000
# 25%                   323.000000                  273.000000             507.000000
# 50%                   341.000000                  297.000000             554.000000
# 75%                   356.000000                  317.000000             598.000000
# max                   416.000000                  402.000000             778.000000
#
#        Forearmhandlength  Functionalleglength  Handbreadth  Handcircumference   Handlength  \
# count        5769.000000          5769.000000  5769.000000        5769.000000  5769.000000
# mean          467.898769          1104.347201    85.098111         204.215635   189.574796
# std            29.785714            67.719289     6.320915          15.486056    11.422521
# min           342.000000           835.000000    67.000000         160.000000   150.000000
# 25%           447.000000          1057.000000    80.000000         192.000000   182.000000
# 50%           470.000000          1106.000000    86.000000         206.000000   190.000000
# 75%           488.000000          1150.000000    90.000000         216.000000   197.000000
# max           574.000000          1316.000000   105.000000         248.000000   239.000000
#
#        Headbreadth  Headcircumference   Headlength  Heelanklecircumference  Heelbreadth  \
# count  5769.000000        5769.000000  5769.000000             5769.000000  5769.000000
# mean    152.043682         570.424337   196.640839              333.274918    70.834113
# std       6.176650          18.245395     8.322907               22.260663     5.932530
# min     131.000000         502.000000   168.000000              258.000000    48.000000
# 25%     148.000000         558.000000   191.000000              317.000000    67.000000
# 50%     152.000000         570.000000   197.000000              335.000000    71.000000
# 75%     156.000000         583.000000   202.000000              349.000000    75.000000
# max     177.000000         635.000000   225.000000              403.000000    93.000000
#
#         Hipbreadth  Hipbreadthsitting  Iliocristaleheight  Interpupillarybreadth   Interscyei  \
# count  5769.000000        5769.000000         5769.000000            5769.000000  5769.000000
# mean    348.930837         386.417923         1042.152366             632.534928   412.773964
# std      25.191381          32.273943           59.102058              36.644621    42.868488
# min     264.000000         280.000000          816.000000             510.000000   270.000000
# 25%     332.000000         364.000000         1001.000000             610.000000   382.000000
# 50%     347.000000         384.000000         1042.000000             635.000000   412.000000
# 75%     364.000000         407.000000         1083.000000             655.000000   443.000000
# max     473.000000         541.000000         1253.000000             770.000000   562.000000
#
#        Interscyeii  Kneeheightmidpatella  Kneeheightsitting  Lateralfemoralepicondyleheight  \
# count  5769.000000           5769.000000        5769.000000                     5769.000000
# mean    433.017334            476.665280         541.376668                      484.316693
# std      38.513152             32.643757          33.737243                       28.977173
# min     306.000000            346.000000         407.000000                      352.000000
# 25%     405.000000            453.000000         517.000000                      465.000000
# 50%     435.000000            477.000000         543.000000                      484.000000
# 75%     461.000000            498.000000         565.000000                      504.000000
# max     577.000000            612.000000         666.000000                      594.000000
#
#        Lateralmalleolusheight  Lowerthighcircumference  Mentonsellionlength  Neckcircumference  \
# count              5769.00000              5769.000000          5769.000000        5769.000000
# mean                 69.76183               406.943144           119.601664         376.127578
# std                   7.24541                33.098625             7.860484          39.724315
# min                  43.00000               290.000000            91.000000         275.000000
# 25%                  65.00000               384.000000           114.000000         342.000000
# 50%                  70.00000               406.000000           120.000000         381.000000
# 75%                  75.00000               427.000000           125.000000         405.000000
# max                  93.00000               600.000000           156.000000         514.000000
#
#        Neckcircumferencebase  Overheadfingertipreachsitting   Palmlength  Poplitealheight  \
# count            5769.000000                    5769.000000  5769.000000      5769.000000
# mean              414.554516                    1390.525048   114.106604       417.227076
# std                38.037263                      85.519035     7.105352        30.954287
# min               302.000000                    1111.000000    92.000000       305.000000
# 25%               383.000000                    1330.000000   109.000000       395.000000
# 50%               419.000000                    1395.000000   114.000000       418.000000
# 75%               443.000000                    1451.000000   119.000000       439.000000
# max               545.000000                    1651.000000   140.000000       525.000000
#
#        Radialestylionlength  Shouldercircumference  Shoulderelbowlength  Shoulderlength  \
# count           5769.000000            5769.000000          5769.000000     5769.000000
# mean             259.757670            1131.214422           354.805166      145.202288
# std               19.619717              92.350728            22.330743       12.394681
# min              169.000000             852.000000           271.000000      107.000000
# 25%              246.000000            1059.000000           339.000000      137.000000
# 50%              261.000000            1141.000000           356.000000      145.000000
# 75%              273.000000            1199.000000           370.000000      154.000000
# max              328.000000            1413.000000           423.000000      185.000000
#
#        Sittingheight  Sleevelengthspinewrist  Sleeveoutseam         Span      Stature  \
# count    5769.000000             5769.000000    5769.000000  5769.000000  5769.000000
# mean      898.592477              868.361068     578.013001  1766.951118  1716.938984
# std        45.257322               56.904175      37.905418   109.925336    89.256478
# min       750.000000              636.000000     410.000000  1323.000000  1442.000000
# 25%       867.000000              826.000000     551.000000  1690.000000  1655.000000
# 50%       900.000000              874.000000     580.000000  1774.000000  1722.000000
# 75%       931.000000              910.000000     605.000000  1844.000000  1781.000000
# max      1039.000000             1058.000000     709.000000  2121.000000  1993.000000
#
#        Suprasternaleheight  Tenthribheight  Thighcircumference  Thighclearance  Thumbtipreach  \
# count          5769.000000     5769.000000         5769.000000     5769.000000    5769.000000
# mean           1405.392442     1101.631479          623.583637      176.696481     791.044548
# std              78.008905       59.786688           57.529947       16.124405      53.486543
# min            1150.000000      874.000000          412.000000      121.000000     602.000000
# 25%            1350.000000     1059.000000          585.000000      166.000000     754.000000
# 50%            1409.000000     1102.000000          622.000000      176.000000     793.000000
# 75%            1461.000000     1143.000000          661.000000      187.000000     828.000000
# max            1650.000000     1305.000000          870.000000      259.000000     998.000000
#
#        Tibialheight  Tragiontopofhead  Trochanterionheight  Verticaltrunkcircumferenceusa  \
# count   5769.000000       5769.000000          5769.000000                    5769.000000
# mean     459.389149        129.580343           884.659386                    1632.470966
# std       29.274797          6.635641            53.766243                      98.204399
# min      347.000000        105.000000           660.000000                    1342.000000
# 25%      439.000000        125.000000           847.000000                    1561.000000
# 50%      459.000000        130.000000           883.000000                    1631.000000
# 75%      479.000000        134.000000           920.000000                    1697.000000
# max      584.000000        150.000000          1095.000000                    1991.000000
#
#        Waistbacklength  Waistbreadth  Waistcircumference   Waistdepth  Waistfrontlengthsitting  \
# count      5769.000000   5769.000000         5769.000000  5769.000000              5769.000000
# mean        460.990293    318.409950          916.817126   230.459178               377.352054
# std          36.706353     36.395675          114.386464    35.691681                31.714316
# min         345.000000    211.000000          611.000000   138.000000               289.000000
# 25%         435.000000    292.000000          831.000000   204.000000               355.000000
# 50%         463.000000    316.000000          910.000000   226.000000               376.000000
# 75%         486.000000    344.000000          995.000000   253.000000               398.000000
# max         598.000000    461.000000         1379.000000   406.000000               494.000000
#
#        Waistheightomphalion     Weightkg  Wristcircumference  Wristheight          Age  \
# count           5769.000000  5769.000000         5769.000000  5769.000000  5769.000000
# mean            1033.591090   800.981106          169.308372   831.334547    29.776391
# std               61.957938   155.990338           13.060900    47.321580     8.706610
# min              808.000000   358.000000          124.000000   688.000000    17.000000
# 25%              990.000000   686.000000          159.000000   798.000000    23.000000
# 50%             1035.000000   790.000000          171.000000   831.000000    28.000000
# 75%             1077.000000   900.000000          179.000000   864.000000    36.000000
# max             1245.000000  1442.000000          216.000000  1009.000000    58.000000
#
#        Gender_Male  Subjectsbirthlocation_Alaska  Subjectsbirthlocation_Antigua and Barbuda  \
# count  5769.000000                   5769.000000                                5769.000000
# mean      0.675854                      0.001213                                   0.000347
# std       0.468096                      0.034816                                   0.018618
# min       0.000000                      0.000000                                   0.000000
# 25%       0.000000                      0.000000                                   0.000000
# 50%       1.000000                      0.000000                                   0.000000
# 75%       1.000000                      0.000000                                   0.000000
# max       1.000000                      1.000000                                   1.000000
#
#        Subjectsbirthlocation_Argentina  Subjectsbirthlocation_Arizona  \
# count                      5769.000000                    5769.000000
# mean                          0.000173                       0.013001
# std                           0.013166                       0.113286
# min                           0.000000                       0.000000
# 25%                           0.000000                       0.000000
# 50%                           0.000000                       0.000000
# 75%                           0.000000                       0.000000
# max                           1.000000                       1.000000
#
#        Subjectsbirthlocation_Arkansas  Subjectsbirthlocation_Azerbaijan  \
# count                     5769.000000                       5769.000000
# mean                         0.009187                          0.000173
# std                          0.095416                          0.013166
# min                          0.000000                          0.000000
# 25%                          0.000000                          0.000000
# 50%                          0.000000                          0.000000
# 75%                          0.000000                          0.000000
# max                          1.000000                          1.000000
#
#        Subjectsbirthlocation_Bahamas  Subjectsbirthlocation_Barbados  \
# count                    5769.000000                     5769.000000
# mean                        0.000173                        0.000867
# std                         0.013166                        0.029430
# min                         0.000000                        0.000000
# 25%                         0.000000                        0.000000
# 50%                         0.000000                        0.000000
# 75%                         0.000000                        0.000000
# max                         1.000000                        1.000000
#
#        Subjectsbirthlocation_Belarus  Subjectsbirthlocation_Belgium  Subjectsbirthlocation_Belize  \
# count                    5769.000000                     5769.00000                   5769.000000
# mean                        0.000173                        0.00052                      0.000347
# std                         0.013166                        0.02280                      0.018618
# min                         0.000000                        0.00000                      0.000000
# 25%                         0.000000                        0.00000                      0.000000
# 50%                         0.000000                        0.00000                      0.000000
# 75%                         0.000000                        0.00000                      0.000000
# max                         1.000000                        1.00000                      1.000000
#
#        Subjectsbirthlocation_Bermuda  Subjectsbirthlocation_Bolivia  \
# count                    5769.000000                    5769.000000
# mean                        0.000173                       0.000347
# std                         0.013166                       0.018618
# min                         0.000000                       0.000000
# 25%                         0.000000                       0.000000
# 50%                         0.000000                       0.000000
# 75%                         0.000000                       0.000000
# max                         1.000000                       1.000000
#
#        Subjectsbirthlocation_Bosnia and Herzegovina  Subjectsbirthlocation_Brazil  \
# count                                   5769.000000                   5769.000000
# mean                                       0.000173                      0.000173
# std                                        0.013166                      0.013166
# min                                        0.000000                      0.000000
# 25%                                        0.000000                      0.000000
# 50%                                        0.000000                      0.000000
# 75%                                        0.000000                      0.000000
# max                                        1.000000                      1.000000
#
#        Subjectsbirthlocation_British Virgin Islands  Subjectsbirthlocation_Bulgaria  \
# count                                   5769.000000                     5769.000000
# mean                                       0.000173                        0.000173
# std                                        0.013166                        0.013166
# min                                        0.000000                        0.000000
# 25%                                        0.000000                        0.000000
# 50%                                        0.000000                        0.000000
# 75%                                        0.000000                        0.000000
# max                                        1.000000                        1.000000
#
#        Subjectsbirthlocation_California  Subjectsbirthlocation_Cameroon  \
# count                       5769.000000                     5769.000000
# mean                           0.072283                        0.000347
# std                            0.258978                        0.018618
# min                            0.000000                        0.000000
# 25%                            0.000000                        0.000000
# 50%                            0.000000                        0.000000
# 75%                            0.000000                        0.000000
# max                            1.000000                        1.000000
#
#        Subjectsbirthlocation_Canada  Subjectsbirthlocation_Cape Verde  \
# count                   5769.000000                       5769.000000
# mean                       0.001387                          0.000173
# std                        0.037216                          0.013166
# min                        0.000000                          0.000000
# 25%                        0.000000                          0.000000
# 50%                        0.000000                          0.000000
# 75%                        0.000000                          0.000000
# max                        1.000000                          1.000000
#
#        Subjectsbirthlocation_Chile  Subjectsbirthlocation_Colombia  \
# count                  5769.000000                     5769.000000
# mean                      0.000173                        0.002253
# std                       0.013166                        0.047421
# min                       0.000000                        0.000000
# 25%                       0.000000                        0.000000
# 50%                       0.000000                        0.000000
# 75%                       0.000000                        0.000000
# max                       1.000000                        1.000000
#
#        Subjectsbirthlocation_Colorado  Subjectsbirthlocation_Connecticut  \
# count                     5769.000000                        5769.000000
# mean                         0.013521                           0.006240
# std                          0.115499                           0.078755
# min                          0.000000                           0.000000
# 25%                          0.000000                           0.000000
# 50%                          0.000000                           0.000000
# 75%                          0.000000                           0.000000
# max                          1.000000                           1.000000
#
#        Subjectsbirthlocation_Costa Rica  Subjectsbirthlocation_Cuba  \
# count                       5769.000000                 5769.000000
# mean                           0.000347                    0.000693
# std                            0.018618                    0.026325
# min                            0.000000                    0.000000
# 25%                            0.000000                    0.000000
# 50%                            0.000000                    0.000000
# 75%                            0.000000                    0.000000
# max                            1.000000                    1.000000
#
#        Subjectsbirthlocation_Delaware  Subjectsbirthlocation_Denmark  \
# count                     5769.000000                    5769.000000
# mean                         0.002947                       0.000173
# std                          0.054209                       0.013166
# min                          0.000000                       0.000000
# 25%                          0.000000                       0.000000
# 50%                          0.000000                       0.000000
# 75%                          0.000000                       0.000000
# max                          1.000000                       1.000000
#
#        Subjectsbirthlocation_District of Columbia  Subjectsbirthlocation_Dominica  \
# count                                 5769.000000                     5769.000000
# mean                                     0.003293                        0.000173
# std                                      0.057299                        0.013166
# min                                      0.000000                        0.000000
# 25%                                      0.000000                        0.000000
# 50%                                      0.000000                        0.000000
# 75%                                      0.000000                        0.000000
# max                                      1.000000                        1.000000
#
#        Subjectsbirthlocation_Dominican Republic  Subjectsbirthlocation_Ecuador  \
# count                               5769.000000                    5769.000000
# mean                                   0.002947                       0.000867
# std                                    0.054209                       0.029430
# min                                    0.000000                       0.000000
# 25%                                    0.000000                       0.000000
# 50%                                    0.000000                       0.000000
# 75%                                    0.000000                       0.000000
# max                                    1.000000                       1.000000
#
#        Subjectsbirthlocation_Egypt  Subjectsbirthlocation_El Salvador  \
# count                  5769.000000                        5769.000000
# mean                      0.000173                           0.000867
# std                       0.013166                           0.029430
# min                       0.000000                           0.000000
# 25%                       0.000000                           0.000000
# 50%                       0.000000                           0.000000
# 75%                       0.000000                           0.000000
# max                       1.000000                           1.000000
#
#        Subjectsbirthlocation_Ethiopia  Subjectsbirthlocation_Florida  \
# count                     5769.000000                    5769.000000
# mean                         0.000173                       0.036401
# std                          0.013166                       0.187303
# min                          0.000000                       0.000000
# 25%                          0.000000                       0.000000
# 50%                          0.000000                       0.000000
# 75%                          0.000000                       0.000000
# max                          1.000000                       1.000000
#
#        Subjectsbirthlocation_France  Subjectsbirthlocation_French Guiana  \
# count                    5769.00000                          5769.000000
# mean                        0.00052                             0.000173
# std                         0.02280                             0.013166
# min                         0.00000                             0.000000
# 25%                         0.00000                             0.000000
# 50%                         0.00000                             0.000000
# 75%                         0.00000                             0.000000
# max                         1.00000                             1.000000
#
#        Subjectsbirthlocation_Georgia  Subjectsbirthlocation_Germany  Subjectsbirthlocation_Ghana  \
# count                    5769.000000                    5769.000000                  5769.000000
# mean                        0.029121                       0.015601                     0.000347
# std                         0.168161                       0.123935                     0.018618
# min                         0.000000                       0.000000                     0.000000
# 25%                         0.000000                       0.000000                     0.000000
# 50%                         0.000000                       0.000000                     0.000000
# 75%                         0.000000                       0.000000                     0.000000
# max                         1.000000                       1.000000                     1.000000
#
#        Subjectsbirthlocation_Grenada  Subjectsbirthlocation_Guadalupe  Subjectsbirthlocation_Guam  \
# count                    5769.000000                      5769.000000                  5769.00000
# mean                        0.000693                         0.000173                     0.00052
# std                         0.026325                         0.013166                     0.02280
# min                         0.000000                         0.000000                     0.00000
# 25%                         0.000000                         0.000000                     0.00000
# 50%                         0.000000                         0.000000                     0.00000
# 75%                         0.000000                         0.000000                     0.00000
# max                         1.000000                         1.000000                     1.00000
#
#        Subjectsbirthlocation_Guatemala  Subjectsbirthlocation_Guyana  Subjectsbirthlocation_Haiti  \
# count                      5769.000000                   5769.000000                  5769.000000
# mean                          0.000173                      0.001387                     0.002080
# std                           0.013166                      0.037216                     0.045564
# min                           0.000000                      0.000000                     0.000000
# 25%                           0.000000                      0.000000                     0.000000
# 50%                           0.000000                      0.000000                     0.000000
# 75%                           0.000000                      0.000000                     0.000000
# max                           1.000000                      1.000000                     1.000000
#
#        Subjectsbirthlocation_Hawaii  Subjectsbirthlocation_Honduras  \
# count                   5769.000000                     5769.000000
# mean                       0.003120                        0.000693
# std                        0.055776                        0.026325
# min                        0.000000                        0.000000
# 25%                        0.000000                        0.000000
# 50%                        0.000000                        0.000000
# 75%                        0.000000                        0.000000
# max                        1.000000                        1.000000
#
#        Subjectsbirthlocation_Iceland  Subjectsbirthlocation_Idaho  Subjectsbirthlocation_Illinois  \
# count                    5769.000000                  5769.000000                     5769.000000
# mean                        0.000173                     0.003467                        0.036401
# std                         0.013166                     0.058783                        0.187303
# min                         0.000000                     0.000000                        0.000000
# 25%                         0.000000                     0.000000                        0.000000
# 50%                         0.000000                     0.000000                        0.000000
# 75%                         0.000000                     0.000000                        0.000000
# max                         1.000000                     1.000000                        1.000000
#
#        Subjectsbirthlocation_India  Subjectsbirthlocation_Indiana  Subjectsbirthlocation_Iowa  \
# count                  5769.000000                    5769.000000                 5769.000000
# mean                      0.000173                       0.045762                    0.009534
# std                       0.013166                       0.208986                    0.097183
# min                       0.000000                       0.000000                    0.000000
# 25%                       0.000000                       0.000000                    0.000000
# 50%                       0.000000                       0.000000                    0.000000
# 75%                       0.000000                       0.000000                    0.000000
# max                       1.000000                       1.000000                    1.000000
#
#        Subjectsbirthlocation_Iran  Subjectsbirthlocation_Iraq  Subjectsbirthlocation_Israel  \
# count                 5769.000000                 5769.000000                    5769.00000
# mean                     0.000173                    0.000347                       0.00052
# std                      0.013166                    0.018618                       0.02280
# min                      0.000000                    0.000000                       0.00000
# 25%                      0.000000                    0.000000                       0.00000
# 50%                      0.000000                    0.000000                       0.00000
# 75%                      0.000000                    0.000000                       0.00000
# max                      1.000000                    1.000000                       1.00000
#
#        Subjectsbirthlocation_Italy  Subjectsbirthlocation_Ivory Coast  \
# count                  5769.000000                        5769.000000
# mean                      0.000347                           0.000173
# std                       0.018618                           0.013166
# min                       0.000000                           0.000000
# 25%                       0.000000                           0.000000
# 50%                       0.000000                           0.000000
# 75%                       0.000000                           0.000000
# max                       1.000000                           1.000000
#
#        Subjectsbirthlocation_Jamaica  Subjectsbirthlocation_Japan  Subjectsbirthlocation_Kansas  \
# count                    5769.000000                  5769.000000                   5769.000000
# mean                        0.006067                     0.001213                      0.010747
# std                         0.077660                     0.034816                      0.103119
# min                         0.000000                     0.000000                      0.000000
# 25%                         0.000000                     0.000000                      0.000000
# 50%                         0.000000                     0.000000                      0.000000
# 75%                         0.000000                     0.000000                      0.000000
# max                         1.000000                     1.000000                      1.000000
#
#        Subjectsbirthlocation_Kentucky  Subjectsbirthlocation_Kenya  Subjectsbirthlocation_Lebanon  \
# count                     5769.000000                   5769.00000                    5769.000000
# mean                         0.011614                      0.00052                       0.000347
# std                          0.107149                      0.02280                       0.018618
# min                          0.000000                      0.00000                       0.000000
# 25%                          0.000000                      0.00000                       0.000000
# 50%                          0.000000                      0.00000                       0.000000
# 75%                          0.000000                      0.00000                       0.000000
# max                          1.000000                      1.00000                       1.000000
#
#        Subjectsbirthlocation_Liberia  Subjectsbirthlocation_Louisiana  \
# count                    5769.000000                      5769.000000
# mean                        0.001040                         0.023574
# std                         0.032236                         0.151732
# min                         0.000000                         0.000000
# 25%                         0.000000                         0.000000
# 50%                         0.000000                         0.000000
# 75%                         0.000000                         0.000000
# max                         1.000000                         1.000000
#
#        Subjectsbirthlocation_Maine  Subjectsbirthlocation_Maryland  \
# count                  5769.000000                     5769.000000
# mean                      0.003120                        0.013521
# std                       0.055776                        0.115499
# min                       0.000000                        0.000000
# 25%                       0.000000                        0.000000
# 50%                       0.000000                        0.000000
# 75%                       0.000000                        0.000000
# max                       1.000000                        1.000000
#
#        Subjectsbirthlocation_Massachusetts  Subjectsbirthlocation_Mexico  \
# count                          5769.000000                    5769.00000
# mean                              0.018894                       0.00676
# std                               0.136163                       0.08195
# min                               0.000000                       0.00000
# 25%                               0.000000                       0.00000
# 50%                               0.000000                       0.00000
# 75%                               0.000000                       0.00000
# max                               1.000000                       1.00000
#
#        Subjectsbirthlocation_Michigan  Subjectsbirthlocation_Minnesota  \
# count                     5769.000000                      5769.000000
# mean                         0.033628                         0.033628
# std                          0.180285                         0.180285
# min                          0.000000                         0.000000
# 25%                          0.000000                         0.000000
# 50%                          0.000000                         0.000000
# 75%                          0.000000                         0.000000
# max                          1.000000                         1.000000
#
#        Subjectsbirthlocation_Mississippi  Subjectsbirthlocation_Missouri  \
# count                        5769.000000                     5769.000000
# mean                            0.033455                        0.014387
# std                             0.179836                        0.119091
# min                             0.000000                        0.000000
# 25%                             0.000000                        0.000000
# 50%                             0.000000                        0.000000
# 75%                             0.000000                        0.000000
# max                             1.000000                        1.000000
#
#        Subjectsbirthlocation_Montana  Subjectsbirthlocation_Morocco  \
# count                    5769.000000                     5769.00000
# mean                        0.002080                        0.00052
# std                         0.045564                        0.02280
# min                         0.000000                        0.00000
# 25%                         0.000000                        0.00000
# 50%                         0.000000                        0.00000
# 75%                         0.000000                        0.00000
# max                         1.000000                        1.00000
#
#        Subjectsbirthlocation_Nebraska  Subjectsbirthlocation_Netherlands  \
# count                     5769.000000                        5769.000000
# mean                         0.005200                           0.000347
# std                          0.071931                           0.018618
# min                          0.000000                           0.000000
# 25%                          0.000000                           0.000000
# 50%                          0.000000                           0.000000
# 75%                          0.000000                           0.000000
# max                          1.000000                           1.000000
#
#        Subjectsbirthlocation_Nevada  Subjectsbirthlocation_New Hampshire  \
# count                   5769.000000                          5769.000000
# mean                       0.003640                             0.002427
# std                        0.060229                             0.049207
# min                        0.000000                             0.000000
# 25%                        0.000000                             0.000000
# 50%                        0.000000                             0.000000
# 75%                        0.000000                             0.000000
# max                        1.000000                             1.000000
#
#        Subjectsbirthlocation_New Jersey  Subjectsbirthlocation_New Mexico  \
# count                       5769.000000                       5769.000000
# mean                           0.015254                          0.002773
# std                            0.122572                          0.052595
# min                            0.000000                          0.000000
# 25%                            0.000000                          0.000000
# 50%                            0.000000                          0.000000
# 75%                            0.000000                          0.000000
# max                            1.000000                          1.000000
#
#        Subjectsbirthlocation_New York  Subjectsbirthlocation_New Zealand  \
# count                     5769.000000                        5769.000000
# mean                         0.071243                           0.000173
# std                          0.257252                           0.013166
# min                          0.000000                           0.000000
# 25%                          0.000000                           0.000000
# 50%                          0.000000                           0.000000
# 75%                          0.000000                           0.000000
# max                          1.000000                           1.000000
#
#        Subjectsbirthlocation_Nicaragua  Subjectsbirthlocation_Nigeria  \
# count                      5769.000000                    5769.000000
# mean                          0.000693                       0.000693
# std                           0.026325                       0.026325
# min                           0.000000                       0.000000
# 25%                           0.000000                       0.000000
# 50%                           0.000000                       0.000000
# 75%                           0.000000                       0.000000
# max                           1.000000                       1.000000
#
#        Subjectsbirthlocation_North Carolina  Subjectsbirthlocation_North Dakota  \
# count                           5769.000000                         5769.000000
# mean                               0.025134                            0.003120
# std                                0.156547                            0.055776
# min                                0.000000                            0.000000
# 25%                                0.000000                            0.000000
# 50%                                0.000000                            0.000000
# 75%                                0.000000                            0.000000
# max                                1.000000                            1.000000
#
#        Subjectsbirthlocation_Ohio  Subjectsbirthlocation_Oklahoma  Subjectsbirthlocation_Oregon  \
# count                 5769.000000                     5769.000000                   5769.000000
# mean                     0.024094                        0.035535                      0.006934
# std                      0.153355                        0.185143                      0.082986
# min                      0.000000                        0.000000                      0.000000
# 25%                      0.000000                        0.000000                      0.000000
# 50%                      0.000000                        0.000000                      0.000000
# 75%                      0.000000                        0.000000                      0.000000
# max                      1.000000                        1.000000                      1.000000
#
#        Subjectsbirthlocation_Panama  Subjectsbirthlocation_Paraguay  \
# count                   5769.000000                     5769.000000
# mean                       0.001733                        0.000173
# std                        0.041602                        0.013166
# min                        0.000000                        0.000000
# 25%                        0.000000                        0.000000
# 50%                        0.000000                        0.000000
# 75%                        0.000000                        0.000000
# max                        1.000000                        1.000000
#
#        Subjectsbirthlocation_Pennsylvania  Subjectsbirthlocation_Peru  \
# count                         5769.000000                 5769.000000
# mean                             0.022534                    0.001387
# std                              0.148426                    0.037216
# min                              0.000000                    0.000000
# 25%                              0.000000                    0.000000
# 50%                              0.000000                    0.000000
# 75%                              0.000000                    0.000000
# max                              1.000000                    1.000000
#
#        Subjectsbirthlocation_Philippines  Subjectsbirthlocation_Poland  \
# count                        5769.000000                   5769.000000
# mean                            0.000867                      0.000867
# std                             0.029430                      0.029430
# min                             0.000000                      0.000000
# 25%                             0.000000                      0.000000
# 50%                             0.000000                      0.000000
# 75%                             0.000000                      0.000000
# max                             1.000000                      1.000000
#
#        Subjectsbirthlocation_Portugal  Subjectsbirthlocation_Puerto Rico  \
# count                     5769.000000                        5769.000000
# mean                         0.000693                           0.015254
# std                          0.026325                           0.122572
# min                          0.000000                           0.000000
# 25%                          0.000000                           0.000000
# 50%                          0.000000                           0.000000
# 75%                          0.000000                           0.000000
# max                          1.000000                           1.000000
#
#        Subjectsbirthlocation_Rhode Island  Subjectsbirthlocation_Romania  \
# count                         5769.000000                     5769.00000
# mean                             0.003120                        0.00052
# std                              0.055776                        0.02280
# min                              0.000000                        0.00000
# 25%                              0.000000                        0.00000
# 50%                              0.000000                        0.00000
# 75%                              0.000000                        0.00000
# max                              1.000000                        1.00000
#
#        Subjectsbirthlocation_Russia  Subjectsbirthlocation_Saint Lucia  \
# count                   5769.000000                        5769.000000
# mean                       0.001387                           0.000173
# std                        0.037216                           0.013166
# min                        0.000000                           0.000000
# 25%                        0.000000                           0.000000
# 50%                        0.000000                           0.000000
# 75%                        0.000000                           0.000000
# max                        1.000000                           1.000000
#
#        Subjectsbirthlocation_Senegal  Subjectsbirthlocation_Serbia  \
# count                    5769.000000                   5769.000000
# mean                        0.000173                      0.000173
# std                         0.013166                      0.013166
# min                         0.000000                      0.000000
# 25%                         0.000000                      0.000000
# 50%                         0.000000                      0.000000
# 75%                         0.000000                      0.000000
# max                         1.000000                      1.000000
#
#        Subjectsbirthlocation_Sierra Leone  Subjectsbirthlocation_South Africa  \
# count                         5769.000000                         5769.000000
# mean                             0.000347                            0.000693
# std                              0.018618                            0.026325
# min                              0.000000                            0.000000
# 25%                              0.000000                            0.000000
# 50%                              0.000000                            0.000000
# 75%                              0.000000                            0.000000
# max                              1.000000                            1.000000
#
#        Subjectsbirthlocation_South America  Subjectsbirthlocation_South Carolina  \
# count                          5769.000000                           5769.000000
# mean                              0.000173                              0.027908
# std                               0.013166                              0.164723
# min                               0.000000                              0.000000
# 25%                               0.000000                              0.000000
# 50%                               0.000000                              0.000000
# 75%                               0.000000                              0.000000
# max                               1.000000                              1.000000
#
#        Subjectsbirthlocation_South Dakota  Subjectsbirthlocation_South Korea  \
# count                         5769.000000                        5769.000000
# mean                             0.009187                           0.000173
# std                              0.095416                           0.013166
# min                              0.000000                           0.000000
# 25%                              0.000000                           0.000000
# 50%                              0.000000                           0.000000
# 75%                              0.000000                           0.000000
# max                              1.000000                           1.000000
#
#        Subjectsbirthlocation_Sri Lanka  Subjectsbirthlocation_Sudan  Subjectsbirthlocation_Syria  \
# count                      5769.000000                  5769.000000                  5769.000000
# mean                          0.000173                     0.000347                     0.000173
# std                           0.013166                     0.018618                     0.013166
# min                           0.000000                     0.000000                     0.000000
# 25%                           0.000000                     0.000000                     0.000000
# 50%                           0.000000                     0.000000                     0.000000
# 75%                           0.000000                     0.000000                     0.000000
# max                           1.000000                     1.000000                     1.000000
#
#        Subjectsbirthlocation_Tennessee  Subjectsbirthlocation_Texas  Subjectsbirthlocation_Togo  \
# count                      5769.000000                  5769.000000                 5769.000000
# mean                          0.012827                     0.066909                    0.000173
# std                           0.112538                     0.249887                    0.013166
# min                           0.000000                     0.000000                    0.000000
# 25%                           0.000000                     0.000000                    0.000000
# 50%                           0.000000                     0.000000                    0.000000
# 75%                           0.000000                     0.000000                    0.000000
# max                           1.000000                     1.000000                    1.000000
#
#        Subjectsbirthlocation_Trinidad and Tobago  Subjectsbirthlocation_Turkey  \
# count                                5769.000000                   5769.000000
# mean                                    0.001213                      0.000347
# std                                     0.034816                      0.018618
# min                                     0.000000                      0.000000
# 25%                                     0.000000                      0.000000
# 50%                                     0.000000                      0.000000
# 75%                                     0.000000                      0.000000
# max                                     1.000000                      1.000000
#
#        Subjectsbirthlocation_US Virgin Islands  Subjectsbirthlocation_Ukraine  \
# count                              5769.000000                    5769.000000
# mean                                  0.001213                       0.001213
# std                                   0.034816                       0.034816
# min                                   0.000000                       0.000000
# 25%                                   0.000000                       0.000000
# 50%                                   0.000000                       0.000000
# 75%                                   0.000000                       0.000000
# max                                   1.000000                       1.000000
#
#        Subjectsbirthlocation_United Kingdom  Subjectsbirthlocation_United States  \
# count                           5769.000000                          5769.000000
# mean                               0.001907                             0.000347
# std                                0.043628                             0.018618
# min                                0.000000                             0.000000
# 25%                                0.000000                             0.000000
# 50%                                0.000000                             0.000000
# 75%                                0.000000                             0.000000
# max                                1.000000                             1.000000
#
#        Subjectsbirthlocation_Utah  Subjectsbirthlocation_Venezuela  Subjectsbirthlocation_Vermont  \
# count                 5769.000000                      5769.000000                    5769.000000
# mean                     0.004680                         0.000173                       0.002253
# std                      0.068258                         0.013166                       0.047421
# min                      0.000000                         0.000000                       0.000000
# 25%                      0.000000                         0.000000                       0.000000
# 50%                      0.000000                         0.000000                       0.000000
# 75%                      0.000000                         0.000000                       0.000000
# max                      1.000000                         1.000000                       1.000000
#
#        Subjectsbirthlocation_Virginia  Subjectsbirthlocation_Washington  \
# count                     5769.000000                       5769.000000
# mean                         0.019587                          0.010574
# std                          0.138590                          0.102293
# min                          0.000000                          0.000000
# 25%                          0.000000                          0.000000
# 50%                          0.000000                          0.000000
# 75%                          0.000000                          0.000000
# max                          1.000000                          1.000000
#
#        Subjectsbirthlocation_West Virginia  Subjectsbirthlocation_Wisconsin  \
# count                          5769.000000                      5769.000000
# mean                              0.004507                         0.017161
# std                               0.066987                         0.129881
# min                               0.000000                         0.000000
# 25%                               0.000000                         0.000000
# 50%                               0.000000                         0.000000
# 75%                               0.000000                         0.000000
# max                               1.000000                         1.000000
#
#        Subjectsbirthlocation_Wyoming  Subjectsbirthlocation_Zambia  Writingpreference_Left hand  \
# count                    5769.000000                   5769.000000                  5769.000000
# mean                        0.001213                      0.000173                     0.107818
# std                         0.034816                      0.013166                     0.310177
# min                         0.000000                      0.000000                     0.000000
# 25%                         0.000000                      0.000000                     0.000000
# 50%                         0.000000                      0.000000                     0.000000
# 75%                         0.000000                      0.000000                     0.000000
# max                         1.000000                      1.000000                     1.000000
#
#        Writingpreference_Right hand
# count                   5769.000000
# mean                       0.881955
# std                        0.322689
# min                        0.000000
# 25%                        1.000000
# 50%                        1.000000
# 75%                        1.000000
# max                        1.000000

# %%
mean_human = X.describe().loc['mean']
mean_human
# Out:
# Abdominalextensiondepthsitting                   247.254290
# Acromialheight                                  1408.630265
# Acromionradialelength                            328.071590
# Anklecircumference                               225.201768
# Axillaheight                                    1301.902583
# Balloffootcircumference                          244.408043
# Balloffootlength                                 195.118911
# Biacromialbreadth                                399.706015
# Bicepscircumferenceflexed                        341.663027
# Bicristalbreadth                                 274.903449
# Bideltoidbreadth                                 491.454845
# Bimalleolarbreadth                                72.335413
# Bitragionchinarc                                 324.962212
# Bitragionsubmandibulararc                        306.677760
# Bizygomaticbreadth                               139.529381
# Buttockcircumference                            1022.059456
# Buttockdepth                                     242.234356
# Buttockheight                                    872.112845
# Buttockkneelength                                610.449991
# Buttockpopliteallength                           498.331773
# Calfcircumference                                386.316519
# Cervicaleheight                                 1479.952158
# Chestbreadth                                     283.232623
# Chestcircumference                              1024.206622
# Chestdepth                                       252.322586
# Chestheight                                     1254.290172
# Crotchheight                                     827.105738
# Crotchlengthomphalion                            622.693708
# Crotchlengthposterioromphalion                   351.880222
# Earbreadth                                        35.175420
# Earlength                                         62.606171
# Earprotrusion                                     22.227249
# Elbowrestheight                                  240.553302
# Eyeheightsitting                                 786.399203
# Footbreadthhorizontal                             98.915063
# Footlength                                       263.512394
# Forearmcenterofgriplength                        339.458832
# Forearmcircumferenceflexed                       295.661640
# Forearmforearmbreadth                            553.098284
# Forearmhandlength                                467.898769
# Functionalleglength                             1104.347201
# Handbreadth                                       85.098111
# Handcircumference                                204.215635
# Handlength                                       189.574796
# Headbreadth                                      152.043682
# Headcircumference                                570.424337
# Headlength                                       196.640839
# Heelanklecircumference                           333.274918
# Heelbreadth                                       70.834113
# Hipbreadth                                       348.930837
# Hipbreadthsitting                                386.417923
# Iliocristaleheight                              1042.152366
# Interpupillarybreadth                            632.534928
# Interscyei                                       412.773964
# Interscyeii                                      433.017334
# Kneeheightmidpatella                             476.665280
# Kneeheightsitting                                541.376668
# Lateralfemoralepicondyleheight                   484.316693
# Lateralmalleolusheight                            69.761830
# Lowerthighcircumference                          406.943144
# Mentonsellionlength                              119.601664
# Neckcircumference                                376.127578
# Neckcircumferencebase                            414.554516
# Overheadfingertipreachsitting                   1390.525048
# Palmlength                                       114.106604
# Poplitealheight                                  417.227076
# Radialestylionlength                             259.757670
# Shouldercircumference                           1131.214422
# Shoulderelbowlength                              354.805166
# Shoulderlength                                   145.202288
# Sittingheight                                    898.592477
# Sleevelengthspinewrist                           868.361068
# Sleeveoutseam                                    578.013001
# Span                                            1766.951118
# Stature                                         1716.938984
# Suprasternaleheight                             1405.392442
# Tenthribheight                                  1101.631479
# Thighcircumference                               623.583637
# Thighclearance                                   176.696481
# Thumbtipreach                                    791.044548
# Tibialheight                                     459.389149
# Tragiontopofhead                                 129.580343
# Trochanterionheight                              884.659386
# Verticaltrunkcircumferenceusa                   1632.470966
# Waistbacklength                                  460.990293
# Waistbreadth                                     318.409950
# Waistcircumference                               916.817126
# Waistdepth                                       230.459178
# Waistfrontlengthsitting                          377.352054
# Waistheightomphalion                            1033.591090
# Weightkg                                         800.981106
# Wristcircumference                               169.308372
# Wristheight                                      831.334547
# Age                                               29.776391
# Gender_Male                                        0.675854
# Subjectsbirthlocation_Alaska                       0.001213
# Subjectsbirthlocation_Antigua and Barbuda          0.000347
# Subjectsbirthlocation_Argentina                    0.000173
# Subjectsbirthlocation_Arizona                      0.013001
# Subjectsbirthlocation_Arkansas                     0.009187
# Subjectsbirthlocation_Azerbaijan                   0.000173
# Subjectsbirthlocation_Bahamas                      0.000173
# Subjectsbirthlocation_Barbados                     0.000867
# Subjectsbirthlocation_Belarus                      0.000173
# Subjectsbirthlocation_Belgium                      0.000520
# Subjectsbirthlocation_Belize                       0.000347
# Subjectsbirthlocation_Bermuda                      0.000173
# Subjectsbirthlocation_Bolivia                      0.000347
# Subjectsbirthlocation_Bosnia and Herzegovina       0.000173
# Subjectsbirthlocation_Brazil                       0.000173
# Subjectsbirthlocation_British Virgin Islands       0.000173
# Subjectsbirthlocation_Bulgaria                     0.000173
# Subjectsbirthlocation_California                   0.072283
# Subjectsbirthlocation_Cameroon                     0.000347
# Subjectsbirthlocation_Canada                       0.001387
# Subjectsbirthlocation_Cape Verde                   0.000173
# Subjectsbirthlocation_Chile                        0.000173
# Subjectsbirthlocation_Colombia                     0.002253
# Subjectsbirthlocation_Colorado                     0.013521
# Subjectsbirthlocation_Connecticut                  0.006240
# Subjectsbirthlocation_Costa Rica                   0.000347
# Subjectsbirthlocation_Cuba                         0.000693
# Subjectsbirthlocation_Delaware                     0.002947
# Subjectsbirthlocation_Denmark                      0.000173
# Subjectsbirthlocation_District of Columbia         0.003293
# Subjectsbirthlocation_Dominica                     0.000173
# Subjectsbirthlocation_Dominican Republic           0.002947
# Subjectsbirthlocation_Ecuador                      0.000867
# Subjectsbirthlocation_Egypt                        0.000173
# Subjectsbirthlocation_El Salvador                  0.000867
# Subjectsbirthlocation_Ethiopia                     0.000173
# Subjectsbirthlocation_Florida                      0.036401
# Subjectsbirthlocation_France                       0.000520
# Subjectsbirthlocation_French Guiana                0.000173
# Subjectsbirthlocation_Georgia                      0.029121
# Subjectsbirthlocation_Germany                      0.015601
# Subjectsbirthlocation_Ghana                        0.000347
# Subjectsbirthlocation_Grenada                      0.000693
# Subjectsbirthlocation_Guadalupe                    0.000173
# Subjectsbirthlocation_Guam                         0.000520
# Subjectsbirthlocation_Guatemala                    0.000173
# Subjectsbirthlocation_Guyana                       0.001387
# Subjectsbirthlocation_Haiti                        0.002080
# Subjectsbirthlocation_Hawaii                       0.003120
# Subjectsbirthlocation_Honduras                     0.000693
# Subjectsbirthlocation_Iceland                      0.000173
# Subjectsbirthlocation_Idaho                        0.003467
# Subjectsbirthlocation_Illinois                     0.036401
# Subjectsbirthlocation_India                        0.000173
# Subjectsbirthlocation_Indiana                      0.045762
# Subjectsbirthlocation_Iowa                         0.009534
# Subjectsbirthlocation_Iran                         0.000173
# Subjectsbirthlocation_Iraq                         0.000347
# Subjectsbirthlocation_Israel                       0.000520
# Subjectsbirthlocation_Italy                        0.000347
# Subjectsbirthlocation_Ivory Coast                  0.000173
# Subjectsbirthlocation_Jamaica                      0.006067
# Subjectsbirthlocation_Japan                        0.001213
# Subjectsbirthlocation_Kansas                       0.010747
# Subjectsbirthlocation_Kentucky                     0.011614
# Subjectsbirthlocation_Kenya                        0.000520
# Subjectsbirthlocation_Lebanon                      0.000347
# Subjectsbirthlocation_Liberia                      0.001040
# Subjectsbirthlocation_Louisiana                    0.023574
# Subjectsbirthlocation_Maine                        0.003120
# Subjectsbirthlocation_Maryland                     0.013521
# Subjectsbirthlocation_Massachusetts                0.018894
# Subjectsbirthlocation_Mexico                       0.006760
# Subjectsbirthlocation_Michigan                     0.033628
# Subjectsbirthlocation_Minnesota                    0.033628
# Subjectsbirthlocation_Mississippi                  0.033455
# Subjectsbirthlocation_Missouri                     0.014387
# Subjectsbirthlocation_Montana                      0.002080
# Subjectsbirthlocation_Morocco                      0.000520
# Subjectsbirthlocation_Nebraska                     0.005200
# Subjectsbirthlocation_Netherlands                  0.000347
# Subjectsbirthlocation_Nevada                       0.003640
# Subjectsbirthlocation_New Hampshire                0.002427
# Subjectsbirthlocation_New Jersey                   0.015254
# Subjectsbirthlocation_New Mexico                   0.002773
# Subjectsbirthlocation_New York                     0.071243
# Subjectsbirthlocation_New Zealand                  0.000173
# Subjectsbirthlocation_Nicaragua                    0.000693
# Subjectsbirthlocation_Nigeria                      0.000693
# Subjectsbirthlocation_North Carolina               0.025134
# Subjectsbirthlocation_North Dakota                 0.003120
# Subjectsbirthlocation_Ohio                         0.024094
# Subjectsbirthlocation_Oklahoma                     0.035535
# Subjectsbirthlocation_Oregon                       0.006934
# Subjectsbirthlocation_Panama                       0.001733
# Subjectsbirthlocation_Paraguay                     0.000173
# Subjectsbirthlocation_Pennsylvania                 0.022534
# Subjectsbirthlocation_Peru                         0.001387
# Subjectsbirthlocation_Philippines                  0.000867
# Subjectsbirthlocation_Poland                       0.000867
# Subjectsbirthlocation_Portugal                     0.000693
# Subjectsbirthlocation_Puerto Rico                  0.015254
# Subjectsbirthlocation_Rhode Island                 0.003120
# Subjectsbirthlocation_Romania                      0.000520
# Subjectsbirthlocation_Russia                       0.001387
# Subjectsbirthlocation_Saint Lucia                  0.000173
# Subjectsbirthlocation_Senegal                      0.000173
# Subjectsbirthlocation_Serbia                       0.000173
# Subjectsbirthlocation_Sierra Leone                 0.000347
# Subjectsbirthlocation_South Africa                 0.000693
# Subjectsbirthlocation_South America                0.000173
# Subjectsbirthlocation_South Carolina               0.027908
# Subjectsbirthlocation_South Dakota                 0.009187
# Subjectsbirthlocation_South Korea                  0.000173
# Subjectsbirthlocation_Sri Lanka                    0.000173
# Subjectsbirthlocation_Sudan                        0.000347
# Subjectsbirthlocation_Syria                        0.000173
# Subjectsbirthlocation_Tennessee                    0.012827
# Subjectsbirthlocation_Texas                        0.066909
# Subjectsbirthlocation_Togo                         0.000173
# Subjectsbirthlocation_Trinidad and Tobago          0.001213
# Subjectsbirthlocation_Turkey                       0.000347
# Subjectsbirthlocation_US Virgin Islands            0.001213
# Subjectsbirthlocation_Ukraine                      0.001213
# Subjectsbirthlocation_United Kingdom               0.001907
# Subjectsbirthlocation_United States                0.000347
# Subjectsbirthlocation_Utah                         0.004680
# Subjectsbirthlocation_Venezuela                    0.000173
# Subjectsbirthlocation_Vermont                      0.002253
# Subjectsbirthlocation_Virginia                     0.019587
# Subjectsbirthlocation_Washington                   0.010574
# Subjectsbirthlocation_West Virginia                0.004507
# Subjectsbirthlocation_Wisconsin                    0.017161
# Subjectsbirthlocation_Wyoming                      0.001213
# Subjectsbirthlocation_Zambia                       0.000173
# Writingpreference_Left hand                        0.107818
# Writingpreference_Right hand                       0.881955
# Name: mean, dtype: float64

# %%
final_model = pickle.load(open('final_model_soldiers', 'rb'))

# %%
final_model.predict([mean_human])
# Out:
# array(['White'], dtype=object)

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
