# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# <h1 style="text-align: center;">Deep Learning<br><br>Assignment-1 (ANN)<br><br>Churn Prediction for Bank Customer<br><h1>

# %% [markdown]
# ## Dataset Info

# %% [markdown]
# We have a dataset in which there are details of a bank's customers and the target variable is a binary variable reflecting the fact whether the customer left the bank (closed his account) or he continues to be a customer.

# %% [markdown]
# ## Improt Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
# %matplotlib notebook

import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

plt.rcParams["figure.figsize"] = (10,6)

sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %% [markdown]
# ## Indest Data

# %%
df = pd.read_csv("Churn_Modelling.csv", index_col='RowNumber')

# %% [markdown]
# ## Exploratory Data Analysis and Visualization

# %% [markdown]
# 1. Implement basic steps to see how is your data looks like
# 2. Check for missing values
# 3. Drop the features that not suitable for modelling
# 4. Implement basic visualization steps such as histogram, countplot, heatmap
# 5. Convert categorical variables to dummy variables

# %%
df.head()
# Out:
#            CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602  Hargrave          619    France  Female   42       2
# 2            15647311      Hill          608     Spain  Female   41       1
# 3            15619304      Onio          502    France  Female   42       8
# 4            15701354      Boni          699    France  Female   39       1
# 5            15737888  Mitchell          850     Spain  Female   43       2
#
#              Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# RowNumber
# 1              0.000              1          1               1
# 2          83807.860              1          0               1
# 3         159660.800              3          1               0
# 4              0.000              2          0               0
# 5         125510.820              1          1               1
#
#            EstimatedSalary  Exited
# RowNumber
# 1               101348.880       1
# 2               112542.580       0
# 3               113931.570       1
# 4                93826.630       0
# 5                79084.100       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 1 to 10000
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       10000 non-null  int64
#  1   Surname          10000 non-null  object
#  2   CreditScore      10000 non-null  int64
#  3   Geography        10000 non-null  object
#  4   Gender           10000 non-null  object
#  5   Age              10000 non-null  int64
#  6   Tenure           10000 non-null  int64
#  7   Balance          10000 non-null  float64
#  8   NumOfProducts    10000 non-null  int64
#  9   HasCrCard        10000 non-null  int64
#  10  IsActiveMember   10000 non-null  int64
#  11  EstimatedSalary  10000 non-null  float64
#  12  Exited           10000 non-null  int64
# dtypes: float64(2), int64(8), object(3)
# memory usage: 1.1+ MB

# %%
df.shape, df.size
# Out:
# ((10000, 13), 130000)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe().T
# Out:
#                     count         mean       std          min          25%  \
# CustomerId      10000.000 15690940.569 71936.186 15565701.000 15628528.250
# CreditScore     10000.000      650.529    96.653      350.000      584.000
# Age             10000.000       38.922    10.488       18.000       32.000
# Tenure          10000.000        5.013     2.892        0.000        3.000
# Balance         10000.000    76485.889 62397.405        0.000        0.000
# NumOfProducts   10000.000        1.530     0.582        1.000        1.000
# HasCrCard       10000.000        0.706     0.456        0.000        0.000
# IsActiveMember  10000.000        0.515     0.500        0.000        0.000
# EstimatedSalary 10000.000   100090.240 57510.493       11.580    51002.110
# Exited          10000.000        0.204     0.403        0.000        0.000
#
#                          50%          75%          max
# CustomerId      15690738.000 15753233.750 15815690.000
# CreditScore          652.000      718.000      850.000
# Age                   37.000       44.000       92.000
# Tenure                 5.000        7.000       10.000
# Balance            97198.540   127644.240   250898.090
# NumOfProducts          1.000        2.000        4.000
# HasCrCard              1.000        1.000        1.000
# IsActiveMember         1.000        1.000        1.000
# EstimatedSalary   100193.915   149388.247   199992.480
# Exited                 0.000        0.000        1.000

# %%
# I will drop some columns that won't be useful

del df['CustomerId'], df['Surname']

# %% [markdown]
# ***object type columns***

# %%
index = 0
plt.figure(figsize=(15,6))
for col in df.select_dtypes('O').columns:    
    index += 1
    plt.subplot(1,2,index)
    a = sns.countplot(data=df, x=col)
    a.bar_label(a.containers[0], fontsize=13, padding=5)
    plt.title(f'Distribution of {col}', fontsize=15, pad=10)
    plt.ylim(0, 6000)
plt.tight_layout()

# %% [markdown]
# ***numeric columns-1***

# %%
columns = ['Tenure', 'NumOfProducts', 'HasCrCard', 'IsActiveMember']
index = 0
plt.figure(figsize=(20,12))
for col in columns:    
    index += 1
    plt.subplot(2,2,index)
    a = sns.countplot(data=df, x=col)
    a.bar_label(a.containers[0], fontsize=13)
plt.tight_layout()

# %% [markdown]
# ***numeric columns-2***

# %%
columns = ['CreditScore', 'Age', 'Balance', 'EstimatedSalary']
index = 0
plt.figure(figsize=(20,10))
for col in columns:    
    index += 1
    plt.subplot(2,2,index)
    sns.histplot(data=df, x=col, bins=50, kde=True)

# %%
columns = ['CreditScore', 'Age', 'Balance', 'EstimatedSalary']
index = 0
plt.figure(figsize=(20,10))
for col in columns:    
    index += 1
    plt.subplot(2,2,index)
    sns.boxplot(data=df, x=col)

# %%
df.CreditScore.value_counts()
# Out:
# 850    233
# 678     63
# 655     54
# 705     53
# 667     53
#       ...
# 404      1
# 351      1
# 365      1
# 417      1
# 419      1
# Name: CreditScore, Length: 460, dtype: int64

# %%
df.Age.value_counts()
# Out:
# 37    478
# 38    477
# 35    474
# 36    456
# 34    447
#      ...
# 92      2
# 82      1
# 88      1
# 85      1
# 83      1
# Name: Age, Length: 70, dtype: int64

# %%
df.Balance.value_counts()
# Out:
# 0.000         3617
# 130170.820       2
# 105473.740       2
# 85304.270        1
# 159397.750       1
#               ...
# 81556.890        1
# 112687.690       1
# 108698.960       1
# 238387.560       1
# 130142.790       1
# Name: Balance, Length: 6382, dtype: int64

# %%
df.EstimatedSalary.value_counts()
# Out:
# 24924.920     2
# 101348.880    1
# 55313.440     1
# 72500.680     1
# 182692.800    1
#              ..
# 120893.070    1
# 188377.210    1
# 55902.930     1
# 4523.740      1
# 38190.780     1
# Name: EstimatedSalary, Length: 9999, dtype: int64

# %% [markdown]
# ***target column***

# %%
ax = sns.countplot(x='Exited', data=df)
for p in ax.patches:
    percentage = f'{p.get_height()} ({100 * p.get_height() / len(df):.1f}%)\n'
    ax.annotate(percentage, (p.get_x()+0.27, p.get_height()-3), fontsize=13)
ax.set_title('Distribution of Exited Column', pad=15)
ax.set_ylim(0, 9000);

# %%
columns = ['CreditScore', 'Age', 'Balance', 'EstimatedSalary']
index = 0
plt.figure(figsize=(20,14))
for col in columns:    
    index += 1
    plt.subplot(2,2,index)
    sns.boxplot(data=df, x='Exited', y=col)

# %% [markdown]
# ***correlations - patterns***

# %%
sns.pairplot(df, hue='Exited', corner=True)

# %%
columns = ['CreditScore', 'Age', 'Balance', 'EstimatedSalary']

from mpl_toolkits.mplot3d import Axes3D 
fig = plt.figure(figsize=(20,10))
color_map = plt.get_cmap('Spectral')

ax1 = fig.add_subplot(131, projection='3d')
ax1.scatter(df['CreditScore'], df['Age'], df['Exited'], c=df['Exited'], cmap = color_map)
ax1.set_title('CreditScore - Age', fontsize=15)

ax2 = fig.add_subplot(132, projection='3d')
ax2.scatter(df['CreditScore'], df['Balance'], df['Exited'], c=df['Exited'], cmap = color_map)
ax2.set_title('CreditScore - Balance', fontsize=15)

ax3 = fig.add_subplot(133, projection='3d')
ax3.scatter(df['Balance'], df['EstimatedSalary'], df['Exited'], c=df['Exited'], cmap = color_map)
ax3.set_title('Balance - EstimatedSalary', fontsize=15);

# %%
plt.figure(figsize=(16,8))
sns.heatmap(df.corr(), annot=True);

# %%
df.corr()['Exited'].drop('Exited').sort_values().plot.barh()
# df.corr()['Exited'][:-1].sort_values().plot.barh()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ***

# %%
df=pd.get_dummies(df, drop_first=True)
df
# Out:
#            CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# RowNumber
# 1                  619   42       2      0.000              1          1
# 2                  608   41       1  83807.860              1          0
# 3                  502   42       8 159660.800              3          1
# 4                  699   39       1      0.000              2          0
# 5                  850   43       2 125510.820              1          1
# ...                ...  ...     ...        ...            ...        ...
# 9996               771   39       5      0.000              2          1
# 9997               516   35      10  57369.610              1          1
# 9998               709   36       7      0.000              1          0
# 9999               772   42       3  75075.310              2          1
# 10000              792   28       4 130142.790              1          1
#
#            IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# RowNumber
# 1                       1       101348.880       1                  0
# 2                       1       112542.580       0                  0
# 3                       0       113931.570       1                  0
# 4                       0        93826.630       0                  0
# 5                       1        79084.100       0                  0
# ...                   ...              ...     ...                ...
# 9996                    0        96270.640       0                  0
# 9997                    1       101699.770       0                  0
# 9998                    1        42085.580       1                  0
# 9999                    0        92888.520       1                  1
# 10000                   0        38190.780       0                  0
#
#            Geography_Spain  Gender_Male
# RowNumber
# 1                        0            0
# 2                        1            0
# 3                        0            0
# 4                        0            0
# 5                        1            0
# ...                    ...          ...
# 9996                     0            1
# 9997                     0            1
# 9998                     0            0
# 9999                     0            1
# 10000                    0            0
#
# [10000 rows x 12 columns]

# %%
df.shape, df.size
# Out:
# ((10000, 12), 120000)

# %% [markdown]
# ## Preprocessing of Data
# - Train | Test Split, Scaling

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
X = df.drop('Exited', axis=1)
y = df['Exited'].values

# %%
seed=42

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=seed)

# %%
scaler = MinMaxScaler()

# %%
X_train= scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
print("Train features shape : ", X_train.shape)
print("Train target shape   : ", y_train.shape)
print("Test features shape  : ", X_test.shape)
print("Test target shape    : ", y_test.shape)
# Out:
# Train features shape :  (8000, 11)
# Train target shape   :  (8000,)
# Test features shape  :  (2000, 11)
# Test target shape    :  (2000,)

# %% [markdown]
# ## Modeling & Model Performance

# %% [markdown]
# ### Import related libraries

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam, Adadelta, RMSprop, Nadam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import plot_roc_curve, roc_auc_score, roc_curve, precision_recall_curve, average_precision_score
from sklearn.model_selection import cross_val_score, cross_validate
from sklearn.model_selection import GridSearchCV

# %%
print(tf.__version__)
# Out:
# 2.8.0

# %% [markdown]
# ### Creating Model

# %% [markdown]
# ### without class_weigth

# %%
tf.random.set_seed(seed)

model = Sequential()

model.add(Dense(16, activation='relu', input_dim=X_train.shape[1]))
model.add(Dense(16, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['Recall'])  # recall = TP / TP +FN

early_stop = EarlyStopping(monitor='val_loss', mode='auto', verbose=1, patience=15)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16)                192
#
#  dense_1 (Dense)             (None, 16)                272
#
#  dense_2 (Dense)             (None, 8)                 136
#
#  dense_3 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 609
# Trainable params: 609
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x=X_train, y=y_train, validation_split=0.1, batch_size=32, epochs=250, verbose=1,
          callbacks=[early_stop])
# Out:
# Epoch 1/250
# 225/225 [==============================] - 2s 3ms/step - loss: 0.5440 - recall: 0.0284 - val_loss: 0.4696 - val_recall: 0.0000e+00
# Epoch 2/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4816 - recall: 0.0000e+00 - val_loss: 0.4550 - val_recall: 0.0000e+00
# Epoch 3/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4683 - recall: 0.0000e+00 - val_loss: 0.4447 - val_recall: 0.0000e+00
# Epoch 4/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4542 - recall: 0.0514 - val_loss: 0.4316 - val_recall: 0.0789
# Epoch 5/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4365 - recall: 0.1779 - val_loss: 0.4121 - val_recall: 0.1711
# Epoch 6/250
# 225/225 [==============================] - 1s 2ms/step - loss: 0.4209 - recall: 0.2280 - val_loss: 0.3968 - val_recall: 0.2105
# Epoch 7/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4075 - recall: 0.2740 - val_loss: 0.3835 - val_recall: 0.2434
# Epoch 8/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3954 - recall: 0.3275 - val_loss: 0.3663 - val_recall: 0.3355
# Epoch 9/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3836 - recall: 0.3599 - val_loss: 0.3580 - val_recall: 0.3553
# Epoch 10/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3762 - recall: 0.4032 - val_loss: 0.3430 - val_recall: 0.3750
# Epoch 11/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3710 - recall: 0.4107 - val_loss: 0.3425 - val_recall: 0.3684
# Epoch 12/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3671 - recall: 0.4100 - val_loss: 0.3390 - val_recall: 0.3553
# Epoch 13/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3644 - recall: 0.4263 - val_loss: 0.3385 - val_recall: 0.3553
# Epoch 14/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3605 - recall: 0.4303 - val_loss: 0.3299 - val_recall: 0.4474
# Epoch 15/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3566 - recall: 0.4405 - val_loss: 0.3294 - val_recall: 0.3882
# Epoch 16/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3553 - recall: 0.4411 - val_loss: 0.3262 - val_recall: 0.4145
# Epoch 17/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3533 - recall: 0.4405 - val_loss: 0.3282 - val_recall: 0.4803
# Epoch 18/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3518 - recall: 0.4452 - val_loss: 0.3244 - val_recall: 0.4211
# Epoch 19/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3507 - recall: 0.4432 - val_loss: 0.3292 - val_recall: 0.4539
# Epoch 20/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3523 - recall: 0.4452 - val_loss: 0.3252 - val_recall: 0.4408
# Epoch 21/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3490 - recall: 0.4465 - val_loss: 0.3234 - val_recall: 0.4079
# Epoch 22/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3488 - recall: 0.4587 - val_loss: 0.3285 - val_recall: 0.4803
# Epoch 23/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3484 - recall: 0.4438 - val_loss: 0.3256 - val_recall: 0.3816
# Epoch 24/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3476 - recall: 0.4472 - val_loss: 0.3258 - val_recall: 0.3750
# Epoch 25/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3484 - recall: 0.4472 - val_loss: 0.3238 - val_recall: 0.4079
# Epoch 26/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3477 - recall: 0.4432 - val_loss: 0.3239 - val_recall: 0.4342
# Epoch 27/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3467 - recall: 0.4540 - val_loss: 0.3228 - val_recall: 0.4539
# Epoch 28/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3464 - recall: 0.4459 - val_loss: 0.3240 - val_recall: 0.4474
# Epoch 29/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3458 - recall: 0.4479 - val_loss: 0.3232 - val_recall: 0.4539
# Epoch 30/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3447 - recall: 0.4486 - val_loss: 0.3241 - val_recall: 0.4342
# Epoch 31/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3445 - recall: 0.4540 - val_loss: 0.3252 - val_recall: 0.4276
# Epoch 32/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3446 - recall: 0.4526 - val_loss: 0.3254 - val_recall: 0.4934
# Epoch 33/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3436 - recall: 0.4445 - val_loss: 0.3259 - val_recall: 0.4408
# Epoch 34/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3439 - recall: 0.4553 - val_loss: 0.3240 - val_recall: 0.4737
# Epoch 35/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3429 - recall: 0.4641 - val_loss: 0.3232 - val_recall: 0.3947
# Epoch 36/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3428 - recall: 0.4621 - val_loss: 0.3223 - val_recall: 0.3947
# Epoch 37/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3421 - recall: 0.4553 - val_loss: 0.3225 - val_recall: 0.4539
# Epoch 38/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3409 - recall: 0.4601 - val_loss: 0.3209 - val_recall: 0.3947
# Epoch 39/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3411 - recall: 0.4608 - val_loss: 0.3208 - val_recall: 0.3947
# Epoch 40/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3432 - recall: 0.4581 - val_loss: 0.3255 - val_recall: 0.5066
# Epoch 41/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3397 - recall: 0.4581 - val_loss: 0.3234 - val_recall: 0.4671
# Epoch 42/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3410 - recall: 0.4635 - val_loss: 0.3217 - val_recall: 0.4013
# Epoch 43/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3409 - recall: 0.4513 - val_loss: 0.3227 - val_recall: 0.4605
# Epoch 44/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3408 - recall: 0.4635 - val_loss: 0.3231 - val_recall: 0.4276
# Epoch 45/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3403 - recall: 0.4614 - val_loss: 0.3220 - val_recall: 0.4013
# Epoch 46/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3391 - recall: 0.4614 - val_loss: 0.3243 - val_recall: 0.4079
# Epoch 47/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3384 - recall: 0.4662 - val_loss: 0.3217 - val_recall: 0.4276
# Epoch 48/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3391 - recall: 0.4628 - val_loss: 0.3251 - val_recall: 0.4803
# Epoch 49/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3378 - recall: 0.4621 - val_loss: 0.3362 - val_recall: 0.5592
# Epoch 50/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3395 - recall: 0.4655 - val_loss: 0.3284 - val_recall: 0.4013
# Epoch 51/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3382 - recall: 0.4608 - val_loss: 0.3289 - val_recall: 0.5263
# Epoch 52/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3389 - recall: 0.4655 - val_loss: 0.3220 - val_recall: 0.4474
# Epoch 53/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3372 - recall: 0.4635 - val_loss: 0.3226 - val_recall: 0.4605
# Epoch 54/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3373 - recall: 0.4709 - val_loss: 0.3211 - val_recall: 0.4803
# Epoch 54: early stopping

# %%
loss_df = pd.DataFrame(model.history.history)
loss_df.head()
# Out:
#    loss  recall  val_loss  val_recall
# 0 0.544   0.028     0.470       0.000
# 1 0.482   0.000     0.455       0.000
# 2 0.468   0.000     0.445       0.000
# 3 0.454   0.051     0.432       0.079
# 4 0.436   0.178     0.412       0.171

# %%
loss_df.plot();

# %% [markdown]
# #### Evaluate

# %%
model.evaluate(X_test, y_test, verbose=0)
# Out:
# [0.34186655282974243, 0.49631449580192566]

# %%
loss, recall = model.evaluate(X_test, y_test, verbose=0)
print("loss : ", loss)
print("recall : ", recall)
# Out:
# loss :  0.34186655282974243
# recall :  0.49631449580192566

# %%
y_pred = (model.predict(X_test) > 0.5).astype("int32")

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[1528   65]
#  [ 205  202]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.96      0.92      1593
#            1       0.76      0.50      0.60       407
#
#     accuracy                           0.86      2000
#    macro avg       0.82      0.73      0.76      2000
# weighted avg       0.86      0.86      0.85      2000

# %%
y_pred_proba = model.predict(X_test)
precision, recall, thresholds = precision_recall_curve(y_test, y_pred_proba)
plt.plot([1,0],[0,1],'k--')
plt.plot(recall, precision)
plt.xlabel('recall')
plt.ylabel('precision')
plt.title('Precision-Recall Curve')
plt.show()

# %%
average_precision_score(y_test, y_pred_proba)
# Out:
# 0.6965488411032849

# %% [markdown]
# ### with class_weigth

# %%
from sklearn.utils import class_weight
class_weights = class_weight.compute_class_weight('balanced', np.unique(y_train), y_train)
class_weights = {0: class_weights[0], 1: class_weights[1]}
class_weights
# Out:
# {0: 0.6279434850863422, 1: 2.4539877300613497}

# %%
tf.random.set_seed(seed)

model_2 = Sequential()

model_2.add(Dense(16, activation='relu', input_dim=X_train.shape[1]))
model_2.add(Dense(16, activation='relu'))
model_2.add(Dense(8, activation='relu'))
model_2.add(Dense(1, activation='sigmoid'))

model_2.compile(optimizer='adam', loss='binary_crossentropy', metrics=['Recall'])

early_stop = EarlyStopping(monitor='val_loss', mode='auto', verbose=1, patience=15)

# %%
model_2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 16)                192
#
#  dense_5 (Dense)             (None, 16)                272
#
#  dense_6 (Dense)             (None, 8)                 136
#
#  dense_7 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 609
# Trainable params: 609
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_2.fit(x=X_train, y=y_train, validation_split=0.1, batch_size=32, epochs=250, verbose=1,
            callbacks=[early_stop], class_weight=class_weights)
# Out:
# Epoch 1/250
# 225/225 [==============================] - 2s 3ms/step - loss: 0.6907 - recall: 0.5907 - val_loss: 0.6783 - val_recall: 0.7237
# Epoch 2/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.6457 - recall: 0.6191 - val_loss: 0.6159 - val_recall: 0.6513
# Epoch 3/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.6129 - recall: 0.6488 - val_loss: 0.6181 - val_recall: 0.6974
# Epoch 4/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.5915 - recall: 0.6881 - val_loss: 0.5048 - val_recall: 0.5263
# Epoch 5/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.5778 - recall: 0.6888 - val_loss: 0.5362 - val_recall: 0.6711
# Epoch 6/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.5654 - recall: 0.7050 - val_loss: 0.5428 - val_recall: 0.7039
# Epoch 7/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.5535 - recall: 0.7057 - val_loss: 0.5102 - val_recall: 0.6776
# Epoch 8/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.5429 - recall: 0.7300 - val_loss: 0.5083 - val_recall: 0.6908
# Epoch 9/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.5321 - recall: 0.7463 - val_loss: 0.4816 - val_recall: 0.7039
# Epoch 10/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.5257 - recall: 0.7402 - val_loss: 0.5045 - val_recall: 0.7697
# Epoch 11/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.5180 - recall: 0.7456 - val_loss: 0.4803 - val_recall: 0.6974
# Epoch 12/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.5108 - recall: 0.7530 - val_loss: 0.4450 - val_recall: 0.6513
# Epoch 13/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.5091 - recall: 0.7517 - val_loss: 0.4476 - val_recall: 0.6842
# Epoch 14/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.5030 - recall: 0.7544 - val_loss: 0.4920 - val_recall: 0.7763
# Epoch 15/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4975 - recall: 0.7564 - val_loss: 0.4481 - val_recall: 0.7368
# Epoch 16/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4951 - recall: 0.7503 - val_loss: 0.4696 - val_recall: 0.7500
# Epoch 17/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4933 - recall: 0.7551 - val_loss: 0.5017 - val_recall: 0.7763
# Epoch 18/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4883 - recall: 0.7571 - val_loss: 0.4412 - val_recall: 0.7303
# Epoch 19/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4838 - recall: 0.7436 - val_loss: 0.5164 - val_recall: 0.8158
# Epoch 20/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4858 - recall: 0.7483 - val_loss: 0.4592 - val_recall: 0.7566
# Epoch 21/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4795 - recall: 0.7564 - val_loss: 0.4686 - val_recall: 0.7763
# Epoch 22/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4802 - recall: 0.7517 - val_loss: 0.5103 - val_recall: 0.8355
# Epoch 23/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4782 - recall: 0.7497 - val_loss: 0.4298 - val_recall: 0.7368
# Epoch 24/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4763 - recall: 0.7530 - val_loss: 0.4125 - val_recall: 0.7171
# Epoch 25/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4757 - recall: 0.7530 - val_loss: 0.4331 - val_recall: 0.7500
# Epoch 26/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4747 - recall: 0.7517 - val_loss: 0.4715 - val_recall: 0.7961
# Epoch 27/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4730 - recall: 0.7537 - val_loss: 0.4364 - val_recall: 0.7566
# Epoch 28/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4737 - recall: 0.7537 - val_loss: 0.4727 - val_recall: 0.8092
# Epoch 29/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4717 - recall: 0.7483 - val_loss: 0.4755 - val_recall: 0.8224
# Epoch 30/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4699 - recall: 0.7558 - val_loss: 0.4671 - val_recall: 0.7895
# Epoch 31/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4687 - recall: 0.7585 - val_loss: 0.4637 - val_recall: 0.8026
# Epoch 32/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4692 - recall: 0.7612 - val_loss: 0.4735 - val_recall: 0.8289
# Epoch 33/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4678 - recall: 0.7659 - val_loss: 0.4714 - val_recall: 0.8224
# Epoch 34/250
# 225/225 [==============================] - 1s 2ms/step - loss: 0.4677 - recall: 0.7666 - val_loss: 0.4785 - val_recall: 0.8224
# Epoch 35/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4661 - recall: 0.7605 - val_loss: 0.4146 - val_recall: 0.7237
# Epoch 36/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4659 - recall: 0.7571 - val_loss: 0.4369 - val_recall: 0.7829
# Epoch 37/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4643 - recall: 0.7625 - val_loss: 0.4761 - val_recall: 0.8224
# Epoch 38/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4631 - recall: 0.7652 - val_loss: 0.4080 - val_recall: 0.7434
# Epoch 39/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4628 - recall: 0.7652 - val_loss: 0.4220 - val_recall: 0.7632
# Epoch 40/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4656 - recall: 0.7618 - val_loss: 0.4920 - val_recall: 0.8289
# Epoch 41/250
# 225/225 [==============================] - 1s 2ms/step - loss: 0.4616 - recall: 0.7578 - val_loss: 0.4417 - val_recall: 0.7829
# Epoch 42/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4625 - recall: 0.7625 - val_loss: 0.4151 - val_recall: 0.7697
# Epoch 43/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4606 - recall: 0.7632 - val_loss: 0.4498 - val_recall: 0.8026
# Epoch 44/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4616 - recall: 0.7639 - val_loss: 0.4445 - val_recall: 0.7763
# Epoch 45/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4608 - recall: 0.7632 - val_loss: 0.4290 - val_recall: 0.7566
# Epoch 46/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4597 - recall: 0.7585 - val_loss: 0.4429 - val_recall: 0.7829
# Epoch 47/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4580 - recall: 0.7625 - val_loss: 0.4299 - val_recall: 0.7697
# Epoch 48/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4586 - recall: 0.7591 - val_loss: 0.4597 - val_recall: 0.8026
# Epoch 49/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4562 - recall: 0.7551 - val_loss: 0.5221 - val_recall: 0.8553
# Epoch 50/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4575 - recall: 0.7693 - val_loss: 0.4235 - val_recall: 0.7237
# Epoch 51/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4577 - recall: 0.7591 - val_loss: 0.4817 - val_recall: 0.8092
# Epoch 52/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4579 - recall: 0.7591 - val_loss: 0.4247 - val_recall: 0.7697
# Epoch 53/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4559 - recall: 0.7544 - val_loss: 0.4466 - val_recall: 0.7763
# Epoch 53: early stopping

# %%
loss_df2 = pd.DataFrame(model_2.history.history)
loss_df2.head()
# Out:
#    loss  recall  val_loss  val_recall
# 0 0.691   0.591     0.678       0.724
# 1 0.646   0.619     0.616       0.651
# 2 0.613   0.649     0.618       0.697
# 3 0.591   0.688     0.505       0.526
# 4 0.578   0.689     0.536       0.671

# %%
loss_df2.plot();

# %% [markdown]
# #### Evaluate

# %%
model_2.evaluate(X_test, y_test, verbose=0)
# Out:
# [0.4553016424179077, 0.7690417766571045]

# %%
loss, recall = model_2.evaluate(X_test, y_test, verbose=0)
print("loss   : ", loss)
print("recall : ", recall)
# Out:
# loss   :  0.4553016424179077
# recall :  0.7690417766571045

# %%
y_pred = (model_2.predict(X_test) > 0.5).astype("int32")

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[1261  332]
#  [  94  313]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.79      0.86      1593
#            1       0.49      0.77      0.60       407
#
#     accuracy                           0.79      2000
#    macro avg       0.71      0.78      0.73      2000
# weighted avg       0.84      0.79      0.80      2000

# %%
y_pred_proba = model_2.predict(X_test)
precision, recall, thresholds = precision_recall_curve(y_test, y_pred_proba)
plt.plot([1,0],[0,1],'k--')
plt.plot(recall, precision)
plt.xlabel('recall')
plt.ylabel('precision')
plt.title('Precision-Recall Curve')
plt.show()

# %%
average_precision_score(y_test, y_pred_proba)
# Out:
# 0.7020116865527525

# %% [markdown]
# ## GridSearchCV

# %%
def build_classifier(optimizer, learn_rate):
    classifier = Sequential()
    classifier.add(Dense(units=16, activation='relu'))
    classifier.add(Dense(units=16, activation='relu'))
    classifier.add(Dense(units=8, activation='relu'))
    classifier.add(Dense(units=1, activation='sigmoid'))
    classifier.compile(optimizer=optimizer(learn_rate), loss='binary_crossentropy', metrics=['Recall'])
    return classifier

# %%
early_stop = EarlyStopping(monitor = "val_recall", mode = "auto", verbose = 1, patience = 15)

# %%
tf.random.set_seed(seed)

classifier_model = KerasClassifier(build_fn = build_classifier, validation_split = 0.1, epochs = 250)

parameters = {'batch_size': [32, 64],
              'optimizer': [Adam, RMSprop, Adadelta, Nadam],
              'learn_rate': [0.001, 0.003, 0.005]}

grid_model = GridSearchCV(estimator = classifier_model,
                          param_grid = parameters,
                          scoring = 'recall',
                          cv = 10,
                          n_jobs = -1,
                          verbose = 1)

grid_model.fit(X_train, y_train, callbacks = [early_stop], class_weight=class_weights)
# Out:
# Fitting 10 folds for each of 24 candidates, totalling 240 fits
# Epoch 1/250
# 225/225 [==============================] - 1s 3ms/step - loss: 0.6703 - recall: 0.4899 - val_loss: 0.5769 - val_recall: 0.5592
# Epoch 2/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.6021 - recall: 0.6624 - val_loss: 0.5870 - val_recall: 0.7500
# Epoch 3/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.5614 - recall: 0.6969 - val_loss: 0.5512 - val_recall: 0.7171
# Epoch 4/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.5310 - recall: 0.7104 - val_loss: 0.4281 - val_recall: 0.5658
# Epoch 5/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.5073 - recall: 0.7307 - val_loss: 0.4682 - val_recall: 0.6645
# Epoch 6/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4983 - recall: 0.7246 - val_loss: 0.4686 - val_recall: 0.7500
# Epoch 7/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4908 - recall: 0.7226 - val_loss: 0.4329 - val_recall: 0.6974
# Epoch 8/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4875 - recall: 0.7287 - val_loss: 0.4275 - val_recall: 0.6974
# Epoch 9/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4834 - recall: 0.7402 - val_loss: 0.3997 - val_recall: 0.6711
# Epoch 10/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4811 - recall: 0.7388 - val_loss: 0.4290 - val_recall: 0.7368
# Epoch 11/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4794 - recall: 0.7361 - val_loss: 0.4261 - val_recall: 0.6776
# Epoch 12/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4792 - recall: 0.7395 - val_loss: 0.4369 - val_recall: 0.6711
# Epoch 13/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4787 - recall: 0.7348 - val_loss: 0.4262 - val_recall: 0.7171
# Epoch 14/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4759 - recall: 0.7361 - val_loss: 0.4671 - val_recall: 0.7763
# Epoch 15/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4726 - recall: 0.7375 - val_loss: 0.4057 - val_recall: 0.7237
# Epoch 16/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4715 - recall: 0.7388 - val_loss: 0.4439 - val_recall: 0.7763
# Epoch 16: early stopping
# GridSearchCV(cv=10,
#              estimator=<keras.wrappers.scikit_learn.KerasClassifier object at 0x000002747B6F3FA0>,
#              n_jobs=-1,
#              param_grid={'batch_size': [32, 64],
#                          'learn_rate': [0.001, 0.003, 0.005],
#                          'optimizer': [<class 'keras.optimizer_v2.adam.Adam'>,
#                                        <class 'keras.optimizer_v2.rmsprop.RMSprop'>,
#                                        <class 'keras.optimizer_v2.adadelta.Adadelta'>,
#                                        <class 'keras.optimizer_v2.nadam.Nadam'>]},
#              scoring='recall', verbose=1)

# %%
grid_model.best_score_
# Out:
# 0.7590570548710096

# %%
grid_model.best_params_
# Out:
# {'batch_size': 32,
#  'learn_rate': 0.003,
#  'optimizer': keras.optimizer_v2.adam.Adam}

# %%
grid_result = pd.DataFrame(grid_model.cv_results_)[["mean_test_score", "std_test_score", "rank_test_score", "params"]]
grid_result
# Out:
#     mean_test_score  std_test_score  rank_test_score  \
# 0             0.746           0.060                6
# 1             0.709           0.052               18
# 2             0.467           0.335               21
# 3             0.734           0.047               11
# 4             0.759           0.052                1
# 5             0.747           0.066                5
# 6             0.506           0.330               19
# 7             0.745           0.039                7
# 8             0.732           0.053               14
# 9             0.732           0.069               15
# 10            0.405           0.204               22
# 11            0.744           0.058                8
# 12            0.741           0.072                9
# 13            0.731           0.076               16
# 14            0.304           0.337               23
# 15            0.734           0.049               12
# 16            0.754           0.049                3
# 17            0.733           0.079               13
# 18            0.290           0.227               24
# 19            0.755           0.049                2
# 20            0.752           0.056                4
# 21            0.710           0.145               17
# 22            0.494           0.272               20
# 23            0.739           0.090               10
#
#                                                params
# 0   {'batch_size': 32, 'learn_rate': 0.001, 'optim...
# 1   {'batch_size': 32, 'learn_rate': 0.001, 'optim...
# 2   {'batch_size': 32, 'learn_rate': 0.001, 'optim...
# 3   {'batch_size': 32, 'learn_rate': 0.001, 'optim...
# 4   {'batch_size': 32, 'learn_rate': 0.003, 'optim...
# 5   {'batch_size': 32, 'learn_rate': 0.003, 'optim...
# 6   {'batch_size': 32, 'learn_rate': 0.003, 'optim...
# 7   {'batch_size': 32, 'learn_rate': 0.003, 'optim...
# 8   {'batch_size': 32, 'learn_rate': 0.005, 'optim...
# 9   {'batch_size': 32, 'learn_rate': 0.005, 'optim...
# 10  {'batch_size': 32, 'learn_rate': 0.005, 'optim...
# 11  {'batch_size': 32, 'learn_rate': 0.005, 'optim...
# 12  {'batch_size': 64, 'learn_rate': 0.001, 'optim...
# 13  {'batch_size': 64, 'learn_rate': 0.001, 'optim...
# 14  {'batch_size': 64, 'learn_rate': 0.001, 'optim...
# 15  {'batch_size': 64, 'learn_rate': 0.001, 'optim...
# 16  {'batch_size': 64, 'learn_rate': 0.003, 'optim...
# 17  {'batch_size': 64, 'learn_rate': 0.003, 'optim...
# 18  {'batch_size': 64, 'learn_rate': 0.003, 'optim...
# 19  {'batch_size': 64, 'learn_rate': 0.003, 'optim...
# 20  {'batch_size': 64, 'learn_rate': 0.005, 'optim...
# 21  {'batch_size': 64, 'learn_rate': 0.005, 'optim...
# 22  {'batch_size': 64, 'learn_rate': 0.005, 'optim...
# 23  {'batch_size': 64, 'learn_rate': 0.005, 'optim...

# %% [markdown]
# #### Evaluate

# %%
y_pred = (grid_model.predict(X_test) > 0.5).astype("int32")

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[1270  323]
#  [ 108  299]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.80      0.85      1593
#            1       0.48      0.73      0.58       407
#
#     accuracy                           0.78      2000
#    macro avg       0.70      0.77      0.72      2000
# weighted avg       0.83      0.78      0.80      2000

# %%
y_pred_proba = grid_model.predict(X_test)
precision, recall, thresholds = precision_recall_curve(y_test, y_pred_proba)
plt.plot([1,0],[0,1],'k--')
plt.plot(recall, precision)
plt.xlabel('recall')
plt.ylabel('precision')
plt.title('Precision-Recall Curve')
plt.show()

# %%
average_precision_score(y_test, y_pred_proba)
# Out:
# 0.4071486762998017

# %% [markdown]
# ## Final Model and Model Deployment

# %%
import pickle
pickle.dump(scaler, open('scaler_churn', 'wb'))

# %%
tf.random.set_seed(seed)

model = Sequential()

model.add(Dense(16, activation='relu', input_dim=X_train.shape[1]))
model.add(Dense(16, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

opt = Adam(lr=0.001)
model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['Recall'])

early_stop = EarlyStopping(monitor='val_loss', mode='auto', verbose=1, patience=15)

# %%
model.fit(x=X_train, y=y_train, validation_data=(X_test, y_test), batch_size=32, epochs=250, verbose=1,
            callbacks=[early_stop], class_weight=class_weights)
# Out:
# Epoch 1/250
# 250/250 [==============================] - 2s 4ms/step - loss: 0.6875 - recall: 0.6448 - val_loss: 0.6709 - val_recall: 0.6290
# Epoch 2/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.6355 - recall: 0.6387 - val_loss: 0.6465 - val_recall: 0.6855
# Epoch 3/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.5992 - recall: 0.6730 - val_loss: 0.5800 - val_recall: 0.6708
# Epoch 4/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.5793 - recall: 0.6926 - val_loss: 0.5689 - val_recall: 0.7002
# Epoch 5/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.5630 - recall: 0.6933 - val_loss: 0.5694 - val_recall: 0.7420
# Epoch 6/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.5495 - recall: 0.7166 - val_loss: 0.5853 - val_recall: 0.7666
# Epoch 7/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.5378 - recall: 0.7344 - val_loss: 0.5455 - val_recall: 0.7641
# Epoch 8/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.5210 - recall: 0.7319 - val_loss: 0.4846 - val_recall: 0.7052
# Epoch 9/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.5097 - recall: 0.7442 - val_loss: 0.5384 - val_recall: 0.7936
# Epoch 10/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4998 - recall: 0.7417 - val_loss: 0.4764 - val_recall: 0.7396
# Epoch 11/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4907 - recall: 0.7515 - val_loss: 0.5361 - val_recall: 0.7936
# Epoch 12/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4886 - recall: 0.7485 - val_loss: 0.4520 - val_recall: 0.7174
# Epoch 13/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4877 - recall: 0.7411 - val_loss: 0.4962 - val_recall: 0.7641
# Epoch 14/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4829 - recall: 0.7497 - val_loss: 0.4940 - val_recall: 0.7641
# Epoch 15/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4813 - recall: 0.7472 - val_loss: 0.4658 - val_recall: 0.7346
# Epoch 16/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4812 - recall: 0.7515 - val_loss: 0.4409 - val_recall: 0.7052
# Epoch 17/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4774 - recall: 0.7485 - val_loss: 0.4624 - val_recall: 0.7396
# Epoch 18/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4762 - recall: 0.7515 - val_loss: 0.5096 - val_recall: 0.7887
# Epoch 19/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4751 - recall: 0.7479 - val_loss: 0.4900 - val_recall: 0.7715
# Epoch 20/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4754 - recall: 0.7472 - val_loss: 0.4318 - val_recall: 0.7076
# Epoch 21/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4744 - recall: 0.7503 - val_loss: 0.4667 - val_recall: 0.7518
# Epoch 22/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4738 - recall: 0.7479 - val_loss: 0.4783 - val_recall: 0.7690
# Epoch 23/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4718 - recall: 0.7491 - val_loss: 0.4775 - val_recall: 0.7568
# Epoch 24/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4719 - recall: 0.7503 - val_loss: 0.4566 - val_recall: 0.7518
# Epoch 25/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4703 - recall: 0.7528 - val_loss: 0.4919 - val_recall: 0.7789
# Epoch 26/250
# 250/250 [==============================] - 1s 3ms/step - loss: 0.4698 - recall: 0.7552 - val_loss: 0.4863 - val_recall: 0.7838
# Epoch 27/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4688 - recall: 0.7521 - val_loss: 0.4837 - val_recall: 0.7789
# Epoch 28/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4679 - recall: 0.7534 - val_loss: 0.4568 - val_recall: 0.7346
# Epoch 29/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4688 - recall: 0.7436 - val_loss: 0.4280 - val_recall: 0.7052
# Epoch 30/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4676 - recall: 0.7485 - val_loss: 0.4771 - val_recall: 0.7690
# Epoch 31/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4671 - recall: 0.7472 - val_loss: 0.4428 - val_recall: 0.7346
# Epoch 32/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4661 - recall: 0.7564 - val_loss: 0.4461 - val_recall: 0.7396
# Epoch 33/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4655 - recall: 0.7485 - val_loss: 0.5036 - val_recall: 0.7887
# Epoch 34/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4657 - recall: 0.7448 - val_loss: 0.4861 - val_recall: 0.7912
# Epoch 35/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4638 - recall: 0.7466 - val_loss: 0.4473 - val_recall: 0.7494
# Epoch 36/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4636 - recall: 0.7558 - val_loss: 0.4565 - val_recall: 0.7445
# Epoch 37/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4628 - recall: 0.7491 - val_loss: 0.4434 - val_recall: 0.7396
# Epoch 38/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4630 - recall: 0.7540 - val_loss: 0.5543 - val_recall: 0.8231
# Epoch 39/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4619 - recall: 0.7534 - val_loss: 0.5216 - val_recall: 0.8010
# Epoch 40/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4616 - recall: 0.7479 - val_loss: 0.5247 - val_recall: 0.8084
# Epoch 41/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4608 - recall: 0.7571 - val_loss: 0.4158 - val_recall: 0.7002
# Epoch 42/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4601 - recall: 0.7460 - val_loss: 0.4855 - val_recall: 0.7813
# Epoch 43/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4606 - recall: 0.7583 - val_loss: 0.5305 - val_recall: 0.7985
# Epoch 44/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4574 - recall: 0.7558 - val_loss: 0.4270 - val_recall: 0.6978
# Epoch 45/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4586 - recall: 0.7583 - val_loss: 0.4390 - val_recall: 0.7396
# Epoch 46/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4563 - recall: 0.7583 - val_loss: 0.4239 - val_recall: 0.7150
# Epoch 47/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4572 - recall: 0.7540 - val_loss: 0.5039 - val_recall: 0.8059
# Epoch 48/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4579 - recall: 0.7577 - val_loss: 0.4505 - val_recall: 0.7420
# Epoch 49/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4559 - recall: 0.7583 - val_loss: 0.4028 - val_recall: 0.6855
# Epoch 50/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4568 - recall: 0.7521 - val_loss: 0.4134 - val_recall: 0.6904
# Epoch 51/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4561 - recall: 0.7540 - val_loss: 0.4326 - val_recall: 0.7322
# Epoch 52/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4543 - recall: 0.7601 - val_loss: 0.4486 - val_recall: 0.7592
# Epoch 53/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4547 - recall: 0.7650 - val_loss: 0.5181 - val_recall: 0.8182
# Epoch 54/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4544 - recall: 0.7613 - val_loss: 0.4663 - val_recall: 0.7813
# Epoch 55/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4540 - recall: 0.7564 - val_loss: 0.4694 - val_recall: 0.7789
# Epoch 56/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4544 - recall: 0.7583 - val_loss: 0.5039 - val_recall: 0.8010
# Epoch 57/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4554 - recall: 0.7589 - val_loss: 0.4770 - val_recall: 0.7887
# Epoch 58/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4520 - recall: 0.7693 - val_loss: 0.4373 - val_recall: 0.7543
# Epoch 59/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4514 - recall: 0.7601 - val_loss: 0.4062 - val_recall: 0.6830
# Epoch 60/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4518 - recall: 0.7564 - val_loss: 0.5344 - val_recall: 0.8256
# Epoch 61/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4512 - recall: 0.7638 - val_loss: 0.5106 - val_recall: 0.8157
# Epoch 62/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4511 - recall: 0.7669 - val_loss: 0.4291 - val_recall: 0.7174
# Epoch 63/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4514 - recall: 0.7699 - val_loss: 0.3902 - val_recall: 0.6781
# Epoch 64/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4508 - recall: 0.7558 - val_loss: 0.4286 - val_recall: 0.7346
# Epoch 65/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4502 - recall: 0.7675 - val_loss: 0.4217 - val_recall: 0.7248
# Epoch 66/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4496 - recall: 0.7613 - val_loss: 0.4675 - val_recall: 0.7862
# Epoch 67/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4489 - recall: 0.7656 - val_loss: 0.4533 - val_recall: 0.7715
# Epoch 68/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4514 - recall: 0.7681 - val_loss: 0.4372 - val_recall: 0.7445
# Epoch 69/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4480 - recall: 0.7589 - val_loss: 0.4439 - val_recall: 0.7371
# Epoch 70/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4490 - recall: 0.7577 - val_loss: 0.4290 - val_recall: 0.7371
# Epoch 71/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4485 - recall: 0.7607 - val_loss: 0.4673 - val_recall: 0.7789
# Epoch 72/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4472 - recall: 0.7644 - val_loss: 0.4066 - val_recall: 0.6978
# Epoch 73/250
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4490 - recall: 0.7546 - val_loss: 0.4759 - val_recall: 0.7985
# Epoch 74/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4453 - recall: 0.7706 - val_loss: 0.4078 - val_recall: 0.6978
# Epoch 75/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4440 - recall: 0.7650 - val_loss: 0.4657 - val_recall: 0.7887
# Epoch 76/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4478 - recall: 0.7644 - val_loss: 0.4295 - val_recall: 0.7396
# Epoch 77/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4464 - recall: 0.7583 - val_loss: 0.4682 - val_recall: 0.7961
# Epoch 78/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4462 - recall: 0.7681 - val_loss: 0.4732 - val_recall: 0.7887
# Epoch 78: early stopping

# %%
loss_df = pd.DataFrame(model.history.history)
loss_df.plot()
# Out:
# <AxesSubplot:>

# %%
loss, recall = model.evaluate(X_test, y_test, verbose=0)
print("loss     : ", loss)
print("recall : ", recall)
# Out:
# loss     :  0.4732294976711273
# recall :  0.7886977791786194

# %%
y_pred = (model.predict(X_test) > 0.5).astype("int32")

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[1225  368]
#  [  86  321]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.77      0.84      1593
#            1       0.47      0.79      0.59       407
#
#     accuracy                           0.77      2000
#    macro avg       0.70      0.78      0.71      2000
# weighted avg       0.84      0.77      0.79      2000

# %%
model.save('model_churn.h5')

# %% [markdown]
# ### Prediction

# %%
from tensorflow.keras.models import load_model

# %%
model_churn = load_model('model_churn.h5')
scaler_churn = pickle.load(open("scaler_churn", "rb"))

# %%
sample_custs = df.drop('Exited', axis = 1).iloc[0:5, :]
sample_custs
# Out:
#            CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# RowNumber
# 1                  619   42       2      0.000              1          1
# 2                  608   41       1  83807.860              1          0
# 3                  502   42       8 159660.800              3          1
# 4                  699   39       1      0.000              2          0
# 5                  850   43       2 125510.820              1          1
#
#            IsActiveMember  EstimatedSalary  Geography_Germany  \
# RowNumber
# 1                       1       101348.880                  0
# 2                       1       112542.580                  0
# 3                       0       113931.570                  0
# 4                       0        93826.630                  0
# 5                       1        79084.100                  0
#
#            Geography_Spain  Gender_Male
# RowNumber
# 1                        0            0
# 2                        1            0
# 3                        0            0
# 4                        0            0
# 5                        1            0

# %%
sample_custs = scaler_churn.transform(sample_custs)
sample_custs
# Out:
# array([[0.538     , 0.32432432, 0.2       , 0.        , 0.        ,
#         1.        , 1.        , 0.50673489, 0.        , 0.        ,
#         0.        ],
#        [0.516     , 0.31081081, 0.1       , 0.35156138, 0.        ,
#         0.        , 1.        , 0.56270874, 0.        , 1.        ,
#         0.        ],
#        [0.304     , 0.32432432, 0.8       , 0.66975307, 0.66666667,
#         1.        , 0.        , 0.56965435, 0.        , 0.        ,
#         0.        ],
#        [0.698     , 0.28378378, 0.1       , 0.        , 0.33333333,
#         0.        , 0.        , 0.46912005, 0.        , 0.        ,
#         0.        ],
#        [1.        , 0.33783784, 0.2       , 0.52649903, 0.        ,
#         1.        , 1.        , 0.39540036, 0.        , 1.        ,
#         0.        ]])

# %%
(model_churn.predict(sample_custs) > 0.5).astype("int32")
# Out:
# array([[1],
#        [1],
#        [1],
#        [0],
#        [0]])

# %%
df["Exited"].iloc[0:5]
# Out:
# RowNumber
# 1    1
# 2    0
# 3    1
# 4    0
# 5    0
# Name: Exited, dtype: int64

# %% [markdown]
# ***

# %% [markdown]
# ## Comparison with ML

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_model=LogisticRegression(class_weight='balanced')
log_model.fit(X_train, y_train)
y_pred = log_model.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[1137  456]
#  [ 122  285]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.71      0.80      1593
#            1       0.38      0.70      0.50       407
#
#     accuracy                           0.71      2000
#    macro avg       0.64      0.71      0.65      2000
# weighted avg       0.80      0.71      0.74      2000

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model = RandomForestClassifier(class_weight='balanced')
rf_model.fit(X_train, y_train)
y_pred = rf_model.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[1540   53]
#  [ 221  186]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.92      1593
#            1       0.78      0.46      0.58       407
#
#     accuracy                           0.86      2000
#    macro avg       0.83      0.71      0.75      2000
# weighted avg       0.85      0.86      0.85      2000

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
